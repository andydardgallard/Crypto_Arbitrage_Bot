# %%
import requests
import json
import csv

def write_csv(new_line):
    with open("common.csv", "a" ) as fout:
        writer=csv.writer(fout)
        writer.writerow((new_line))

# %%
pos=0.25
base_url="https://btc-e.nz/api/3/"
pairs="btc_rur-btc_usd-dsh_btc-dsh_eth-dsh_ltc-dsh_usd-eth_btc-eth_ltc-eth_usd-ltc_btc-ltc_usd-nmc_btc-nmc_usd-nvc_btc-nvc_usd-ppc_btc-ppc_usd"

ticker_url=base_url+"ticker/"+pairs
depth_url=base_url+"depth/"+pairs

html_ticker=requests.get(ticker_url).text
html_depth=requests.get(depth_url).text

ticker_data=json.loads(html_ticker)
depth_data=json.loads(html_depth)

for i in ticker_data:
    q=0
    w=[]
    e=[]
    for j in depth_data[i]["bids"]:
        q=q+j[1]
        if q>pos:
            w.append(j)
        if q<pos:
            e.append(j)      
    r=0
    t=0
    for j in e:
        r=j[0]*j[1]+r
        t=j[1]+t    
    r=w[0][0]*(pos-t)+r
    bids=r/pos


    q=0
    w=[]
    e=[]
    for j in depth_data[i]["asks"]:
        q=q+j[1]
        if q>pos:
            w.append(j)
        if q<pos:
            e.append(j)    
    r=0
    t=0
    for j in e:
        r=j[0]*j[1]+r
        t=j[1]+t    
    r=w[0][0]*(pos-t)+r
    asks=r/pos    
    
    new_line=["btc-e", str(i).replace("_","").upper(), ticker_data[i]["buy"], ticker_data[i]["sell"], asks, bids]
    #new_line=[str(i), str(ticker_data[i]["buy"]), str(ticker_data[i]["sell"]), str(asks), str(bids)]
    print new_line
    
    #write_csv(new_line)
    #print i, ticker_data[i]["buy"], ticker_data[i]["sell"], asks, bids
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-c86f412f8d6d> in <module>()
#       9 html_depth=requests.get(depth_url).text
#      10
# ---> 11 ticker_data=json.loads(html_ticker)
#      12 depth_data=json.loads(html_depth)
#      13
#
# C:\ProgramData\Anaconda2\lib\json\__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337             parse_int is None and parse_float is None and
#     338             parse_constant is None and object_pairs_hook is None and not kw):
# --> 339         return _default_decoder.decode(s)
#     340     if cls is None:
#     341         cls = JSONDecoder
#
# C:\ProgramData\Anaconda2\lib\json\decoder.pyc in decode(self, s, _w)
#     362
#     363         """
# --> 364         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     365         end = _w(s, end).end()
#     366         if end != len(s):
#
# C:\ProgramData\Anaconda2\lib\json\decoder.pyc in raw_decode(self, s, idx)
#     380             obj, end = self.scan_once(s, idx)
#     381         except StopIteration:
# --> 382             raise ValueError("No JSON object could be decoded")
#     383         return obj, end
#
# ValueError: No JSON object could be decoded

# %%
#print "btc-e", str(i).replace("_","").upper(), ticker_data[i]["buy"], ticker_data[i]["sell"], asks, bids
# Out:
# btc-e NVCUSD 3.565 3.544 3.565 3.545

# %%
#pairs=open('pairs.txt').read().split("\n")

# %%
#for i in pairs:
#    print i
# Out:
# 1ST_BTC
# 1ST_DASH
# 1ST_DOGE
# 1ST_ETC
# 1ST_ETH
# 1ST_EUR
# 1ST_LTC
# 1ST_NXT
# 1ST_POSW
# 1ST_REP
# 1ST_RUR
# 1ST_USD
# 1ST_USDT
# 1ST_XMR
# 1ST_ZEC
# 2GIVE_BTC
# 2GIVE_DASH
# 2GIVE_DOGE
# 2GIVE_ETC
# 2GIVE_ETH
# 2GIVE_EUR
# 2GIVE_LTC
# 2GIVE_NXT
# 2GIVE_POSW
# 2GIVE_REP
# 2GIVE_RUR
# 2GIVE_USD
# 2GIVE_USDT
# 2GIVE_XMR
# 2GIVE_ZEC
# 8BIT_BTC
# 8BIT_DASH
# 8BIT_DOGE
# 8BIT_ETC
# 8BIT_ETH
# 8BIT_EUR
# 8BIT_LTC
# 8BIT_NXT
# 8BIT_POSW
# 8BIT_REP
# 8BIT_RUR
# 8BIT_USD
# 8BIT_USDT
# 8BIT_XMR
# 8BIT_ZEC
# ABY_BTC
# ABY_DASH
# ABY_DOGE
# ABY_ETC
# ABY_ETH
# ABY_EUR
# ABY_LTC
# ABY_NXT
# ABY_POSW
# ABY_REP
# ABY_RUR
# ABY_USD
# ABY_USDT
# ABY_XMR
# ABY_ZEC
# ACP_BTC
# ACP_DASH
# ACP_DOGE
# ACP_ETC
# ACP_ETH
# ACP_EUR
# ACP_LTC
# ACP_NXT
# ACP_POSW
# ACP_REP
# ACP_RUR
# ACP_USD
# ACP_USDT
# ACP_XMR
# ACP_ZEC
# ADCN_BTC
# ADCN_DASH
# ADCN_DOGE
# ADCN_ETC
# ADCN_ETH
# ADCN_EUR
# ADCN_LTC
# ADCN_NXT
# ADCN_POSW
# ADCN_REP
# ADCN_RUR
# ADCN_USD
# ADCN_USDT
# ADCN_XMR
# ADCN_ZEC
# ADZ_BTC
# ADZ_DASH
# ADZ_DOGE
# ADZ_ETC
# ADZ_ETH
# ADZ_EUR
# ADZ_LTC
# ADZ_NXT
# ADZ_POSW
# ADZ_REP
# ADZ_RUR
# ADZ_USD
# ADZ_USDT
# ADZ_XMR
# ADZ_ZEC
# AEON_BTC
# AEON_DASH
# AEON_DOGE
# AEON_ETC
# AEON_ETH
# AEON_EUR
# AEON_LTC
# AEON_NXT
# AEON_POSW
# AEON_REP
# AEON_RUR
# AEON_USD
# AEON_USDT
# AEON_XMR
# AEON_ZEC
# AIB_BTC
# AIB_DASH
# AIB_DOGE
# AIB_ETC
# AIB_ETH
# AIB_EUR
# AIB_LTC
# AIB_NXT
# AIB_POSW
# AIB_REP
# AIB_RUR
# AIB_USD
# AIB_USDT
# AIB_XMR
# AIB_ZEC
# AMP_BTC
# AMP_DASH
# AMP_DOGE
# AMP_ETC
# AMP_ETH
# AMP_EUR
# AMP_LTC
# AMP_NXT
# AMP_POSW
# AMP_REP
# AMP_RUR
# AMP_USD
# AMP_USDT
# AMP_XMR
# AMP_ZEC
# ARC_BTC
# ARC_DASH
# ARC_DOGE
# ARC_ETC
# ARC_ETH
# ARC_EUR
# ARC_LTC
# ARC_NXT
# ARC_POSW
# ARC_REP
# ARC_RUR
# ARC_USD
# ARC_USDT
# ARC_XMR
# ARC_ZEC
# ARDR_BTC
# ARDR_DASH
# ARDR_DOGE
# ARDR_ETC
# ARDR_ETH
# ARDR_EUR
# ARDR_LTC
# ARDR_NXT
# ARDR_POSW
# ARDR_REP
# ARDR_RUR
# ARDR_USD
# ARDR_USDT
# ARDR_XMR
# ARDR_ZEC
# AUR_BTC
# AUR_DASH
# AUR_DOGE
# AUR_ETC
# AUR_ETH
# AUR_EUR
# AUR_LTC
# AUR_NXT
# AUR_POSW
# AUR_REP
# AUR_RUR
# AUR_USD
# AUR_USDT
# AUR_XMR
# AUR_ZEC
# BASH_BTC
# BASH_DASH
# BASH_DOGE
# BASH_ETC
# BASH_ETH
# BASH_EUR
# BASH_LTC
# BASH_NXT
# BASH_POSW
# BASH_REP
# BASH_RUR
# BASH_USD
# BASH_USDT
# BASH_XMR
# BASH_ZEC
# BAY_BTC
# BAY_DASH
# BAY_DOGE
# BAY_ETC
# BAY_ETH
# BAY_EUR
# BAY_LTC
# BAY_NXT
# BAY_POSW
# BAY_REP
# BAY_RUR
# BAY_USD
# BAY_USDT
# BAY_XMR
# BAY_ZEC
# BCC_BTC
# BCC_DASH
# BCC_DOGE
# BCC_ETC
# BCC_ETH
# BCC_EUR
# BCC_LTC
# BCC_NXT
# BCC_POSW
# BCC_REP
# BCC_RUR
# BCC_USD
# BCC_USDT
# BCC_XMR
# BCC_ZEC
# BCN_BTC
# BCN_DASH
# BCN_DOGE
# BCN_ETC
# BCN_ETH
# BCN_EUR
# BCN_LTC
# BCN_NXT
# BCN_POSW
# BCN_REP
# BCN_RUR
# BCN_USD
# BCN_USDT
# BCN_XMR
# BCN_ZEC
# BCY_BTC
# BCY_DASH
# BCY_DOGE
# BCY_ETC
# BCY_ETH
# BCY_EUR
# BCY_LTC
# BCY_NXT
# BCY_POSW
# BCY_REP
# BCY_RUR
# BCY_USD
# BCY_USDT
# BCY_XMR
# BCY_ZEC
# BHC_BTC
# BHC_DASH
# BHC_DOGE
# BHC_ETC
# BHC_ETH
# BHC_EUR
# BHC_LTC
# BHC_NXT
# BHC_POSW
# BHC_REP
# BHC_RUR
# BHC_USD
# BHC_USDT
# BHC_XMR
# BHC_ZEC
# BIOS_BTC
# BIOS_DASH
# BIOS_DOGE
# BIOS_ETC
# BIOS_ETH
# BIOS_EUR
# BIOS_LTC
# BIOS_NXT
# BIOS_POSW
# BIOS_REP
# BIOS_RUR
# BIOS_USD
# BIOS_USDT
# BIOS_XMR
# BIOS_ZEC
# BIT_BTC
# BIT_DASH
# BIT_DOGE
# BIT_ETC
# BIT_ETH
# BIT_EUR
# BIT_LTC
# BIT_NXT
# BIT_POSW
# BIT_REP
# BIT_RUR
# BIT_USD
# BIT_USDT
# BIT_XMR
# BIT_ZEC
# BITB_BTC
# BITB_DASH
# BITB_DOGE
# BITB_ETC
# BITB_ETH
# BITB_EUR
# BITB_LTC
# BITB_NXT
# BITB_POSW
# BITB_REP
# BITB_RUR
# BITB_USD
# BITB_USDT
# BITB_XMR
# BITB_ZEC
# BLK_BTC
# BLK_DASH
# BLK_DOGE
# BLK_ETC
# BLK_ETH
# BLK_EUR
# BLK_LTC
# BLK_NXT
# BLK_POSW
# BLK_REP
# BLK_RUR
# BLK_USD
# BLK_USDT
# BLK_XMR
# BLK_ZEC
# BLU_BTC
# BLU_DASH
# BLU_DOGE
# BLU_ETC
# BLU_ETH
# BLU_EUR
# BLU_LTC
# BLU_NXT
# BLU_POSW
# BLU_REP
# BLU_RUR
# BLU_USD
# BLU_USDT
# BLU_XMR
# BLU_ZEC
# BPC_BTC
# BPC_DASH
# BPC_DOGE
# BPC_ETC
# BPC_ETH
# BPC_EUR
# BPC_LTC
# BPC_NXT
# BPC_POSW
# BPC_REP
# BPC_RUR
# BPC_USD
# BPC_USDT
# BPC_XMR
# BPC_ZEC
# BSD_BTC
# BSD_DASH
# BSD_DOGE
# BSD_ETC
# BSD_ETH
# BSD_EUR
# BSD_LTC
# BSD_NXT
# BSD_POSW
# BSD_REP
# BSD_RUR
# BSD_USD
# BSD_USDT
# BSD_XMR
# BSD_ZEC
# BTA_BTC
# BTA_DASH
# BTA_DOGE
# BTA_ETC
# BTA_ETH
# BTA_EUR
# BTA_LTC
# BTA_NXT
# BTA_POSW
# BTA_REP
# BTA_RUR
# BTA_USD
# BTA_USDT
# BTA_XMR
# BTA_ZEC
# BTC_1ST
# BTC_2GIVE
# BTC_8BIT
# BTC_ABY
# BTC_ACP
# BTC_ADCN
# BTC_ADZ
# BTC_AEON
# BTC_AIB
# BTC_AMP
# BTC_ARC
# BTC_ARDR
# BTC_AUR
# BTC_BASH
# BTC_BAY
# BTC_BCC
# BTC_BCN
# BTC_BCY
# BTC_BHC
# BTC_BIOS
# BTC_BIT
# BTC_BITB
# BTC_BLK
# BTC_BLU
# BTC_BPC
# BTC_BSD
# BTC_BTA
# BTC_BTC
# BTC_BTC
# BTC_BTCD
# BTC_BTS
# BTC_BURST
# BTC_CANN
# BTC_CCRB
# BTC_CJ
# BTC_CLAM
# BTC_CLOAK
# BTC_CLUB
# BTC_CNT
# BTC_CPC
# BTC_CREVA
# BTC_CRW
# BTC_CURE
# BTC_DASH
# BTC_DASH
# BTC_DCR
# BTC_DCT
# BTC_DGB
# BTC_DGD
# BTC_DIME
# BTC_DOGE
# BTC_DOGE
# BTC_DRACO
# BTC_DRZ
# BTC_DSH
# BTC_ECN
# BTC_EGC
# BTC_EL
# BTC_ELE
# BTC_EMC
# BTC_EMC2
# BTC_ENT
# BTC_ETC
# BTC_ETC
# BTC_ETH
# BTC_ETH
# BTC_EUR
# BTC_EUR
# BTC_EXP
# BTC_FCT
# BTC_FJC
# BTC_FRST
# BTC_GAME
# BTC_GB
# BTC_GCR
# BTC_GEO
# BTC_GHS
# BTC_GLD
# BTC_GNO
# BTC_GNT
# BTC_GOLOS
# BTC_GRC
# BTC_GUP
# BTC_HCC
# BTC_HXX
# BTC_ICN
# BTC_INCNT
# BTC_INFX
# BTC_IOC
# BTC_ION
# BTC_IOP
# BTC_ISL
# BTC_ITI
# BTC_JWL
# BTC_KC
# BTC_LBC
# BTC_LEO
# BTC_LEPEN
# BTC_LSK
# BTC_LTC
# BTC_LTC
# BTC_LTCR
# BTC_LTS
# BTC_LUN
# BTC_LUNA
# BTC_MAID
# BTC_MLN
# BTC_MOIN
# BTC_MOJO
# BTC_MONA
# BTC_MSCN
# BTC_MUE
# BTC_NAUT
# BTC_NAV
# BTC_NLG
# BTC_NMC
# BTC_NOTE
# BTC_NVC
# BTC_NXC
# BTC_NXT
# BTC_NXT
# BTC_OD
# BTC_OK
# BTC_OMNI
# BTC_OTX
# BTC_PINK
# BTC_PIVX
# BTC_PKB
# BTC_POST
# BTC_POSW
# BTC_POSW
# BTC_PPC
# BTC_PRES
# BTC_PROC
# BTC_PSB
# BTC_RADS
# BTC_RBIES
# BTC_RDD
# BTC_REE
# BTC_REP
# BTC_REP
# BTC_RIDE
# BTC_RISE
# BTC_RLC
# BTC_ROYAL
# BTC_RUB
# BTC_RUR
# BTC_RUR
# BTC_SBD
# BTC_SC
# BTC_SHIFT
# BTC_SIB
# BTC_SLR
# BTC_SLS
# BTC_SNGLS
# BTC_SNRG
# BTC_SOAR
# BTC_SONG
# BTC_SPR
# BTC_START
# BTC_STEEM
# BTC_STRAT
# BTC_SWT
# BTC_SXC
# BTC_SYNX
# BTC_SYS
# BTC_TAAS
# BTC_TIME
# BTC_TKN
# BTC_TLE
# BTC_TRST
# BTC_TRUMP
# BTC_TSE
# BTC_TX
# BTC_U
# BTC_UNC
# BTC_UNO
# BTC_UNY
# BTC_USD
# BTC_USD
# BTC_USDT
# BTC_USDT
# BTC_VEC2
# BTC_VIA
# BTC_VOX
# BTC_VRC
# BTC_VRM
# BTC_VRS
# BTC_VTC
# BTC_WAVES
# BTC_WINGS
# BTC_XAUR
# BTC_XBY
# BTC_XDN
# BTC_XEM
# BTC_XHI
# BTC_XLM
# BTC_XMR
# BTC_XMR
# BTC_XMS
# BTC_XRP
# BTC_XSPEC
# BTC_XTO
# BTC_XVC
# BTC_XVG
# BTC_YOC
# BTC_ZCL
# BTC_ZEC
# BTC_ZEC
# BTC_ZENI
# BTCD_BTC
# BTCD_DASH
# BTCD_DOGE
# BTCD_ETC
# BTCD_ETH
# BTCD_EUR
# BTCD_LTC
# BTCD_NXT
# BTCD_POSW
# BTCD_REP
# BTCD_RUR
# BTCD_USD
# BTCD_USDT
# BTCD_XMR
# BTCD_ZEC
# BTS_BTC
# BTS_DASH
# BTS_DOGE
# BTS_ETC
# BTS_ETH
# BTS_EUR
# BTS_LTC
# BTS_NXT
# BTS_POSW
# BTS_REP
# BTS_RUR
# BTS_USD
# BTS_USDT
# BTS_XMR
# BTS_ZEC
# BURST_BTC
# BURST_DASH
# BURST_DOGE
# BURST_ETC
# BURST_ETH
# BURST_EUR
# BURST_LTC
# BURST_NXT
# BURST_POSW
# BURST_REP
# BURST_RUR
# BURST_USD
# BURST_USDT
# BURST_XMR
# BURST_ZEC
# CANN_BTC
# CANN_DASH
# CANN_DOGE
# CANN_ETC
# CANN_ETH
# CANN_EUR
# CANN_LTC
# CANN_NXT
# CANN_POSW
# CANN_REP
# CANN_RUR
# CANN_USD
# CANN_USDT
# CANN_XMR
# CANN_ZEC
# CCRB_BTC
# CCRB_DASH
# CCRB_DOGE
# CCRB_ETC
# CCRB_ETH
# CCRB_EUR
# CCRB_LTC
# CCRB_NXT
# CCRB_POSW
# CCRB_REP
# CCRB_RUR
# CCRB_USD
# CCRB_USDT
# CCRB_XMR
# CCRB_ZEC
# CJ_BTC
# CJ_DASH
# CJ_DOGE
# CJ_ETC
# CJ_ETH
# CJ_EUR
# CJ_LTC
# CJ_NXT
# CJ_POSW
# CJ_REP
# CJ_RUR
# CJ_USD
# CJ_USDT
# CJ_XMR
# CJ_ZEC
# CLAM_BTC
# CLAM_DASH
# CLAM_DOGE
# CLAM_ETC
# CLAM_ETH
# CLAM_EUR
# CLAM_LTC
# CLAM_NXT
# CLAM_POSW
# CLAM_REP
# CLAM_RUR
# CLAM_USD
# CLAM_USDT
# CLAM_XMR
# CLAM_ZEC
# CLOAK_BTC
# CLOAK_DASH
# CLOAK_DOGE
# CLOAK_ETC
# CLOAK_ETH
# CLOAK_EUR
# CLOAK_LTC
# CLOAK_NXT
# CLOAK_POSW
# CLOAK_REP
# CLOAK_RUR
# CLOAK_USD
# CLOAK_USDT
# CLOAK_XMR
# CLOAK_ZEC
# CLUB_BTC
# CLUB_DASH
# CLUB_DOGE
# CLUB_ETC
# CLUB_ETH
# CLUB_EUR
# CLUB_LTC
# CLUB_NXT
# CLUB_POSW
# CLUB_REP
# CLUB_RUR
# CLUB_USD
# CLUB_USDT
# CLUB_XMR
# CLUB_ZEC
# CNT_BTC
# CNT_DASH
# CNT_DOGE
# CNT_ETC
# CNT_ETH
# CNT_EUR
# CNT_LTC
# CNT_NXT
# CNT_POSW
# CNT_REP
# CNT_RUR
# CNT_USD
# CNT_USDT
# CNT_XMR
# CNT_ZEC
# CPC_BTC
# CPC_DASH
# CPC_DOGE
# CPC_ETC
# CPC_ETH
# CPC_EUR
# CPC_LTC
# CPC_NXT
# CPC_POSW
# CPC_REP
# CPC_RUR
# CPC_USD
# CPC_USDT
# CPC_XMR
# CPC_ZEC
# CREVA_BTC
# CREVA_DASH
# CREVA_DOGE
# CREVA_ETC
# CREVA_ETH
# CREVA_EUR
# CREVA_LTC
# CREVA_NXT
# CREVA_POSW
# CREVA_REP
# CREVA_RUR
# CREVA_USD
# CREVA_USDT
# CREVA_XMR
# CREVA_ZEC
# CRW_BTC
# CRW_DASH
# CRW_DOGE
# CRW_ETC
# CRW_ETH
# CRW_EUR
# CRW_LTC
# CRW_NXT
# CRW_POSW
# CRW_REP
# CRW_RUR
# CRW_USD
# CRW_USDT
# CRW_XMR
# CRW_ZEC
# CURE_BTC
# CURE_DASH
# CURE_DOGE
# CURE_ETC
# CURE_ETH
# CURE_EUR
# CURE_LTC
# CURE_NXT
# CURE_POSW
# CURE_REP
# CURE_RUR
# CURE_USD
# CURE_USDT
# CURE_XMR
# CURE_ZEC
# DASH_1ST
# DASH_2GIVE
# DASH_8BIT
# DASH_ABY
# DASH_ACP
# DASH_ADCN
# DASH_ADZ
# DASH_AEON
# DASH_AIB
# DASH_AMP
# DASH_ARC
# DASH_ARDR
# DASH_AUR
# DASH_BASH
# DASH_BAY
# DASH_BCC
# DASH_BCN
# DASH_BCY
# DASH_BHC
# DASH_BIOS
# DASH_BIT
# DASH_BITB
# DASH_BLK
# DASH_BLU
# DASH_BPC
# DASH_BSD
# DASH_BTA
# DASH_BTC
# DASH_BTC
# DASH_BTCD
# DASH_BTS
# DASH_BURST
# DASH_CANN
# DASH_CCRB
# DASH_CJ
# DASH_CLAM
# DASH_CLOAK
# DASH_CLUB
# DASH_CNT
# DASH_CPC
# DASH_CREVA
# DASH_CRW
# DASH_CURE
# DASH_DASH
# DASH_DASH
# DASH_DCR
# DASH_DCT
# DASH_DGB
# DASH_DGD
# DASH_DIME
# DASH_DOGE
# DASH_DOGE
# DASH_DRACO
# DASH_DRZ
# DASH_DSH
# DASH_ECN
# DASH_EGC
# DASH_EL
# DASH_ELE
# DASH_EMC
# DASH_EMC2
# DASH_ENT
# DASH_ETC
# DASH_ETC
# DASH_ETH
# DASH_ETH
# DASH_EUR
# DASH_EUR
# DASH_EXP
# DASH_FCT
# DASH_FJC
# DASH_FRST
# DASH_GAME
# DASH_GB
# DASH_GCR
# DASH_GEO
# DASH_GHS
# DASH_GLD
# DASH_GNO
# DASH_GNT
# DASH_GOLOS
# DASH_GRC
# DASH_GUP
# DASH_HCC
# DASH_HXX
# DASH_ICN
# DASH_INCNT
# DASH_INFX
# DASH_IOC
# DASH_ION
# DASH_IOP
# DASH_ISL
# DASH_ITI
# DASH_JWL
# DASH_KC
# DASH_LBC
# DASH_LEO
# DASH_LEPEN
# DASH_LSK
# DASH_LTC
# DASH_LTC
# DASH_LTCR
# DASH_LTS
# DASH_LUN
# DASH_LUNA
# DASH_MAID
# DASH_MLN
# DASH_MOIN
# DASH_MOJO
# DASH_MONA
# DASH_MSCN
# DASH_MUE
# DASH_NAUT
# DASH_NAV
# DASH_NLG
# DASH_NMC
# DASH_NOTE
# DASH_NVC
# DASH_NXC
# DASH_NXT
# DASH_NXT
# DASH_OD
# DASH_OK
# DASH_OMNI
# DASH_OTX
# DASH_PINK
# DASH_PIVX
# DASH_PKB
# DASH_POST
# DASH_POSW
# DASH_POSW
# DASH_PPC
# DASH_PRES
# DASH_PROC
# DASH_PSB
# DASH_RADS
# DASH_RBIES
# DASH_RDD
# DASH_REE
# DASH_REP
# DASH_REP
# DASH_RIDE
# DASH_RISE
# DASH_RLC
# DASH_ROYAL
# DASH_RUB
# DASH_RUR
# DASH_RUR
# DASH_SBD
# DASH_SC
# DASH_SHIFT
# DASH_SIB
# DASH_SLR
# DASH_SLS
# DASH_SNGLS
# DASH_SNRG
# DASH_SOAR
# DASH_SONG
# DASH_SPR
# DASH_START
# DASH_STEEM
# DASH_STRAT
# DASH_SWT
# DASH_SXC
# DASH_SYNX
# DASH_SYS
# DASH_TAAS
# DASH_TIME
# DASH_TKN
# DASH_TLE
# DASH_TRST
# DASH_TRUMP
# DASH_TSE
# DASH_TX
# DASH_U
# DASH_UNC
# DASH_UNO
# DASH_UNY
# DASH_USD
# DASH_USD
# DASH_USDT
# DASH_USDT
# DASH_VEC2
# DASH_VIA
# DASH_VOX
# DASH_VRC
# DASH_VRM
# DASH_VRS
# DASH_VTC
# DASH_WAVES
# DASH_WINGS
# DASH_XAUR
# DASH_XBY
# DASH_XDN
# DASH_XEM
# DASH_XHI
# DASH_XLM
# DASH_XMR
# DASH_XMR
# DASH_XMS
# DASH_XRP
# DASH_XSPEC
# DASH_XTO
# DASH_XVC
# DASH_XVG
# DASH_YOC
# DASH_ZCL
# DASH_ZEC
# DASH_ZEC
# DASH_ZENI
# DCR_BTC
# DCR_DASH
# DCR_DOGE
# DCR_ETC
# DCR_ETH
# DCR_EUR
# DCR_LTC
# DCR_NXT
# DCR_POSW
# DCR_REP
# DCR_RUR
# DCR_USD
# DCR_USDT
# DCR_XMR
# DCR_ZEC
# DCT_BTC
# DCT_DASH
# DCT_DOGE
# DCT_ETC
# DCT_ETH
# DCT_EUR
# DCT_LTC
# DCT_NXT
# DCT_POSW
# DCT_REP
# DCT_RUR
# DCT_USD
# DCT_USDT
# DCT_XMR
# DCT_ZEC
# DGB_BTC
# DGB_DASH
# DGB_DOGE
# DGB_ETC
# DGB_ETH
# DGB_EUR
# DGB_LTC
# DGB_NXT
# DGB_POSW
# DGB_REP
# DGB_RUR
# DGB_USD
# DGB_USDT
# DGB_XMR
# DGB_ZEC
# DGD_BTC
# DGD_DASH
# DGD_DOGE
# DGD_ETC
# DGD_ETH
# DGD_EUR
# DGD_LTC
# DGD_NXT
# DGD_POSW
# DGD_REP
# DGD_RUR
# DGD_USD
# DGD_USDT
# DGD_XMR
# DGD_ZEC
# DIME_BTC
# DIME_DASH
# DIME_DOGE
# DIME_ETC
# DIME_ETH
# DIME_EUR
# DIME_LTC
# DIME_NXT
# DIME_POSW
# DIME_REP
# DIME_RUR
# DIME_USD
# DIME_USDT
# DIME_XMR
# DIME_ZEC
# DOGE_1ST
# DOGE_2GIVE
# DOGE_8BIT
# DOGE_ABY
# DOGE_ACP
# DOGE_ADCN
# DOGE_ADZ
# DOGE_AEON
# DOGE_AIB
# DOGE_AMP
# DOGE_ARC
# DOGE_ARDR
# DOGE_AUR
# DOGE_BASH
# DOGE_BAY
# DOGE_BCC
# DOGE_BCN
# DOGE_BCY
# DOGE_BHC
# DOGE_BIOS
# DOGE_BIT
# DOGE_BITB
# DOGE_BLK
# DOGE_BLU
# DOGE_BPC
# DOGE_BSD
# DOGE_BTA
# DOGE_BTC
# DOGE_BTC
# DOGE_BTCD
# DOGE_BTS
# DOGE_BURST
# DOGE_CANN
# DOGE_CCRB
# DOGE_CJ
# DOGE_CLAM
# DOGE_CLOAK
# DOGE_CLUB
# DOGE_CNT
# DOGE_CPC
# DOGE_CREVA
# DOGE_CRW
# DOGE_CURE
# DOGE_DASH
# DOGE_DASH
# DOGE_DCR
# DOGE_DCT
# DOGE_DGB
# DOGE_DGD
# DOGE_DIME
# DOGE_DOGE
# DOGE_DOGE
# DOGE_DRACO
# DOGE_DRZ
# DOGE_DSH
# DOGE_ECN
# DOGE_EGC
# DOGE_EL
# DOGE_ELE
# DOGE_EMC
# DOGE_EMC2
# DOGE_ENT
# DOGE_ETC
# DOGE_ETC
# DOGE_ETH
# DOGE_ETH
# DOGE_EUR
# DOGE_EUR
# DOGE_EXP
# DOGE_FCT
# DOGE_FJC
# DOGE_FRST
# DOGE_GAME
# DOGE_GB
# DOGE_GCR
# DOGE_GEO
# DOGE_GHS
# DOGE_GLD
# DOGE_GNO
# DOGE_GNT
# DOGE_GOLOS
# DOGE_GRC
# DOGE_GUP
# DOGE_HCC
# DOGE_HXX
# DOGE_ICN
# DOGE_INCNT
# DOGE_INFX
# DOGE_IOC
# DOGE_ION
# DOGE_IOP
# DOGE_ISL
# DOGE_ITI
# DOGE_JWL
# DOGE_KC
# DOGE_LBC
# DOGE_LEO
# DOGE_LEPEN
# DOGE_LSK
# DOGE_LTC
# DOGE_LTC
# DOGE_LTCR
# DOGE_LTS
# DOGE_LUN
# DOGE_LUNA
# DOGE_MAID
# DOGE_MLN
# DOGE_MOIN
# DOGE_MOJO
# DOGE_MONA
# DOGE_MSCN
# DOGE_MUE
# DOGE_NAUT
# DOGE_NAV
# DOGE_NLG
# DOGE_NMC
# DOGE_NOTE
# DOGE_NVC
# DOGE_NXC
# DOGE_NXT
# DOGE_NXT
# DOGE_OD
# DOGE_OK
# DOGE_OMNI
# DOGE_OTX
# DOGE_PINK
# DOGE_PIVX
# DOGE_PKB
# DOGE_POST
# DOGE_POSW
# DOGE_POSW
# DOGE_PPC
# DOGE_PRES
# DOGE_PROC
# DOGE_PSB
# DOGE_RADS
# DOGE_RBIES
# DOGE_RDD
# DOGE_REE
# DOGE_REP
# DOGE_REP
# DOGE_RIDE
# DOGE_RISE
# DOGE_RLC
# DOGE_ROYAL
# DOGE_RUB
# DOGE_RUR
# DOGE_RUR
# DOGE_SBD
# DOGE_SC
# DOGE_SHIFT
# DOGE_SIB
# DOGE_SLR
# DOGE_SLS
# DOGE_SNGLS
# DOGE_SNRG
# DOGE_SOAR
# DOGE_SONG
# DOGE_SPR
# DOGE_START
# DOGE_STEEM
# DOGE_STRAT
# DOGE_SWT
# DOGE_SXC
# DOGE_SYNX
# DOGE_SYS
# DOGE_TAAS
# DOGE_TIME
# DOGE_TKN
# DOGE_TLE
# DOGE_TRST
# DOGE_TRUMP
# DOGE_TSE
# DOGE_TX
# DOGE_U
# DOGE_UNC
# DOGE_UNO
# DOGE_UNY
# DOGE_USD
# DOGE_USD
# DOGE_USDT
# DOGE_USDT
# DOGE_VEC2
# DOGE_VIA
# DOGE_VOX
# DOGE_VRC
# DOGE_VRM
# DOGE_VRS
# DOGE_VTC
# DOGE_WAVES
# DOGE_WINGS
# DOGE_XAUR
# DOGE_XBY
# DOGE_XDN
# DOGE_XEM
# DOGE_XHI
# DOGE_XLM
# DOGE_XMR
# DOGE_XMR
# DOGE_XMS
# DOGE_XRP
# DOGE_XSPEC
# DOGE_XTO
# DOGE_XVC
# DOGE_XVG
# DOGE_YOC
# DOGE_ZCL
# DOGE_ZEC
# DOGE_ZEC
# DOGE_ZENI
# DRACO_BTC
# DRACO_DASH
# DRACO_DOGE
# DRACO_ETC
# DRACO_ETH
# DRACO_EUR
# DRACO_LTC
# DRACO_NXT
# DRACO_POSW
# DRACO_REP
# DRACO_RUR
# DRACO_USD
# DRACO_USDT
# DRACO_XMR
# DRACO_ZEC
# DRZ_BTC
# DRZ_DASH
# DRZ_DOGE
# DRZ_ETC
# DRZ_ETH
# DRZ_EUR
# DRZ_LTC
# DRZ_NXT
# DRZ_POSW
# DRZ_REP
# DRZ_RUR
# DRZ_USD
# DRZ_USDT
# DRZ_XMR
# DRZ_ZEC
# DSH_BTC
# DSH_DASH
# DSH_DOGE
# DSH_ETC
# DSH_ETH
# DSH_EUR
# DSH_LTC
# DSH_NXT
# DSH_POSW
# DSH_REP
# DSH_RUR
# DSH_USD
# DSH_USDT
# DSH_XMR
# DSH_ZEC
# ECN_BTC
# ECN_DASH
# ECN_DOGE
# ECN_ETC
# ECN_ETH
# ECN_EUR
# ECN_LTC
# ECN_NXT
# ECN_POSW
# ECN_REP
# ECN_RUR
# ECN_USD
# ECN_USDT
# ECN_XMR
# ECN_ZEC
# EGC_BTC
# EGC_DASH
# EGC_DOGE
# EGC_ETC
# EGC_ETH
# EGC_EUR
# EGC_LTC
# EGC_NXT
# EGC_POSW
# EGC_REP
# EGC_RUR
# EGC_USD
# EGC_USDT
# EGC_XMR
# EGC_ZEC
# EL_BTC
# EL_DASH
# EL_DOGE
# EL_ETC
# EL_ETH
# EL_EUR
# EL_LTC
# EL_NXT
# EL_POSW
# EL_REP
# EL_RUR
# EL_USD
# EL_USDT
# EL_XMR
# EL_ZEC
# ELE_BTC
# ELE_DASH
# ELE_DOGE
# ELE_ETC
# ELE_ETH
# ELE_EUR
# ELE_LTC
# ELE_NXT
# ELE_POSW
# ELE_REP
# ELE_RUR
# ELE_USD
# ELE_USDT
# ELE_XMR
# ELE_ZEC
# EMC_BTC
# EMC_DASH
# EMC_DOGE
# EMC_ETC
# EMC_ETH
# EMC_EUR
# EMC_LTC
# EMC_NXT
# EMC_POSW
# EMC_REP
# EMC_RUR
# EMC_USD
# EMC_USDT
# EMC_XMR
# EMC_ZEC
# EMC2_BTC
# EMC2_DASH
# EMC2_DOGE
# EMC2_ETC
# EMC2_ETH
# EMC2_EUR
# EMC2_LTC
# EMC2_NXT
# EMC2_POSW
# EMC2_REP
# EMC2_RUR
# EMC2_USD
# EMC2_USDT
# EMC2_XMR
# EMC2_ZEC
# ENT_BTC
# ENT_DASH
# ENT_DOGE
# ENT_ETC
# ENT_ETH
# ENT_EUR
# ENT_LTC
# ENT_NXT
# ENT_POSW
# ENT_REP
# ENT_RUR
# ENT_USD
# ENT_USDT
# ENT_XMR
# ENT_ZEC
# ETC_1ST
# ETC_2GIVE
# ETC_8BIT
# ETC_ABY
# ETC_ACP
# ETC_ADCN
# ETC_ADZ
# ETC_AEON
# ETC_AIB
# ETC_AMP
# ETC_ARC
# ETC_ARDR
# ETC_AUR
# ETC_BASH
# ETC_BAY
# ETC_BCC
# ETC_BCN
# ETC_BCY
# ETC_BHC
# ETC_BIOS
# ETC_BIT
# ETC_BITB
# ETC_BLK
# ETC_BLU
# ETC_BPC
# ETC_BSD
# ETC_BTA
# ETC_BTC
# ETC_BTC
# ETC_BTCD
# ETC_BTS
# ETC_BURST
# ETC_CANN
# ETC_CCRB
# ETC_CJ
# ETC_CLAM
# ETC_CLOAK
# ETC_CLUB
# ETC_CNT
# ETC_CPC
# ETC_CREVA
# ETC_CRW
# ETC_CURE
# ETC_DASH
# ETC_DASH
# ETC_DCR
# ETC_DCT
# ETC_DGB
# ETC_DGD
# ETC_DIME
# ETC_DOGE
# ETC_DOGE
# ETC_DRACO
# ETC_DRZ
# ETC_DSH
# ETC_ECN
# ETC_EGC
# ETC_EL
# ETC_ELE
# ETC_EMC
# ETC_EMC2
# ETC_ENT
# ETC_ETC
# ETC_ETC
# ETC_ETH
# ETC_ETH
# ETC_EUR
# ETC_EUR
# ETC_EXP
# ETC_FCT
# ETC_FJC
# ETC_FRST
# ETC_GAME
# ETC_GB
# ETC_GCR
# ETC_GEO
# ETC_GHS
# ETC_GLD
# ETC_GNO
# ETC_GNT
# ETC_GOLOS
# ETC_GRC
# ETC_GUP
# ETC_HCC
# ETC_HXX
# ETC_ICN
# ETC_INCNT
# ETC_INFX
# ETC_IOC
# ETC_ION
# ETC_IOP
# ETC_ISL
# ETC_ITI
# ETC_JWL
# ETC_KC
# ETC_LBC
# ETC_LEO
# ETC_LEPEN
# ETC_LSK
# ETC_LTC
# ETC_LTC
# ETC_LTCR
# ETC_LTS
# ETC_LUN
# ETC_LUNA
# ETC_MAID
# ETC_MLN
# ETC_MOIN
# ETC_MOJO
# ETC_MONA
# ETC_MSCN
# ETC_MUE
# ETC_NAUT
# ETC_NAV
# ETC_NLG
# ETC_NMC
# ETC_NOTE
# ETC_NVC
# ETC_NXC
# ETC_NXT
# ETC_NXT
# ETC_OD
# ETC_OK
# ETC_OMNI
# ETC_OTX
# ETC_PINK
# ETC_PIVX
# ETC_PKB
# ETC_POST
# ETC_POSW
# ETC_POSW
# ETC_PPC
# ETC_PRES
# ETC_PROC
# ETC_PSB
# ETC_RADS
# ETC_RBIES
# ETC_RDD
# ETC_REE
# ETC_REP
# ETC_REP
# ETC_RIDE
# ETC_RISE
# ETC_RLC
# ETC_ROYAL
# ETC_RUB
# ETC_RUR
# ETC_RUR
# ETC_SBD
# ETC_SC
# ETC_SHIFT
# ETC_SIB
# ETC_SLR
# ETC_SLS
# ETC_SNGLS
# ETC_SNRG
# ETC_SOAR
# ETC_SONG
# ETC_SPR
# ETC_START
# ETC_STEEM
# ETC_STRAT
# ETC_SWT
# ETC_SXC
# ETC_SYNX
# ETC_SYS
# ETC_TAAS
# ETC_TIME
# ETC_TKN
# ETC_TLE
# ETC_TRST
# ETC_TRUMP
# ETC_TSE
# ETC_TX
# ETC_U
# ETC_UNC
# ETC_UNO
# ETC_UNY
# ETC_USD
# ETC_USD
# ETC_USDT
# ETC_USDT
# ETC_VEC2
# ETC_VIA
# ETC_VOX
# ETC_VRC
# ETC_VRM
# ETC_VRS
# ETC_VTC
# ETC_WAVES
# ETC_WINGS
# ETC_XAUR
# ETC_XBY
# ETC_XDN
# ETC_XEM
# ETC_XHI
# ETC_XLM
# ETC_XMR
# ETC_XMR
# ETC_XMS
# ETC_XRP
# ETC_XSPEC
# ETC_XTO
# ETC_XVC
# ETC_XVG
# ETC_YOC
# ETC_ZCL
# ETC_ZEC
# ETC_ZEC
# ETC_ZENI
# ETH_1ST
# ETH_2GIVE
# ETH_8BIT
# ETH_ABY
# ETH_ACP
# ETH_ADCN
# ETH_ADZ
# ETH_AEON
# ETH_AIB
# ETH_AMP
# ETH_ARC
# ETH_ARDR
# ETH_AUR
# ETH_BASH
# ETH_BAY
# ETH_BCC
# ETH_BCN
# ETH_BCY
# ETH_BHC
# ETH_BIOS
# ETH_BIT
# ETH_BITB
# ETH_BLK
# ETH_BLU
# ETH_BPC
# ETH_BSD
# ETH_BTA
# ETH_BTC
# ETH_BTC
# ETH_BTCD
# ETH_BTS
# ETH_BURST
# ETH_CANN
# ETH_CCRB
# ETH_CJ
# ETH_CLAM
# ETH_CLOAK
# ETH_CLUB
# ETH_CNT
# ETH_CPC
# ETH_CREVA
# ETH_CRW
# ETH_CURE
# ETH_DASH
# ETH_DASH
# ETH_DCR
# ETH_DCT
# ETH_DGB
# ETH_DGD
# ETH_DIME
# ETH_DOGE
# ETH_DOGE
# ETH_DRACO
# ETH_DRZ
# ETH_DSH
# ETH_ECN
# ETH_EGC
# ETH_EL
# ETH_ELE
# ETH_EMC
# ETH_EMC2
# ETH_ENT
# ETH_ETC
# ETH_ETC
# ETH_ETH
# ETH_ETH
# ETH_EUR
# ETH_EUR
# ETH_EXP
# ETH_FCT
# ETH_FJC
# ETH_FRST
# ETH_GAME
# ETH_GB
# ETH_GCR
# ETH_GEO
# ETH_GHS
# ETH_GLD
# ETH_GNO
# ETH_GNT
# ETH_GOLOS
# ETH_GRC
# ETH_GUP
# ETH_HCC
# ETH_HXX
# ETH_ICN
# ETH_INCNT
# ETH_INFX
# ETH_IOC
# ETH_ION
# ETH_IOP
# ETH_ISL
# ETH_ITI
# ETH_JWL
# ETH_KC
# ETH_LBC
# ETH_LEO
# ETH_LEPEN
# ETH_LSK
# ETH_LTC
# ETH_LTC
# ETH_LTCR
# ETH_LTS
# ETH_LUN
# ETH_LUNA
# ETH_MAID
# ETH_MLN
# ETH_MOIN
# ETH_MOJO
# ETH_MONA
# ETH_MSCN
# ETH_MUE
# ETH_NAUT
# ETH_NAV
# ETH_NLG
# ETH_NMC
# ETH_NOTE
# ETH_NVC
# ETH_NXC
# ETH_NXT
# ETH_NXT
# ETH_OD
# ETH_OK
# ETH_OMNI
# ETH_OTX
# ETH_PINK
# ETH_PIVX
# ETH_PKB
# ETH_POST
# ETH_POSW
# ETH_POSW
# ETH_PPC
# ETH_PRES
# ETH_PROC
# ETH_PSB
# ETH_RADS
# ETH_RBIES
# ETH_RDD
# ETH_REE
# ETH_REP
# ETH_REP
# ETH_RIDE
# ETH_RISE
# ETH_RLC
# ETH_ROYAL
# ETH_RUB
# ETH_RUR
# ETH_RUR
# ETH_SBD
# ETH_SC
# ETH_SHIFT
# ETH_SIB
# ETH_SLR
# ETH_SLS
# ETH_SNGLS
# ETH_SNRG
# ETH_SOAR
# ETH_SONG
# ETH_SPR
# ETH_START
# ETH_STEEM
# ETH_STRAT
# ETH_SWT
# ETH_SXC
# ETH_SYNX
# ETH_SYS
# ETH_TAAS
# ETH_TIME
# ETH_TKN
# ETH_TLE
# ETH_TRST
# ETH_TRUMP
# ETH_TSE
# ETH_TX
# ETH_U
# ETH_UNC
# ETH_UNO
# ETH_UNY
# ETH_USD
# ETH_USD
# ETH_USDT
# ETH_USDT
# ETH_VEC2
# ETH_VIA
# ETH_VOX
# ETH_VRC
# ETH_VRM
# ETH_VRS
# ETH_VTC
# ETH_WAVES
# ETH_WINGS
# ETH_XAUR
# ETH_XBY
# ETH_XDN
# ETH_XEM
# ETH_XHI
# ETH_XLM
# ETH_XMR
# ETH_XMR
# ETH_XMS
# ETH_XRP
# ETH_XSPEC
# ETH_XTO
# ETH_XVC
# ETH_XVG
# ETH_YOC
# ETH_ZCL
# ETH_ZEC
# ETH_ZEC
# ETH_ZENI
# EUR_1ST
# EUR_2GIVE
# EUR_8BIT
# EUR_ABY
# EUR_ACP
# EUR_ADCN
# EUR_ADZ
# EUR_AEON
# EUR_AIB
# EUR_AMP
# EUR_ARC
# EUR_ARDR
# EUR_AUR
# EUR_BASH
# EUR_BAY
# EUR_BCC
# EUR_BCN
# EUR_BCY
# EUR_BHC
# EUR_BIOS
# EUR_BIT
# EUR_BITB
# EUR_BLK
# EUR_BLU
# EUR_BPC
# EUR_BSD
# EUR_BTA
# EUR_BTC
# EUR_BTC
# EUR_BTCD
# EUR_BTS
# EUR_BURST
# EUR_CANN
# EUR_CCRB
# EUR_CJ
# EUR_CLAM
# EUR_CLOAK
# EUR_CLUB
# EUR_CNT
# EUR_CPC
# EUR_CREVA
# EUR_CRW
# EUR_CURE
# EUR_DASH
# EUR_DASH
# EUR_DCR
# EUR_DCT
# EUR_DGB
# EUR_DGD
# EUR_DIME
# EUR_DOGE
# EUR_DOGE
# EUR_DRACO
# EUR_DRZ
# EUR_DSH
# EUR_ECN
# EUR_EGC
# EUR_EL
# EUR_ELE
# EUR_EMC
# EUR_EMC2
# EUR_ENT
# EUR_ETC
# EUR_ETC
# EUR_ETH
# EUR_ETH
# EUR_EUR
# EUR_EUR
# EUR_EXP
# EUR_FCT
# EUR_FJC
# EUR_FRST
# EUR_GAME
# EUR_GB
# EUR_GCR
# EUR_GEO
# EUR_GHS
# EUR_GLD
# EUR_GNO
# EUR_GNT
# EUR_GOLOS
# EUR_GRC
# EUR_GUP
# EUR_HCC
# EUR_HXX
# EUR_ICN
# EUR_INCNT
# EUR_INFX
# EUR_IOC
# EUR_ION
# EUR_IOP
# EUR_ISL
# EUR_ITI
# EUR_JWL
# EUR_KC
# EUR_LBC
# EUR_LEO
# EUR_LEPEN
# EUR_LSK
# EUR_LTC
# EUR_LTC
# EUR_LTCR
# EUR_LTS
# EUR_LUN
# EUR_LUNA
# EUR_MAID
# EUR_MLN
# EUR_MOIN
# EUR_MOJO
# EUR_MONA
# EUR_MSCN
# EUR_MUE
# EUR_NAUT
# EUR_NAV
# EUR_NLG
# EUR_NMC
# EUR_NOTE
# EUR_NVC
# EUR_NXC
# EUR_NXT
# EUR_NXT
# EUR_OD
# EUR_OK
# EUR_OMNI
# EUR_OTX
# EUR_PINK
# EUR_PIVX
# EUR_PKB
# EUR_POST
# EUR_POSW
# EUR_POSW
# EUR_PPC
# EUR_PRES
# EUR_PROC
# EUR_PSB
# EUR_RADS
# EUR_RBIES
# EUR_RDD
# EUR_REE
# EUR_REP
# EUR_REP
# EUR_RIDE
# EUR_RISE
# EUR_RLC
# EUR_ROYAL
# EUR_RUB
# EUR_RUR
# EUR_RUR
# EUR_SBD
# EUR_SC
# EUR_SHIFT
# EUR_SIB
# EUR_SLR
# EUR_SLS
# EUR_SNGLS
# EUR_SNRG
# EUR_SOAR
# EUR_SONG
# EUR_SPR
# EUR_START
# EUR_STEEM
# EUR_STRAT
# EUR_SWT
# EUR_SXC
# EUR_SYNX
# EUR_SYS
# EUR_TAAS
# EUR_TIME
# EUR_TKN
# EUR_TLE
# EUR_TRST
# EUR_TRUMP
# EUR_TSE
# EUR_TX
# EUR_U
# EUR_UNC
# EUR_UNO
# EUR_UNY
# EUR_USD
# EUR_USD
# EUR_USDT
# EUR_USDT
# EUR_VEC2
# EUR_VIA
# EUR_VOX
# EUR_VRC
# EUR_VRM
# EUR_VRS
# EUR_VTC
# EUR_WAVES
# EUR_WINGS
# EUR_XAUR
# EUR_XBY
# EUR_XDN
# EUR_XEM
# EUR_XHI
# EUR_XLM
# EUR_XMR
# EUR_XMR
# EUR_XMS
# EUR_XRP
# EUR_XSPEC
# EUR_XTO
# EUR_XVC
# EUR_XVG
# EUR_YOC
# EUR_ZCL
# EUR_ZEC
# EUR_ZEC
# EUR_ZENI
# EXP_BTC
# EXP_DASH
# EXP_DOGE
# EXP_ETC
# EXP_ETH
# EXP_EUR
# EXP_LTC
# EXP_NXT
# EXP_POSW
# EXP_REP
# EXP_RUR
# EXP_USD
# EXP_USDT
# EXP_XMR
# EXP_ZEC
# FCT_BTC
# FCT_DASH
# FCT_DOGE
# FCT_ETC
# FCT_ETH
# FCT_EUR
# FCT_LTC
# FCT_NXT
# FCT_POSW
# FCT_REP
# FCT_RUR
# FCT_USD
# FCT_USDT
# FCT_XMR
# FCT_ZEC
# FJC_BTC
# FJC_DASH
# FJC_DOGE
# FJC_ETC
# FJC_ETH
# FJC_EUR
# FJC_LTC
# FJC_NXT
# FJC_POSW
# FJC_REP
# FJC_RUR
# FJC_USD
# FJC_USDT
# FJC_XMR
# FJC_ZEC
# FRST_BTC
# FRST_DASH
# FRST_DOGE
# FRST_ETC
# FRST_ETH
# FRST_EUR
# FRST_LTC
# FRST_NXT
# FRST_POSW
# FRST_REP
# FRST_RUR
# FRST_USD
# FRST_USDT
# FRST_XMR
# FRST_ZEC
# GAME_BTC
# GAME_DASH
# GAME_DOGE
# GAME_ETC
# GAME_ETH
# GAME_EUR
# GAME_LTC
# GAME_NXT
# GAME_POSW
# GAME_REP
# GAME_RUR
# GAME_USD
# GAME_USDT
# GAME_XMR
# GAME_ZEC
# GB_BTC
# GB_DASH
# GB_DOGE
# GB_ETC
# GB_ETH
# GB_EUR
# GB_LTC
# GB_NXT
# GB_POSW
# GB_REP
# GB_RUR
# GB_USD
# GB_USDT
# GB_XMR
# GB_ZEC
# GCR_BTC
# GCR_DASH
# GCR_DOGE
# GCR_ETC
# GCR_ETH
# GCR_EUR
# GCR_LTC
# GCR_NXT
# GCR_POSW
# GCR_REP
# GCR_RUR
# GCR_USD
# GCR_USDT
# GCR_XMR
# GCR_ZEC
# GEO_BTC
# GEO_DASH
# GEO_DOGE
# GEO_ETC
# GEO_ETH
# GEO_EUR
# GEO_LTC
# GEO_NXT
# GEO_POSW
# GEO_REP
# GEO_RUR
# GEO_USD
# GEO_USDT
# GEO_XMR
# GEO_ZEC
# GHS_BTC
# GHS_DASH
# GHS_DOGE
# GHS_ETC
# GHS_ETH
# GHS_EUR
# GHS_LTC
# GHS_NXT
# GHS_POSW
# GHS_REP
# GHS_RUR
# GHS_USD
# GHS_USDT
# GHS_XMR
# GHS_ZEC
# GLD_BTC
# GLD_DASH
# GLD_DOGE
# GLD_ETC
# GLD_ETH
# GLD_EUR
# GLD_LTC
# GLD_NXT
# GLD_POSW
# GLD_REP
# GLD_RUR
# GLD_USD
# GLD_USDT
# GLD_XMR
# GLD_ZEC
# GNO_BTC
# GNO_DASH
# GNO_DOGE
# GNO_ETC
# GNO_ETH
# GNO_EUR
# GNO_LTC
# GNO_NXT
# GNO_POSW
# GNO_REP
# GNO_RUR
# GNO_USD
# GNO_USDT
# GNO_XMR
# GNO_ZEC
# GNT_BTC
# GNT_DASH
# GNT_DOGE
# GNT_ETC
# GNT_ETH
# GNT_EUR
# GNT_LTC
# GNT_NXT
# GNT_POSW
# GNT_REP
# GNT_RUR
# GNT_USD
# GNT_USDT
# GNT_XMR
# GNT_ZEC
# GOLOS_BTC
# GOLOS_DASH
# GOLOS_DOGE
# GOLOS_ETC
# GOLOS_ETH
# GOLOS_EUR
# GOLOS_LTC
# GOLOS_NXT
# GOLOS_POSW
# GOLOS_REP
# GOLOS_RUR
# GOLOS_USD
# GOLOS_USDT
# GOLOS_XMR
# GOLOS_ZEC
# GRC_BTC
# GRC_DASH
# GRC_DOGE
# GRC_ETC
# GRC_ETH
# GRC_EUR
# GRC_LTC
# GRC_NXT
# GRC_POSW
# GRC_REP
# GRC_RUR
# GRC_USD
# GRC_USDT
# GRC_XMR
# GRC_ZEC
# GUP_BTC
# GUP_DASH
# GUP_DOGE
# GUP_ETC
# GUP_ETH
# GUP_EUR
# GUP_LTC
# GUP_NXT
# GUP_POSW
# GUP_REP
# GUP_RUR
# GUP_USD
# GUP_USDT
# GUP_XMR
# GUP_ZEC
# HCC_BTC
# HCC_DASH
# HCC_DOGE
# HCC_ETC
# HCC_ETH
# HCC_EUR
# HCC_LTC
# HCC_NXT
# HCC_POSW
# HCC_REP
# HCC_RUR
# HCC_USD
# HCC_USDT
# HCC_XMR
# HCC_ZEC
# HXX_BTC
# HXX_DASH
# HXX_DOGE
# HXX_ETC
# HXX_ETH
# HXX_EUR
# HXX_LTC
# HXX_NXT
# HXX_POSW
# HXX_REP
# HXX_RUR
# HXX_USD
# HXX_USDT
# HXX_XMR
# HXX_ZEC
# ICN_BTC
# ICN_DASH
# ICN_DOGE
# ICN_ETC
# ICN_ETH
# ICN_EUR
# ICN_LTC
# ICN_NXT
# ICN_POSW
# ICN_REP
# ICN_RUR
# ICN_USD
# ICN_USDT
# ICN_XMR
# ICN_ZEC
# INCNT_BTC
# INCNT_DASH
# INCNT_DOGE
# INCNT_ETC
# INCNT_ETH
# INCNT_EUR
# INCNT_LTC
# INCNT_NXT
# INCNT_POSW
# INCNT_REP
# INCNT_RUR
# INCNT_USD
# INCNT_USDT
# INCNT_XMR
# INCNT_ZEC
# INFX_BTC
# INFX_DASH
# INFX_DOGE
# INFX_ETC
# INFX_ETH
# INFX_EUR
# INFX_LTC
# INFX_NXT
# INFX_POSW
# INFX_REP
# INFX_RUR
# INFX_USD
# INFX_USDT
# INFX_XMR
# INFX_ZEC
# IOC_BTC
# IOC_DASH
# IOC_DOGE
# IOC_ETC
# IOC_ETH
# IOC_EUR
# IOC_LTC
# IOC_NXT
# IOC_POSW
# IOC_REP
# IOC_RUR
# IOC_USD
# IOC_USDT
# IOC_XMR
# IOC_ZEC
# ION_BTC
# ION_DASH
# ION_DOGE
# ION_ETC
# ION_ETH
# ION_EUR
# ION_LTC
# ION_NXT
# ION_POSW
# ION_REP
# ION_RUR
# ION_USD
# ION_USDT
# ION_XMR
# ION_ZEC
# IOP_BTC
# IOP_DASH
# IOP_DOGE
# IOP_ETC
# IOP_ETH
# IOP_EUR
# IOP_LTC
# IOP_NXT
# IOP_POSW
# IOP_REP
# IOP_RUR
# IOP_USD
# IOP_USDT
# IOP_XMR
# IOP_ZEC
# ISL_BTC
# ISL_DASH
# ISL_DOGE
# ISL_ETC
# ISL_ETH
# ISL_EUR
# ISL_LTC
# ISL_NXT
# ISL_POSW
# ISL_REP
# ISL_RUR
# ISL_USD
# ISL_USDT
# ISL_XMR
# ISL_ZEC
# ITI_BTC
# ITI_DASH
# ITI_DOGE
# ITI_ETC
# ITI_ETH
# ITI_EUR
# ITI_LTC
# ITI_NXT
# ITI_POSW
# ITI_REP
# ITI_RUR
# ITI_USD
# ITI_USDT
# ITI_XMR
# ITI_ZEC
# JWL_BTC
# JWL_DASH
# JWL_DOGE
# JWL_ETC
# JWL_ETH
# JWL_EUR
# JWL_LTC
# JWL_NXT
# JWL_POSW
# JWL_REP
# JWL_RUR
# JWL_USD
# JWL_USDT
# JWL_XMR
# JWL_ZEC
# KC_BTC
# KC_DASH
# KC_DOGE
# KC_ETC
# KC_ETH
# KC_EUR
# KC_LTC
# KC_NXT
# KC_POSW
# KC_REP
# KC_RUR
# KC_USD
# KC_USDT
# KC_XMR
# KC_ZEC
# LBC_BTC
# LBC_DASH
# LBC_DOGE
# LBC_ETC
# LBC_ETH
# LBC_EUR
# LBC_LTC
# LBC_NXT
# LBC_POSW
# LBC_REP
# LBC_RUR
# LBC_USD
# LBC_USDT
# LBC_XMR
# LBC_ZEC
# LEO_BTC
# LEO_DASH
# LEO_DOGE
# LEO_ETC
# LEO_ETH
# LEO_EUR
# LEO_LTC
# LEO_NXT
# LEO_POSW
# LEO_REP
# LEO_RUR
# LEO_USD
# LEO_USDT
# LEO_XMR
# LEO_ZEC
# LEPEN_BTC
# LEPEN_DASH
# LEPEN_DOGE
# LEPEN_ETC
# LEPEN_ETH
# LEPEN_EUR
# LEPEN_LTC
# LEPEN_NXT
# LEPEN_POSW
# LEPEN_REP
# LEPEN_RUR
# LEPEN_USD
# LEPEN_USDT
# LEPEN_XMR
# LEPEN_ZEC
# LSK_BTC
# LSK_DASH
# LSK_DOGE
# LSK_ETC
# LSK_ETH
# LSK_EUR
# LSK_LTC
# LSK_NXT
# LSK_POSW
# LSK_REP
# LSK_RUR
# LSK_USD
# LSK_USDT
# LSK_XMR
# LSK_ZEC
# LTC_1ST
# LTC_2GIVE
# LTC_8BIT
# LTC_ABY
# LTC_ACP
# LTC_ADCN
# LTC_ADZ
# LTC_AEON
# LTC_AIB
# LTC_AMP
# LTC_ARC
# LTC_ARDR
# LTC_AUR
# LTC_BASH
# LTC_BAY
# LTC_BCC
# LTC_BCN
# LTC_BCY
# LTC_BHC
# LTC_BIOS
# LTC_BIT
# LTC_BITB
# LTC_BLK
# LTC_BLU
# LTC_BPC
# LTC_BSD
# LTC_BTA
# LTC_BTC
# LTC_BTC
# LTC_BTCD
# LTC_BTS
# LTC_BURST
# LTC_CANN
# LTC_CCRB
# LTC_CJ
# LTC_CLAM
# LTC_CLOAK
# LTC_CLUB
# LTC_CNT
# LTC_CPC
# LTC_CREVA
# LTC_CRW
# LTC_CURE
# LTC_DASH
# LTC_DASH
# LTC_DCR
# LTC_DCT
# LTC_DGB
# LTC_DGD
# LTC_DIME
# LTC_DOGE
# LTC_DOGE
# LTC_DRACO
# LTC_DRZ
# LTC_DSH
# LTC_ECN
# LTC_EGC
# LTC_EL
# LTC_ELE
# LTC_EMC
# LTC_EMC2
# LTC_ENT
# LTC_ETC
# LTC_ETC
# LTC_ETH
# LTC_ETH
# LTC_EUR
# LTC_EUR
# LTC_EXP
# LTC_FCT
# LTC_FJC
# LTC_FRST
# LTC_GAME
# LTC_GB
# LTC_GCR
# LTC_GEO
# LTC_GHS
# LTC_GLD
# LTC_GNO
# LTC_GNT
# LTC_GOLOS
# LTC_GRC
# LTC_GUP
# LTC_HCC
# LTC_HXX
# LTC_ICN
# LTC_INCNT
# LTC_INFX
# LTC_IOC
# LTC_ION
# LTC_IOP
# LTC_ISL
# LTC_ITI
# LTC_JWL
# LTC_KC
# LTC_LBC
# LTC_LEO
# LTC_LEPEN
# LTC_LSK
# LTC_LTC
# LTC_LTC
# LTC_LTCR
# LTC_LTS
# LTC_LUN
# LTC_LUNA
# LTC_MAID
# LTC_MLN
# LTC_MOIN
# LTC_MOJO
# LTC_MONA
# LTC_MSCN
# LTC_MUE
# LTC_NAUT
# LTC_NAV
# LTC_NLG
# LTC_NMC
# LTC_NOTE
# LTC_NVC
# LTC_NXC
# LTC_NXT
# LTC_NXT
# LTC_OD
# LTC_OK
# LTC_OMNI
# LTC_OTX
# LTC_PINK
# LTC_PIVX
# LTC_PKB
# LTC_POST
# LTC_POSW
# LTC_POSW
# LTC_PPC
# LTC_PRES
# LTC_PROC
# LTC_PSB
# LTC_RADS
# LTC_RBIES
# LTC_RDD
# LTC_REE
# LTC_REP
# LTC_REP
# LTC_RIDE
# LTC_RISE
# LTC_RLC
# LTC_ROYAL
# LTC_RUB
# LTC_RUR
# LTC_RUR
# LTC_SBD
# LTC_SC
# LTC_SHIFT
# LTC_SIB
# LTC_SLR
# LTC_SLS
# LTC_SNGLS
# LTC_SNRG
# LTC_SOAR
# LTC_SONG
# LTC_SPR
# LTC_START
# LTC_STEEM
# LTC_STRAT
# LTC_SWT
# LTC_SXC
# LTC_SYNX
# LTC_SYS
# LTC_TAAS
# LTC_TIME
# LTC_TKN
# LTC_TLE
# LTC_TRST
# LTC_TRUMP
# LTC_TSE
# LTC_TX
# LTC_U
# LTC_UNC
# LTC_UNO
# LTC_UNY
# LTC_USD
# LTC_USD
# LTC_USDT
# LTC_USDT
# LTC_VEC2
# LTC_VIA
# LTC_VOX
# LTC_VRC
# LTC_VRM
# LTC_VRS
# LTC_VTC
# LTC_WAVES
# LTC_WINGS
# LTC_XAUR
# LTC_XBY
# LTC_XDN
# LTC_XEM
# LTC_XHI
# LTC_XLM
# LTC_XMR
# LTC_XMR
# LTC_XMS
# LTC_XRP
# LTC_XSPEC
# LTC_XTO
# LTC_XVC
# LTC_XVG
# LTC_YOC
# LTC_ZCL
# LTC_ZEC
# LTC_ZEC
# LTC_ZENI
# LTCR_BTC
# LTCR_DASH
# LTCR_DOGE
# LTCR_ETC
# LTCR_ETH
# LTCR_EUR
# LTCR_LTC
# LTCR_NXT
# LTCR_POSW
# LTCR_REP
# LTCR_RUR
# LTCR_USD
# LTCR_USDT
# LTCR_XMR
# LTCR_ZEC
# LTS_BTC
# LTS_DASH
# LTS_DOGE
# LTS_ETC
# LTS_ETH
# LTS_EUR
# LTS_LTC
# LTS_NXT
# LTS_POSW
# LTS_REP
# LTS_RUR
# LTS_USD
# LTS_USDT
# LTS_XMR
# LTS_ZEC
# LUN_BTC
# LUN_DASH
# LUN_DOGE
# LUN_ETC
# LUN_ETH
# LUN_EUR
# LUN_LTC
# LUN_NXT
# LUN_POSW
# LUN_REP
# LUN_RUR
# LUN_USD
# LUN_USDT
# LUN_XMR
# LUN_ZEC
# LUNA_BTC
# LUNA_DASH
# LUNA_DOGE
# LUNA_ETC
# LUNA_ETH
# LUNA_EUR
# LUNA_LTC
# LUNA_NXT
# LUNA_POSW
# LUNA_REP
# LUNA_RUR
# LUNA_USD
# LUNA_USDT
# LUNA_XMR
# LUNA_ZEC
# MAID_BTC
# MAID_DASH
# MAID_DOGE
# MAID_ETC
# MAID_ETH
# MAID_EUR
# MAID_LTC
# MAID_NXT
# MAID_POSW
# MAID_REP
# MAID_RUR
# MAID_USD
# MAID_USDT
# MAID_XMR
# MAID_ZEC
# MLN_BTC
# MLN_DASH
# MLN_DOGE
# MLN_ETC
# MLN_ETH
# MLN_EUR
# MLN_LTC
# MLN_NXT
# MLN_POSW
# MLN_REP
# MLN_RUR
# MLN_USD
# MLN_USDT
# MLN_XMR
# MLN_ZEC
# MOIN_BTC
# MOIN_DASH
# MOIN_DOGE
# MOIN_ETC
# MOIN_ETH
# MOIN_EUR
# MOIN_LTC
# MOIN_NXT
# MOIN_POSW
# MOIN_REP
# MOIN_RUR
# MOIN_USD
# MOIN_USDT
# MOIN_XMR
# MOIN_ZEC
# MOJO_BTC
# MOJO_DASH
# MOJO_DOGE
# MOJO_ETC
# MOJO_ETH
# MOJO_EUR
# MOJO_LTC
# MOJO_NXT
# MOJO_POSW
# MOJO_REP
# MOJO_RUR
# MOJO_USD
# MOJO_USDT
# MOJO_XMR
# MOJO_ZEC
# MONA_BTC
# MONA_DASH
# MONA_DOGE
# MONA_ETC
# MONA_ETH
# MONA_EUR
# MONA_LTC
# MONA_NXT
# MONA_POSW
# MONA_REP
# MONA_RUR
# MONA_USD
# MONA_USDT
# MONA_XMR
# MONA_ZEC
# MSCN_BTC
# MSCN_DASH
# MSCN_DOGE
# MSCN_ETC
# MSCN_ETH
# MSCN_EUR
# MSCN_LTC
# MSCN_NXT
# MSCN_POSW
# MSCN_REP
# MSCN_RUR
# MSCN_USD
# MSCN_USDT
# MSCN_XMR
# MSCN_ZEC
# MUE_BTC
# MUE_DASH
# MUE_DOGE
# MUE_ETC
# MUE_ETH
# MUE_EUR
# MUE_LTC
# MUE_NXT
# MUE_POSW
# MUE_REP
# MUE_RUR
# MUE_USD
# MUE_USDT
# MUE_XMR
# MUE_ZEC
# NAUT_BTC
# NAUT_DASH
# NAUT_DOGE
# NAUT_ETC
# NAUT_ETH
# NAUT_EUR
# NAUT_LTC
# NAUT_NXT
# NAUT_POSW
# NAUT_REP
# NAUT_RUR
# NAUT_USD
# NAUT_USDT
# NAUT_XMR
# NAUT_ZEC
# NAV_BTC
# NAV_DASH
# NAV_DOGE
# NAV_ETC
# NAV_ETH
# NAV_EUR
# NAV_LTC
# NAV_NXT
# NAV_POSW
# NAV_REP
# NAV_RUR
# NAV_USD
# NAV_USDT
# NAV_XMR
# NAV_ZEC
# NLG_BTC
# NLG_DASH
# NLG_DOGE
# NLG_ETC
# NLG_ETH
# NLG_EUR
# NLG_LTC
# NLG_NXT
# NLG_POSW
# NLG_REP
# NLG_RUR
# NLG_USD
# NLG_USDT
# NLG_XMR
# NLG_ZEC
# NMC_BTC
# NMC_DASH
# NMC_DOGE
# NMC_ETC
# NMC_ETH
# NMC_EUR
# NMC_LTC
# NMC_NXT
# NMC_POSW
# NMC_REP
# NMC_RUR
# NMC_USD
# NMC_USDT
# NMC_XMR
# NMC_ZEC
# NOTE_BTC
# NOTE_DASH
# NOTE_DOGE
# NOTE_ETC
# NOTE_ETH
# NOTE_EUR
# NOTE_LTC
# NOTE_NXT
# NOTE_POSW
# NOTE_REP
# NOTE_RUR
# NOTE_USD
# NOTE_USDT
# NOTE_XMR
# NOTE_ZEC
# NVC_BTC
# NVC_DASH
# NVC_DOGE
# NVC_ETC
# NVC_ETH
# NVC_EUR
# NVC_LTC
# NVC_NXT
# NVC_POSW
# NVC_REP
# NVC_RUR
# NVC_USD
# NVC_USDT
# NVC_XMR
# NVC_ZEC
# NXC_BTC
# NXC_DASH
# NXC_DOGE
# NXC_ETC
# NXC_ETH
# NXC_EUR
# NXC_LTC
# NXC_NXT
# NXC_POSW
# NXC_REP
# NXC_RUR
# NXC_USD
# NXC_USDT
# NXC_XMR
# NXC_ZEC
# NXT_1ST
# NXT_2GIVE
# NXT_8BIT
# NXT_ABY
# NXT_ACP
# NXT_ADCN
# NXT_ADZ
# NXT_AEON
# NXT_AIB
# NXT_AMP
# NXT_ARC
# NXT_ARDR
# NXT_AUR
# NXT_BASH
# NXT_BAY
# NXT_BCC
# NXT_BCN
# NXT_BCY
# NXT_BHC
# NXT_BIOS
# NXT_BIT
# NXT_BITB
# NXT_BLK
# NXT_BLU
# NXT_BPC
# NXT_BSD
# NXT_BTA
# NXT_BTC
# NXT_BTC
# NXT_BTCD
# NXT_BTS
# NXT_BURST
# NXT_CANN
# NXT_CCRB
# NXT_CJ
# NXT_CLAM
# NXT_CLOAK
# NXT_CLUB
# NXT_CNT
# NXT_CPC
# NXT_CREVA
# NXT_CRW
# NXT_CURE
# NXT_DASH
# NXT_DASH
# NXT_DCR
# NXT_DCT
# NXT_DGB
# NXT_DGD
# NXT_DIME
# NXT_DOGE
# NXT_DOGE
# NXT_DRACO
# NXT_DRZ
# NXT_DSH
# NXT_ECN
# NXT_EGC
# NXT_EL
# NXT_ELE
# NXT_EMC
# NXT_EMC2
# NXT_ENT
# NXT_ETC
# NXT_ETC
# NXT_ETH
# NXT_ETH
# NXT_EUR
# NXT_EUR
# NXT_EXP
# NXT_FCT
# NXT_FJC
# NXT_FRST
# NXT_GAME
# NXT_GB
# NXT_GCR
# NXT_GEO
# NXT_GHS
# NXT_GLD
# NXT_GNO
# NXT_GNT
# NXT_GOLOS
# NXT_GRC
# NXT_GUP
# NXT_HCC
# NXT_HXX
# NXT_ICN
# NXT_INCNT
# NXT_INFX
# NXT_IOC
# NXT_ION
# NXT_IOP
# NXT_ISL
# NXT_ITI
# NXT_JWL
# NXT_KC
# NXT_LBC
# NXT_LEO
# NXT_LEPEN
# NXT_LSK
# NXT_LTC
# NXT_LTC
# NXT_LTCR
# NXT_LTS
# NXT_LUN
# NXT_LUNA
# NXT_MAID
# NXT_MLN
# NXT_MOIN
# NXT_MOJO
# NXT_MONA
# NXT_MSCN
# NXT_MUE
# NXT_NAUT
# NXT_NAV
# NXT_NLG
# NXT_NMC
# NXT_NOTE
# NXT_NVC
# NXT_NXC
# NXT_NXT
# NXT_NXT
# NXT_OD
# NXT_OK
# NXT_OMNI
# NXT_OTX
# NXT_PINK
# NXT_PIVX
# NXT_PKB
# NXT_POST
# NXT_POSW
# NXT_POSW
# NXT_PPC
# NXT_PRES
# NXT_PROC
# NXT_PSB
# NXT_RADS
# NXT_RBIES
# NXT_RDD
# NXT_REE
# NXT_REP
# NXT_REP
# NXT_RIDE
# NXT_RISE
# NXT_RLC
# NXT_ROYAL
# NXT_RUB
# NXT_RUR
# NXT_RUR
# NXT_SBD
# NXT_SC
# NXT_SHIFT
# NXT_SIB
# NXT_SLR
# NXT_SLS
# NXT_SNGLS
# NXT_SNRG
# NXT_SOAR
# NXT_SONG
# NXT_SPR
# NXT_START
# NXT_STEEM
# NXT_STRAT
# NXT_SWT
# NXT_SXC
# NXT_SYNX
# NXT_SYS
# NXT_TAAS
# NXT_TIME
# NXT_TKN
# NXT_TLE
# NXT_TRST
# NXT_TRUMP
# NXT_TSE
# NXT_TX
# NXT_U
# NXT_UNC
# NXT_UNO
# NXT_UNY
# NXT_USD
# NXT_USD
# NXT_USDT
# NXT_USDT
# NXT_VEC2
# NXT_VIA
# NXT_VOX
# NXT_VRC
# NXT_VRM
# NXT_VRS
# NXT_VTC
# NXT_WAVES
# NXT_WINGS
# NXT_XAUR
# NXT_XBY
# NXT_XDN
# NXT_XEM
# NXT_XHI
# NXT_XLM
# NXT_XMR
# NXT_XMR
# NXT_XMS
# NXT_XRP
# NXT_XSPEC
# NXT_XTO
# NXT_XVC
# NXT_XVG
# NXT_YOC
# NXT_ZCL
# NXT_ZEC
# NXT_ZEC
# NXT_ZENI
# OD_BTC
# OD_DASH
# OD_DOGE
# OD_ETC
# OD_ETH
# OD_EUR
# OD_LTC
# OD_NXT
# OD_POSW
# OD_REP
# OD_RUR
# OD_USD
# OD_USDT
# OD_XMR
# OD_ZEC
# OK_BTC
# OK_DASH
# OK_DOGE
# OK_ETC
# OK_ETH
# OK_EUR
# OK_LTC
# OK_NXT
# OK_POSW
# OK_REP
# OK_RUR
# OK_USD
# OK_USDT
# OK_XMR
# OK_ZEC
# OMNI_BTC
# OMNI_DASH
# OMNI_DOGE
# OMNI_ETC
# OMNI_ETH
# OMNI_EUR
# OMNI_LTC
# OMNI_NXT
# OMNI_POSW
# OMNI_REP
# OMNI_RUR
# OMNI_USD
# OMNI_USDT
# OMNI_XMR
# OMNI_ZEC
# OTX_BTC
# OTX_DASH
# OTX_DOGE
# OTX_ETC
# OTX_ETH
# OTX_EUR
# OTX_LTC
# OTX_NXT
# OTX_POSW
# OTX_REP
# OTX_RUR
# OTX_USD
# OTX_USDT
# OTX_XMR
# OTX_ZEC
# PINK_BTC
# PINK_DASH
# PINK_DOGE
# PINK_ETC
# PINK_ETH
# PINK_EUR
# PINK_LTC
# PINK_NXT
# PINK_POSW
# PINK_REP
# PINK_RUR
# PINK_USD
# PINK_USDT
# PINK_XMR
# PINK_ZEC
# PIVX_BTC
# PIVX_DASH
# PIVX_DOGE
# PIVX_ETC
# PIVX_ETH
# PIVX_EUR
# PIVX_LTC
# PIVX_NXT
# PIVX_POSW
# PIVX_REP
# PIVX_RUR
# PIVX_USD
# PIVX_USDT
# PIVX_XMR
# PIVX_ZEC
# PKB_BTC
# PKB_DASH
# PKB_DOGE
# PKB_ETC
# PKB_ETH
# PKB_EUR
# PKB_LTC
# PKB_NXT
# PKB_POSW
# PKB_REP
# PKB_RUR
# PKB_USD
# PKB_USDT
# PKB_XMR
# PKB_ZEC
# POST_BTC
# POST_DASH
# POST_DOGE
# POST_ETC
# POST_ETH
# POST_EUR
# POST_LTC
# POST_NXT
# POST_POSW
# POST_REP
# POST_RUR
# POST_USD
# POST_USDT
# POST_XMR
# POST_ZEC
# POSW_1ST
# POSW_2GIVE
# POSW_8BIT
# POSW_ABY
# POSW_ACP
# POSW_ADCN
# POSW_ADZ
# POSW_AEON
# POSW_AIB
# POSW_AMP
# POSW_ARC
# POSW_ARDR
# POSW_AUR
# POSW_BASH
# POSW_BAY
# POSW_BCC
# POSW_BCN
# POSW_BCY
# POSW_BHC
# POSW_BIOS
# POSW_BIT
# POSW_BITB
# POSW_BLK
# POSW_BLU
# POSW_BPC
# POSW_BSD
# POSW_BTA
# POSW_BTC
# POSW_BTC
# POSW_BTCD
# POSW_BTS
# POSW_BURST
# POSW_CANN
# POSW_CCRB
# POSW_CJ
# POSW_CLAM
# POSW_CLOAK
# POSW_CLUB
# POSW_CNT
# POSW_CPC
# POSW_CREVA
# POSW_CRW
# POSW_CURE
# POSW_DASH
# POSW_DASH
# POSW_DCR
# POSW_DCT
# POSW_DGB
# POSW_DGD
# POSW_DIME
# POSW_DOGE
# POSW_DOGE
# POSW_DRACO
# POSW_DRZ
# POSW_DSH
# POSW_ECN
# POSW_EGC
# POSW_EL
# POSW_ELE
# POSW_EMC
# POSW_EMC2
# POSW_ENT
# POSW_ETC
# POSW_ETC
# POSW_ETH
# POSW_ETH
# POSW_EUR
# POSW_EUR
# POSW_EXP
# POSW_FCT
# POSW_FJC
# POSW_FRST
# POSW_GAME
# POSW_GB
# POSW_GCR
# POSW_GEO
# POSW_GHS
# POSW_GLD
# POSW_GNO
# POSW_GNT
# POSW_GOLOS
# POSW_GRC
# POSW_GUP
# POSW_HCC
# POSW_HXX
# POSW_ICN
# POSW_INCNT
# POSW_INFX
# POSW_IOC
# POSW_ION
# POSW_IOP
# POSW_ISL
# POSW_ITI
# POSW_JWL
# POSW_KC
# POSW_LBC
# POSW_LEO
# POSW_LEPEN
# POSW_LSK
# POSW_LTC
# POSW_LTC
# POSW_LTCR
# POSW_LTS
# POSW_LUN
# POSW_LUNA
# POSW_MAID
# POSW_MLN
# POSW_MOIN
# POSW_MOJO
# POSW_MONA
# POSW_MSCN
# POSW_MUE
# POSW_NAUT
# POSW_NAV
# POSW_NLG
# POSW_NMC
# POSW_NOTE
# POSW_NVC
# POSW_NXC
# POSW_NXT
# POSW_NXT
# POSW_OD
# POSW_OK
# POSW_OMNI
# POSW_OTX
# POSW_PINK
# POSW_PIVX
# POSW_PKB
# POSW_POST
# POSW_POSW
# POSW_POSW
# POSW_PPC
# POSW_PRES
# POSW_PROC
# POSW_PSB
# POSW_RADS
# POSW_RBIES
# POSW_RDD
# POSW_REE
# POSW_REP
# POSW_REP
# POSW_RIDE
# POSW_RISE
# POSW_RLC
# POSW_ROYAL
# POSW_RUB
# POSW_RUR
# POSW_RUR
# POSW_SBD
# POSW_SC
# POSW_SHIFT
# POSW_SIB
# POSW_SLR
# POSW_SLS
# POSW_SNGLS
# POSW_SNRG
# POSW_SOAR
# POSW_SONG
# POSW_SPR
# POSW_START
# POSW_STEEM
# POSW_STRAT
# POSW_SWT
# POSW_SXC
# POSW_SYNX
# POSW_SYS
# POSW_TAAS
# POSW_TIME
# POSW_TKN
# POSW_TLE
# POSW_TRST
# POSW_TRUMP
# POSW_TSE
# POSW_TX
# POSW_U
# POSW_UNC
# POSW_UNO
# POSW_UNY
# POSW_USD
# POSW_USD
# POSW_USDT
# POSW_USDT
# POSW_VEC2
# POSW_VIA
# POSW_VOX
# POSW_VRC
# POSW_VRM
# POSW_VRS
# POSW_VTC
# POSW_WAVES
# POSW_WINGS
# POSW_XAUR
# POSW_XBY
# POSW_XDN
# POSW_XEM
# POSW_XHI
# POSW_XLM
# POSW_XMR
# POSW_XMR
# POSW_XMS
# POSW_XRP
# POSW_XSPEC
# POSW_XTO
# POSW_XVC
# POSW_XVG
# POSW_YOC
# POSW_ZCL
# POSW_ZEC
# POSW_ZEC
# POSW_ZENI
# PPC_BTC
# PPC_DASH
# PPC_DOGE
# PPC_ETC
# PPC_ETH
# PPC_EUR
# PPC_LTC
# PPC_NXT
# PPC_POSW
# PPC_REP
# PPC_RUR
# PPC_USD
# PPC_USDT
# PPC_XMR
# PPC_ZEC
# PRES_BTC
# PRES_DASH
# PRES_DOGE
# PRES_ETC
# PRES_ETH
# PRES_EUR
# PRES_LTC
# PRES_NXT
# PRES_POSW
# PRES_REP
# PRES_RUR
# PRES_USD
# PRES_USDT
# PRES_XMR
# PRES_ZEC
# PROC_BTC
# PROC_DASH
# PROC_DOGE
# PROC_ETC
# PROC_ETH
# PROC_EUR
# PROC_LTC
# PROC_NXT
# PROC_POSW
# PROC_REP
# PROC_RUR
# PROC_USD
# PROC_USDT
# PROC_XMR
# PROC_ZEC
# PSB_BTC
# PSB_DASH
# PSB_DOGE
# PSB_ETC
# PSB_ETH
# PSB_EUR
# PSB_LTC
# PSB_NXT
# PSB_POSW
# PSB_REP
# PSB_RUR
# PSB_USD
# PSB_USDT
# PSB_XMR
# PSB_ZEC
# RADS_BTC
# RADS_DASH
# RADS_DOGE
# RADS_ETC
# RADS_ETH
# RADS_EUR
# RADS_LTC
# RADS_NXT
# RADS_POSW
# RADS_REP
# RADS_RUR
# RADS_USD
# RADS_USDT
# RADS_XMR
# RADS_ZEC
# RBIES_BTC
# RBIES_DASH
# RBIES_DOGE
# RBIES_ETC
# RBIES_ETH
# RBIES_EUR
# RBIES_LTC
# RBIES_NXT
# RBIES_POSW
# RBIES_REP
# RBIES_RUR
# RBIES_USD
# RBIES_USDT
# RBIES_XMR
# RBIES_ZEC
# RDD_BTC
# RDD_DASH
# RDD_DOGE
# RDD_ETC
# RDD_ETH
# RDD_EUR
# RDD_LTC
# RDD_NXT
# RDD_POSW
# RDD_REP
# RDD_RUR
# RDD_USD
# RDD_USDT
# RDD_XMR
# RDD_ZEC
# REE_BTC
# REE_DASH
# REE_DOGE
# REE_ETC
# REE_ETH
# REE_EUR
# REE_LTC
# REE_NXT
# REE_POSW
# REE_REP
# REE_RUR
# REE_USD
# REE_USDT
# REE_XMR
# REE_ZEC
# REP_1ST
# REP_2GIVE
# REP_8BIT
# REP_ABY
# REP_ACP
# REP_ADCN
# REP_ADZ
# REP_AEON
# REP_AIB
# REP_AMP
# REP_ARC
# REP_ARDR
# REP_AUR
# REP_BASH
# REP_BAY
# REP_BCC
# REP_BCN
# REP_BCY
# REP_BHC
# REP_BIOS
# REP_BIT
# REP_BITB
# REP_BLK
# REP_BLU
# REP_BPC
# REP_BSD
# REP_BTA
# REP_BTC
# REP_BTC
# REP_BTCD
# REP_BTS
# REP_BURST
# REP_CANN
# REP_CCRB
# REP_CJ
# REP_CLAM
# REP_CLOAK
# REP_CLUB
# REP_CNT
# REP_CPC
# REP_CREVA
# REP_CRW
# REP_CURE
# REP_DASH
# REP_DASH
# REP_DCR
# REP_DCT
# REP_DGB
# REP_DGD
# REP_DIME
# REP_DOGE
# REP_DOGE
# REP_DRACO
# REP_DRZ
# REP_DSH
# REP_ECN
# REP_EGC
# REP_EL
# REP_ELE
# REP_EMC
# REP_EMC2
# REP_ENT
# REP_ETC
# REP_ETC
# REP_ETH
# REP_ETH
# REP_EUR
# REP_EUR
# REP_EXP
# REP_FCT
# REP_FJC
# REP_FRST
# REP_GAME
# REP_GB
# REP_GCR
# REP_GEO
# REP_GHS
# REP_GLD
# REP_GNO
# REP_GNT
# REP_GOLOS
# REP_GRC
# REP_GUP
# REP_HCC
# REP_HXX
# REP_ICN
# REP_INCNT
# REP_INFX
# REP_IOC
# REP_ION
# REP_IOP
# REP_ISL
# REP_ITI
# REP_JWL
# REP_KC
# REP_LBC
# REP_LEO
# REP_LEPEN
# REP_LSK
# REP_LTC
# REP_LTC
# REP_LTCR
# REP_LTS
# REP_LUN
# REP_LUNA
# REP_MAID
# REP_MLN
# REP_MOIN
# REP_MOJO
# REP_MONA
# REP_MSCN
# REP_MUE
# REP_NAUT
# REP_NAV
# REP_NLG
# REP_NMC
# REP_NOTE
# REP_NVC
# REP_NXC
# REP_NXT
# REP_NXT
# REP_OD
# REP_OK
# REP_OMNI
# REP_OTX
# REP_PINK
# REP_PIVX
# REP_PKB
# REP_POST
# REP_POSW
# REP_POSW
# REP_PPC
# REP_PRES
# REP_PROC
# REP_PSB
# REP_RADS
# REP_RBIES
# REP_RDD
# REP_REE
# REP_REP
# REP_REP
# REP_RIDE
# REP_RISE
# REP_RLC
# REP_ROYAL
# REP_RUB
# REP_RUR
# REP_RUR
# REP_SBD
# REP_SC
# REP_SHIFT
# REP_SIB
# REP_SLR
# REP_SLS
# REP_SNGLS
# REP_SNRG
# REP_SOAR
# REP_SONG
# REP_SPR
# REP_START
# REP_STEEM
# REP_STRAT
# REP_SWT
# REP_SXC
# REP_SYNX
# REP_SYS
# REP_TAAS
# REP_TIME
# REP_TKN
# REP_TLE
# REP_TRST
# REP_TRUMP
# REP_TSE
# REP_TX
# REP_U
# REP_UNC
# REP_UNO
# REP_UNY
# REP_USD
# REP_USD
# REP_USDT
# REP_USDT
# REP_VEC2
# REP_VIA
# REP_VOX
# REP_VRC
# REP_VRM
# REP_VRS
# REP_VTC
# REP_WAVES
# REP_WINGS
# REP_XAUR
# REP_XBY
# REP_XDN
# REP_XEM
# REP_XHI
# REP_XLM
# REP_XMR
# REP_XMR
# REP_XMS
# REP_XRP
# REP_XSPEC
# REP_XTO
# REP_XVC
# REP_XVG
# REP_YOC
# REP_ZCL
# REP_ZEC
# REP_ZEC
# REP_ZENI
# RIDE_BTC
# RIDE_DASH
# RIDE_DOGE
# RIDE_ETC
# RIDE_ETH
# RIDE_EUR
# RIDE_LTC
# RIDE_NXT
# RIDE_POSW
# RIDE_REP
# RIDE_RUR
# RIDE_USD
# RIDE_USDT
# RIDE_XMR
# RIDE_ZEC
# RISE_BTC
# RISE_DASH
# RISE_DOGE
# RISE_ETC
# RISE_ETH
# RISE_EUR
# RISE_LTC
# RISE_NXT
# RISE_POSW
# RISE_REP
# RISE_RUR
# RISE_USD
# RISE_USDT
# RISE_XMR
# RISE_ZEC
# RLC_BTC
# RLC_DASH
# RLC_DOGE
# RLC_ETC
# RLC_ETH
# RLC_EUR
# RLC_LTC
# RLC_NXT
# RLC_POSW
# RLC_REP
# RLC_RUR
# RLC_USD
# RLC_USDT
# RLC_XMR
# RLC_ZEC
# ROYAL_BTC
# ROYAL_DASH
# ROYAL_DOGE
# ROYAL_ETC
# ROYAL_ETH
# ROYAL_EUR
# ROYAL_LTC
# ROYAL_NXT
# ROYAL_POSW
# ROYAL_REP
# ROYAL_RUR
# ROYAL_USD
# ROYAL_USDT
# ROYAL_XMR
# ROYAL_ZEC
# RUB_BTC
# RUB_DASH
# RUB_DOGE
# RUB_ETC
# RUB_ETH
# RUB_EUR
# RUB_LTC
# RUB_NXT
# RUB_POSW
# RUB_REP
# RUB_RUR
# RUB_USD
# RUB_USDT
# RUB_XMR
# RUB_ZEC
# RUR_1ST
# RUR_2GIVE
# RUR_8BIT
# RUR_ABY
# RUR_ACP
# RUR_ADCN
# RUR_ADZ
# RUR_AEON
# RUR_AIB
# RUR_AMP
# RUR_ARC
# RUR_ARDR
# RUR_AUR
# RUR_BASH
# RUR_BAY
# RUR_BCC
# RUR_BCN
# RUR_BCY
# RUR_BHC
# RUR_BIOS
# RUR_BIT
# RUR_BITB
# RUR_BLK
# RUR_BLU
# RUR_BPC
# RUR_BSD
# RUR_BTA
# RUR_BTC
# RUR_BTC
# RUR_BTCD
# RUR_BTS
# RUR_BURST
# RUR_CANN
# RUR_CCRB
# RUR_CJ
# RUR_CLAM
# RUR_CLOAK
# RUR_CLUB
# RUR_CNT
# RUR_CPC
# RUR_CREVA
# RUR_CRW
# RUR_CURE
# RUR_DASH
# RUR_DASH
# RUR_DCR
# RUR_DCT
# RUR_DGB
# RUR_DGD
# RUR_DIME
# RUR_DOGE
# RUR_DOGE
# RUR_DRACO
# RUR_DRZ
# RUR_DSH
# RUR_ECN
# RUR_EGC
# RUR_EL
# RUR_ELE
# RUR_EMC
# RUR_EMC2
# RUR_ENT
# RUR_ETC
# RUR_ETC
# RUR_ETH
# RUR_ETH
# RUR_EUR
# RUR_EUR
# RUR_EXP
# RUR_FCT
# RUR_FJC
# RUR_FRST
# RUR_GAME
# RUR_GB
# RUR_GCR
# RUR_GEO
# RUR_GHS
# RUR_GLD
# RUR_GNO
# RUR_GNT
# RUR_GOLOS
# RUR_GRC
# RUR_GUP
# RUR_HCC
# RUR_HXX
# RUR_ICN
# RUR_INCNT
# RUR_INFX
# RUR_IOC
# RUR_ION
# RUR_IOP
# RUR_ISL
# RUR_ITI
# RUR_JWL
# RUR_KC
# RUR_LBC
# RUR_LEO
# RUR_LEPEN
# RUR_LSK
# RUR_LTC
# RUR_LTC
# RUR_LTCR
# RUR_LTS
# RUR_LUN
# RUR_LUNA
# RUR_MAID
# RUR_MLN
# RUR_MOIN
# RUR_MOJO
# RUR_MONA
# RUR_MSCN
# RUR_MUE
# RUR_NAUT
# RUR_NAV
# RUR_NLG
# RUR_NMC
# RUR_NOTE
# RUR_NVC
# RUR_NXC
# RUR_NXT
# RUR_NXT
# RUR_OD
# RUR_OK
# RUR_OMNI
# RUR_OTX
# RUR_PINK
# RUR_PIVX
# RUR_PKB
# RUR_POST
# RUR_POSW
# RUR_POSW
# RUR_PPC
# RUR_PRES
# RUR_PROC
# RUR_PSB
# RUR_RADS
# RUR_RBIES
# RUR_RDD
# RUR_REE
# RUR_REP
# RUR_REP
# RUR_RIDE
# RUR_RISE
# RUR_RLC
# RUR_ROYAL
# RUR_RUB
# RUR_RUR
# RUR_RUR
# RUR_SBD
# RUR_SC
# RUR_SHIFT
# RUR_SIB
# RUR_SLR
# RUR_SLS
# RUR_SNGLS
# RUR_SNRG
# RUR_SOAR
# RUR_SONG
# RUR_SPR
# RUR_START
# RUR_STEEM
# RUR_STRAT
# RUR_SWT
# RUR_SXC
# RUR_SYNX
# RUR_SYS
# RUR_TAAS
# RUR_TIME
# RUR_TKN
# RUR_TLE
# RUR_TRST
# RUR_TRUMP
# RUR_TSE
# RUR_TX
# RUR_U
# RUR_UNC
# RUR_UNO
# RUR_UNY
# RUR_USD
# RUR_USD
# RUR_USDT
# RUR_USDT
# RUR_VEC2
# RUR_VIA
# RUR_VOX
# RUR_VRC
# RUR_VRM
# RUR_VRS
# RUR_VTC
# RUR_WAVES
# RUR_WINGS
# RUR_XAUR
# RUR_XBY
# RUR_XDN
# RUR_XEM
# RUR_XHI
# RUR_XLM
# RUR_XMR
# RUR_XMR
# RUR_XMS
# RUR_XRP
# RUR_XSPEC
# RUR_XTO
# RUR_XVC
# RUR_XVG
# RUR_YOC
# RUR_ZCL
# RUR_ZEC
# RUR_ZEC
# RUR_ZENI
# SBD_BTC
# SBD_DASH
# SBD_DOGE
# SBD_ETC
# SBD_ETH
# SBD_EUR
# SBD_LTC
# SBD_NXT
# SBD_POSW
# SBD_REP
# SBD_RUR
# SBD_USD
# SBD_USDT
# SBD_XMR
# SBD_ZEC
# SC_BTC
# SC_DASH
# SC_DOGE
# SC_ETC
# SC_ETH
# SC_EUR
# SC_LTC
# SC_NXT
# SC_POSW
# SC_REP
# SC_RUR
# SC_USD
# SC_USDT
# SC_XMR
# SC_ZEC
# SHIFT_BTC
# SHIFT_DASH
# SHIFT_DOGE
# SHIFT_ETC
# SHIFT_ETH
# SHIFT_EUR
# SHIFT_LTC
# SHIFT_NXT
# SHIFT_POSW
# SHIFT_REP
# SHIFT_RUR
# SHIFT_USD
# SHIFT_USDT
# SHIFT_XMR
# SHIFT_ZEC
# SIB_BTC
# SIB_DASH
# SIB_DOGE
# SIB_ETC
# SIB_ETH
# SIB_EUR
# SIB_LTC
# SIB_NXT
# SIB_POSW
# SIB_REP
# SIB_RUR
# SIB_USD
# SIB_USDT
# SIB_XMR
# SIB_ZEC
# SLR_BTC
# SLR_DASH
# SLR_DOGE
# SLR_ETC
# SLR_ETH
# SLR_EUR
# SLR_LTC
# SLR_NXT
# SLR_POSW
# SLR_REP
# SLR_RUR
# SLR_USD
# SLR_USDT
# SLR_XMR
# SLR_ZEC
# SLS_BTC
# SLS_DASH
# SLS_DOGE
# SLS_ETC
# SLS_ETH
# SLS_EUR
# SLS_LTC
# SLS_NXT
# SLS_POSW
# SLS_REP
# SLS_RUR
# SLS_USD
# SLS_USDT
# SLS_XMR
# SLS_ZEC
# SNGLS_BTC
# SNGLS_DASH
# SNGLS_DOGE
# SNGLS_ETC
# SNGLS_ETH
# SNGLS_EUR
# SNGLS_LTC
# SNGLS_NXT
# SNGLS_POSW
# SNGLS_REP
# SNGLS_RUR
# SNGLS_USD
# SNGLS_USDT
# SNGLS_XMR
# SNGLS_ZEC
# SNRG_BTC
# SNRG_DASH
# SNRG_DOGE
# SNRG_ETC
# SNRG_ETH
# SNRG_EUR
# SNRG_LTC
# SNRG_NXT
# SNRG_POSW
# SNRG_REP
# SNRG_RUR
# SNRG_USD
# SNRG_USDT
# SNRG_XMR
# SNRG_ZEC
# SOAR_BTC
# SOAR_DASH
# SOAR_DOGE
# SOAR_ETC
# SOAR_ETH
# SOAR_EUR
# SOAR_LTC
# SOAR_NXT
# SOAR_POSW
# SOAR_REP
# SOAR_RUR
# SOAR_USD
# SOAR_USDT
# SOAR_XMR
# SOAR_ZEC
# SONG_BTC
# SONG_DASH
# SONG_DOGE
# SONG_ETC
# SONG_ETH
# SONG_EUR
# SONG_LTC
# SONG_NXT
# SONG_POSW
# SONG_REP
# SONG_RUR
# SONG_USD
# SONG_USDT
# SONG_XMR
# SONG_ZEC
# SPR_BTC
# SPR_DASH
# SPR_DOGE
# SPR_ETC
# SPR_ETH
# SPR_EUR
# SPR_LTC
# SPR_NXT
# SPR_POSW
# SPR_REP
# SPR_RUR
# SPR_USD
# SPR_USDT
# SPR_XMR
# SPR_ZEC
# START_BTC
# START_DASH
# START_DOGE
# START_ETC
# START_ETH
# START_EUR
# START_LTC
# START_NXT
# START_POSW
# START_REP
# START_RUR
# START_USD
# START_USDT
# START_XMR
# START_ZEC
# STEEM_BTC
# STEEM_DASH
# STEEM_DOGE
# STEEM_ETC
# STEEM_ETH
# STEEM_EUR
# STEEM_LTC
# STEEM_NXT
# STEEM_POSW
# STEEM_REP
# STEEM_RUR
# STEEM_USD
# STEEM_USDT
# STEEM_XMR
# STEEM_ZEC
# STRAT_BTC
# STRAT_DASH
# STRAT_DOGE
# STRAT_ETC
# STRAT_ETH
# STRAT_EUR
# STRAT_LTC
# STRAT_NXT
# STRAT_POSW
# STRAT_REP
# STRAT_RUR
# STRAT_USD
# STRAT_USDT
# STRAT_XMR
# STRAT_ZEC
# SWT_BTC
# SWT_DASH
# SWT_DOGE
# SWT_ETC
# SWT_ETH
# SWT_EUR
# SWT_LTC
# SWT_NXT
# SWT_POSW
# SWT_REP
# SWT_RUR
# SWT_USD
# SWT_USDT
# SWT_XMR
# SWT_ZEC
# SXC_BTC
# SXC_DASH
# SXC_DOGE
# SXC_ETC
# SXC_ETH
# SXC_EUR
# SXC_LTC
# SXC_NXT
# SXC_POSW
# SXC_REP
# SXC_RUR
# SXC_USD
# SXC_USDT
# SXC_XMR
# SXC_ZEC
# SYNX_BTC
# SYNX_DASH
# SYNX_DOGE
# SYNX_ETC
# SYNX_ETH
# SYNX_EUR
# SYNX_LTC
# SYNX_NXT
# SYNX_POSW
# SYNX_REP
# SYNX_RUR
# SYNX_USD
# SYNX_USDT
# SYNX_XMR
# SYNX_ZEC
# SYS_BTC
# SYS_DASH
# SYS_DOGE
# SYS_ETC
# SYS_ETH
# SYS_EUR
# SYS_LTC
# SYS_NXT
# SYS_POSW
# SYS_REP
# SYS_RUR
# SYS_USD
# SYS_USDT
# SYS_XMR
# SYS_ZEC
# TAAS_BTC
# TAAS_DASH
# TAAS_DOGE
# TAAS_ETC
# TAAS_ETH
# TAAS_EUR
# TAAS_LTC
# TAAS_NXT
# TAAS_POSW
# TAAS_REP
# TAAS_RUR
# TAAS_USD
# TAAS_USDT
# TAAS_XMR
# TAAS_ZEC
# TIME_BTC
# TIME_DASH
# TIME_DOGE
# TIME_ETC
# TIME_ETH
# TIME_EUR
# TIME_LTC
# TIME_NXT
# TIME_POSW
# TIME_REP
# TIME_RUR
# TIME_USD
# TIME_USDT
# TIME_XMR
# TIME_ZEC
# TKN_BTC
# TKN_DASH
# TKN_DOGE
# TKN_ETC
# TKN_ETH
# TKN_EUR
# TKN_LTC
# TKN_NXT
# TKN_POSW
# TKN_REP
# TKN_RUR
# TKN_USD
# TKN_USDT
# TKN_XMR
# TKN_ZEC
# TLE_BTC
# TLE_DASH
# TLE_DOGE
# TLE_ETC
# TLE_ETH
# TLE_EUR
# TLE_LTC
# TLE_NXT
# TLE_POSW
# TLE_REP
# TLE_RUR
# TLE_USD
# TLE_USDT
# TLE_XMR
# TLE_ZEC
# TRST_BTC
# TRST_DASH
# TRST_DOGE
# TRST_ETC
# TRST_ETH
# TRST_EUR
# TRST_LTC
# TRST_NXT
# TRST_POSW
# TRST_REP
# TRST_RUR
# TRST_USD
# TRST_USDT
# TRST_XMR
# TRST_ZEC
# TRUMP_BTC
# TRUMP_DASH
# TRUMP_DOGE
# TRUMP_ETC
# TRUMP_ETH
# TRUMP_EUR
# TRUMP_LTC
# TRUMP_NXT
# TRUMP_POSW
# TRUMP_REP
# TRUMP_RUR
# TRUMP_USD
# TRUMP_USDT
# TRUMP_XMR
# TRUMP_ZEC
# TSE_BTC
# TSE_DASH
# TSE_DOGE
# TSE_ETC
# TSE_ETH
# TSE_EUR
# TSE_LTC
# TSE_NXT
# TSE_POSW
# TSE_REP
# TSE_RUR
# TSE_USD
# TSE_USDT
# TSE_XMR
# TSE_ZEC
# TX_BTC
# TX_DASH
# TX_DOGE
# TX_ETC
# TX_ETH
# TX_EUR
# TX_LTC
# TX_NXT
# TX_POSW
# TX_REP
# TX_RUR
# TX_USD
# TX_USDT
# TX_XMR
# TX_ZEC
# U_BTC
# U_DASH
# U_DOGE
# U_ETC
# U_ETH
# U_EUR
# U_LTC
# U_NXT
# U_POSW
# U_REP
# U_RUR
# U_USD
# U_USDT
# U_XMR
# U_ZEC
# UNC_BTC
# UNC_DASH
# UNC_DOGE
# UNC_ETC
# UNC_ETH
# UNC_EUR
# UNC_LTC
# UNC_NXT
# UNC_POSW
# UNC_REP
# UNC_RUR
# UNC_USD
# UNC_USDT
# UNC_XMR
# UNC_ZEC
# UNO_BTC
# UNO_DASH
# UNO_DOGE
# UNO_ETC
# UNO_ETH
# UNO_EUR
# UNO_LTC
# UNO_NXT
# UNO_POSW
# UNO_REP
# UNO_RUR
# UNO_USD
# UNO_USDT
# UNO_XMR
# UNO_ZEC
# UNY_BTC
# UNY_DASH
# UNY_DOGE
# UNY_ETC
# UNY_ETH
# UNY_EUR
# UNY_LTC
# UNY_NXT
# UNY_POSW
# UNY_REP
# UNY_RUR
# UNY_USD
# UNY_USDT
# UNY_XMR
# UNY_ZEC
# USD_1ST
# USD_2GIVE
# USD_8BIT
# USD_ABY
# USD_ACP
# USD_ADCN
# USD_ADZ
# USD_AEON
# USD_AIB
# USD_AMP
# USD_ARC
# USD_ARDR
# USD_AUR
# USD_BASH
# USD_BAY
# USD_BCC
# USD_BCN
# USD_BCY
# USD_BHC
# USD_BIOS
# USD_BIT
# USD_BITB
# USD_BLK
# USD_BLU
# USD_BPC
# USD_BSD
# USD_BTA
# USD_BTC
# USD_BTC
# USD_BTCD
# USD_BTS
# USD_BURST
# USD_CANN
# USD_CCRB
# USD_CJ
# USD_CLAM
# USD_CLOAK
# USD_CLUB
# USD_CNT
# USD_CPC
# USD_CREVA
# USD_CRW
# USD_CURE
# USD_DASH
# USD_DASH
# USD_DCR
# USD_DCT
# USD_DGB
# USD_DGD
# USD_DIME
# USD_DOGE
# USD_DOGE
# USD_DRACO
# USD_DRZ
# USD_DSH
# USD_ECN
# USD_EGC
# USD_EL
# USD_ELE
# USD_EMC
# USD_EMC2
# USD_ENT
# USD_ETC
# USD_ETC
# USD_ETH
# USD_ETH
# USD_EUR
# USD_EUR
# USD_EXP
# USD_FCT
# USD_FJC
# USD_FRST
# USD_GAME
# USD_GB
# USD_GCR
# USD_GEO
# USD_GHS
# USD_GLD
# USD_GNO
# USD_GNT
# USD_GOLOS
# USD_GRC
# USD_GUP
# USD_HCC
# USD_HXX
# USD_ICN
# USD_INCNT
# USD_INFX
# USD_IOC
# USD_ION
# USD_IOP
# USD_ISL
# USD_ITI
# USD_JWL
# USD_KC
# USD_LBC
# USD_LEO
# USD_LEPEN
# USD_LSK
# USD_LTC
# USD_LTC
# USD_LTCR
# USD_LTS
# USD_LUN
# USD_LUNA
# USD_MAID
# USD_MLN
# USD_MOIN
# USD_MOJO
# USD_MONA
# USD_MSCN
# USD_MUE
# USD_NAUT
# USD_NAV
# USD_NLG
# USD_NMC
# USD_NOTE
# USD_NVC
# USD_NXC
# USD_NXT
# USD_NXT
# USD_OD
# USD_OK
# USD_OMNI
# USD_OTX
# USD_PINK
# USD_PIVX
# USD_PKB
# USD_POST
# USD_POSW
# USD_POSW
# USD_PPC
# USD_PRES
# USD_PROC
# USD_PSB
# USD_RADS
# USD_RBIES
# USD_RDD
# USD_REE
# USD_REP
# USD_REP
# USD_RIDE
# USD_RISE
# USD_RLC
# USD_ROYAL
# USD_RUB
# USD_RUR
# USD_RUR
# USD_SBD
# USD_SC
# USD_SHIFT
# USD_SIB
# USD_SLR
# USD_SLS
# USD_SNGLS
# USD_SNRG
# USD_SOAR
# USD_SONG
# USD_SPR
# USD_START
# USD_STEEM
# USD_STRAT
# USD_SWT
# USD_SXC
# USD_SYNX
# USD_SYS
# USD_TAAS
# USD_TIME
# USD_TKN
# USD_TLE
# USD_TRST
# USD_TRUMP
# USD_TSE
# USD_TX
# USD_U
# USD_UNC
# USD_UNO
# USD_UNY
# USD_USD
# USD_USD
# USD_USDT
# USD_USDT
# USD_VEC2
# USD_VIA
# USD_VOX
# USD_VRC
# USD_VRM
# USD_VRS
# USD_VTC
# USD_WAVES
# USD_WINGS
# USD_XAUR
# USD_XBY
# USD_XDN
# USD_XEM
# USD_XHI
# USD_XLM
# USD_XMR
# USD_XMR
# USD_XMS
# USD_XRP
# USD_XSPEC
# USD_XTO
# USD_XVC
# USD_XVG
# USD_YOC
# USD_ZCL
# USD_ZEC
# USD_ZEC
# USD_ZENI
# USDT_1ST
# USDT_2GIVE
# USDT_8BIT
# USDT_ABY
# USDT_ACP
# USDT_ADCN
# USDT_ADZ
# USDT_AEON
# USDT_AIB
# USDT_AMP
# USDT_ARC
# USDT_ARDR
# USDT_AUR
# USDT_BASH
# USDT_BAY
# USDT_BCC
# USDT_BCN
# USDT_BCY
# USDT_BHC
# USDT_BIOS
# USDT_BIT
# USDT_BITB
# USDT_BLK
# USDT_BLU
# USDT_BPC
# USDT_BSD
# USDT_BTA
# USDT_BTC
# USDT_BTC
# USDT_BTCD
# USDT_BTS
# USDT_BURST
# USDT_CANN
# USDT_CCRB
# USDT_CJ
# USDT_CLAM
# USDT_CLOAK
# USDT_CLUB
# USDT_CNT
# USDT_CPC
# USDT_CREVA
# USDT_CRW
# USDT_CURE
# USDT_DASH
# USDT_DASH
# USDT_DCR
# USDT_DCT
# USDT_DGB
# USDT_DGD
# USDT_DIME
# USDT_DOGE
# USDT_DOGE
# USDT_DRACO
# USDT_DRZ
# USDT_DSH
# USDT_ECN
# USDT_EGC
# USDT_EL
# USDT_ELE
# USDT_EMC
# USDT_EMC2
# USDT_ENT
# USDT_ETC
# USDT_ETC
# USDT_ETH
# USDT_ETH
# USDT_EUR
# USDT_EUR
# USDT_EXP
# USDT_FCT
# USDT_FJC
# USDT_FRST
# USDT_GAME
# USDT_GB
# USDT_GCR
# USDT_GEO
# USDT_GHS
# USDT_GLD
# USDT_GNO
# USDT_GNT
# USDT_GOLOS
# USDT_GRC
# USDT_GUP
# USDT_HCC
# USDT_HXX
# USDT_ICN
# USDT_INCNT
# USDT_INFX
# USDT_IOC
# USDT_ION
# USDT_IOP
# USDT_ISL
# USDT_ITI
# USDT_JWL
# USDT_KC
# USDT_LBC
# USDT_LEO
# USDT_LEPEN
# USDT_LSK
# USDT_LTC
# USDT_LTC
# USDT_LTCR
# USDT_LTS
# USDT_LUN
# USDT_LUNA
# USDT_MAID
# USDT_MLN
# USDT_MOIN
# USDT_MOJO
# USDT_MONA
# USDT_MSCN
# USDT_MUE
# USDT_NAUT
# USDT_NAV
# USDT_NLG
# USDT_NMC
# USDT_NOTE
# USDT_NVC
# USDT_NXC
# USDT_NXT
# USDT_NXT
# USDT_OD
# USDT_OK
# USDT_OMNI
# USDT_OTX
# USDT_PINK
# USDT_PIVX
# USDT_PKB
# USDT_POST
# USDT_POSW
# USDT_POSW
# USDT_PPC
# USDT_PRES
# USDT_PROC
# USDT_PSB
# USDT_RADS
# USDT_RBIES
# USDT_RDD
# USDT_REE
# USDT_REP
# USDT_REP
# USDT_RIDE
# USDT_RISE
# USDT_RLC
# USDT_ROYAL
# USDT_RUB
# USDT_RUR
# USDT_RUR
# USDT_SBD
# USDT_SC
# USDT_SHIFT
# USDT_SIB
# USDT_SLR
# USDT_SLS
# USDT_SNGLS
# USDT_SNRG
# USDT_SOAR
# USDT_SONG
# USDT_SPR
# USDT_START
# USDT_STEEM
# USDT_STRAT
# USDT_SWT
# USDT_SXC
# USDT_SYNX
# USDT_SYS
# USDT_TAAS
# USDT_TIME
# USDT_TKN
# USDT_TLE
# USDT_TRST
# USDT_TRUMP
# USDT_TSE
# USDT_TX
# USDT_U
# USDT_UNC
# USDT_UNO
# USDT_UNY
# USDT_USD
# USDT_USD
# USDT_USDT
# USDT_USDT
# USDT_VEC2
# USDT_VIA
# USDT_VOX
# USDT_VRC
# USDT_VRM
# USDT_VRS
# USDT_VTC
# USDT_WAVES
# USDT_WINGS
# USDT_XAUR
# USDT_XBY
# USDT_XDN
# USDT_XEM
# USDT_XHI
# USDT_XLM
# USDT_XMR
# USDT_XMR
# USDT_XMS
# USDT_XRP
# USDT_XSPEC
# USDT_XTO
# USDT_XVC
# USDT_XVG
# USDT_YOC
# USDT_ZCL
# USDT_ZEC
# USDT_ZEC
# USDT_ZENI
# VEC2_BTC
# VEC2_DASH
# VEC2_DOGE
# VEC2_ETC
# VEC2_ETH
# VEC2_EUR
# VEC2_LTC
# VEC2_NXT
# VEC2_POSW
# VEC2_REP
# VEC2_RUR
# VEC2_USD
# VEC2_USDT
# VEC2_XMR
# VEC2_ZEC
# VIA_BTC
# VIA_DASH
# VIA_DOGE
# VIA_ETC
# VIA_ETH
# VIA_EUR
# VIA_LTC
# VIA_NXT
# VIA_POSW
# VIA_REP
# VIA_RUR
# VIA_USD
# VIA_USDT
# VIA_XMR
# VIA_ZEC
# VOX_BTC
# VOX_DASH
# VOX_DOGE
# VOX_ETC
# VOX_ETH
# VOX_EUR
# VOX_LTC
# VOX_NXT
# VOX_POSW
# VOX_REP
# VOX_RUR
# VOX_USD
# VOX_USDT
# VOX_XMR
# VOX_ZEC
# VRC_BTC
# VRC_DASH
# VRC_DOGE
# VRC_ETC
# VRC_ETH
# VRC_EUR
# VRC_LTC
# VRC_NXT
# VRC_POSW
# VRC_REP
# VRC_RUR
# VRC_USD
# VRC_USDT
# VRC_XMR
# VRC_ZEC
# VRM_BTC
# VRM_DASH
# VRM_DOGE
# VRM_ETC
# VRM_ETH
# VRM_EUR
# VRM_LTC
# VRM_NXT
# VRM_POSW
# VRM_REP
# VRM_RUR
# VRM_USD
# VRM_USDT
# VRM_XMR
# VRM_ZEC
# VRS_BTC
# VRS_DASH
# VRS_DOGE
# VRS_ETC
# VRS_ETH
# VRS_EUR
# VRS_LTC
# VRS_NXT
# VRS_POSW
# VRS_REP
# VRS_RUR
# VRS_USD
# VRS_USDT
# VRS_XMR
# VRS_ZEC
# VTC_BTC
# VTC_DASH
# VTC_DOGE
# VTC_ETC
# VTC_ETH
# VTC_EUR
# VTC_LTC
# VTC_NXT
# VTC_POSW
# VTC_REP
# VTC_RUR
# VTC_USD
# VTC_USDT
# VTC_XMR
# VTC_ZEC
# WAVES_BTC
# WAVES_DASH
# WAVES_DOGE
# WAVES_ETC
# WAVES_ETH
# WAVES_EUR
# WAVES_LTC
# WAVES_NXT
# WAVES_POSW
# WAVES_REP
# WAVES_RUR
# WAVES_USD
# WAVES_USDT
# WAVES_XMR
# WAVES_ZEC
# WINGS_BTC
# WINGS_DASH
# WINGS_DOGE
# WINGS_ETC
# WINGS_ETH
# WINGS_EUR
# WINGS_LTC
# WINGS_NXT
# WINGS_POSW
# WINGS_REP
# WINGS_RUR
# WINGS_USD
# WINGS_USDT
# WINGS_XMR
# WINGS_ZEC
# XAUR_BTC
# XAUR_DASH
# XAUR_DOGE
# XAUR_ETC
# XAUR_ETH
# XAUR_EUR
# XAUR_LTC
# XAUR_NXT
# XAUR_POSW
# XAUR_REP
# XAUR_RUR
# XAUR_USD
# XAUR_USDT
# XAUR_XMR
# XAUR_ZEC
# XBY_BTC
# XBY_DASH
# XBY_DOGE
# XBY_ETC
# XBY_ETH
# XBY_EUR
# XBY_LTC
# XBY_NXT
# XBY_POSW
# XBY_REP
# XBY_RUR
# XBY_USD
# XBY_USDT
# XBY_XMR
# XBY_ZEC
# XDN_BTC
# XDN_DASH
# XDN_DOGE
# XDN_ETC
# XDN_ETH
# XDN_EUR
# XDN_LTC
# XDN_NXT
# XDN_POSW
# XDN_REP
# XDN_RUR
# XDN_USD
# XDN_USDT
# XDN_XMR
# XDN_ZEC
# XEM_BTC
# XEM_DASH
# XEM_DOGE
# XEM_ETC
# XEM_ETH
# XEM_EUR
# XEM_LTC
# XEM_NXT
# XEM_POSW
# XEM_REP
# XEM_RUR
# XEM_USD
# XEM_USDT
# XEM_XMR
# XEM_ZEC
# XHI_BTC
# XHI_DASH
# XHI_DOGE
# XHI_ETC
# XHI_ETH
# XHI_EUR
# XHI_LTC
# XHI_NXT
# XHI_POSW
# XHI_REP
# XHI_RUR
# XHI_USD
# XHI_USDT
# XHI_XMR
# XHI_ZEC
# XLM_BTC
# XLM_DASH
# XLM_DOGE
# XLM_ETC
# XLM_ETH
# XLM_EUR
# XLM_LTC
# XLM_NXT
# XLM_POSW
# XLM_REP
# XLM_RUR
# XLM_USD
# XLM_USDT
# XLM_XMR
# XLM_ZEC
# XMR_1ST
# XMR_2GIVE
# XMR_8BIT
# XMR_ABY
# XMR_ACP
# XMR_ADCN
# XMR_ADZ
# XMR_AEON
# XMR_AIB
# XMR_AMP
# XMR_ARC
# XMR_ARDR
# XMR_AUR
# XMR_BASH
# XMR_BAY
# XMR_BCC
# XMR_BCN
# XMR_BCY
# XMR_BHC
# XMR_BIOS
# XMR_BIT
# XMR_BITB
# XMR_BLK
# XMR_BLU
# XMR_BPC
# XMR_BSD
# XMR_BTA
# XMR_BTC
# XMR_BTC
# XMR_BTCD
# XMR_BTS
# XMR_BURST
# XMR_CANN
# XMR_CCRB
# XMR_CJ
# XMR_CLAM
# XMR_CLOAK
# XMR_CLUB
# XMR_CNT
# XMR_CPC
# XMR_CREVA
# XMR_CRW
# XMR_CURE
# XMR_DASH
# XMR_DASH
# XMR_DCR
# XMR_DCT
# XMR_DGB
# XMR_DGD
# XMR_DIME
# XMR_DOGE
# XMR_DOGE
# XMR_DRACO
# XMR_DRZ
# XMR_DSH
# XMR_ECN
# XMR_EGC
# XMR_EL
# XMR_ELE
# XMR_EMC
# XMR_EMC2
# XMR_ENT
# XMR_ETC
# XMR_ETC
# XMR_ETH
# XMR_ETH
# XMR_EUR
# XMR_EUR
# XMR_EXP
# XMR_FCT
# XMR_FJC
# XMR_FRST
# XMR_GAME
# XMR_GB
# XMR_GCR
# XMR_GEO
# XMR_GHS
# XMR_GLD
# XMR_GNO
# XMR_GNT
# XMR_GOLOS
# XMR_GRC
# XMR_GUP
# XMR_HCC
# XMR_HXX
# XMR_ICN
# XMR_INCNT
# XMR_INFX
# XMR_IOC
# XMR_ION
# XMR_IOP
# XMR_ISL
# XMR_ITI
# XMR_JWL
# XMR_KC
# XMR_LBC
# XMR_LEO
# XMR_LEPEN
# XMR_LSK
# XMR_LTC
# XMR_LTC
# XMR_LTCR
# XMR_LTS
# XMR_LUN
# XMR_LUNA
# XMR_MAID
# XMR_MLN
# XMR_MOIN
# XMR_MOJO
# XMR_MONA
# XMR_MSCN
# XMR_MUE
# XMR_NAUT
# XMR_NAV
# XMR_NLG
# XMR_NMC
# XMR_NOTE
# XMR_NVC
# XMR_NXC
# XMR_NXT
# XMR_NXT
# XMR_OD
# XMR_OK
# XMR_OMNI
# XMR_OTX
# XMR_PINK
# XMR_PIVX
# XMR_PKB
# XMR_POST
# XMR_POSW
# XMR_POSW
# XMR_PPC
# XMR_PRES
# XMR_PROC
# XMR_PSB
# XMR_RADS
# XMR_RBIES
# XMR_RDD
# XMR_REE
# XMR_REP
# XMR_REP
# XMR_RIDE
# XMR_RISE
# XMR_RLC
# XMR_ROYAL
# XMR_RUB
# XMR_RUR
# XMR_RUR
# XMR_SBD
# XMR_SC
# XMR_SHIFT
# XMR_SIB
# XMR_SLR
# XMR_SLS
# XMR_SNGLS
# XMR_SNRG
# XMR_SOAR
# XMR_SONG
# XMR_SPR
# XMR_START
# XMR_STEEM
# XMR_STRAT
# XMR_SWT
# XMR_SXC
# XMR_SYNX
# XMR_SYS
# XMR_TAAS
# XMR_TIME
# XMR_TKN
# XMR_TLE
# XMR_TRST
# XMR_TRUMP
# XMR_TSE
# XMR_TX
# XMR_U
# XMR_UNC
# XMR_UNO
# XMR_UNY
# XMR_USD
# XMR_USD
# XMR_USDT
# XMR_USDT
# XMR_VEC2
# XMR_VIA
# XMR_VOX
# XMR_VRC
# XMR_VRM
# XMR_VRS
# XMR_VTC
# XMR_WAVES
# XMR_WINGS
# XMR_XAUR
# XMR_XBY
# XMR_XDN
# XMR_XEM
# XMR_XHI
# XMR_XLM
# XMR_XMR
# XMR_XMR
# XMR_XMS
# XMR_XRP
# XMR_XSPEC
# XMR_XTO
# XMR_XVC
# XMR_XVG
# XMR_YOC
# XMR_ZCL
# XMR_ZEC
# XMR_ZEC
# XMR_ZENI
# XMS_BTC
# XMS_DASH
# XMS_DOGE
# XMS_ETC
# XMS_ETH
# XMS_EUR
# XMS_LTC
# XMS_NXT
# XMS_POSW
# XMS_REP
# XMS_RUR
# XMS_USD
# XMS_USDT
# XMS_XMR
# XMS_ZEC
# XRP_BTC
# XRP_DASH
# XRP_DOGE
# XRP_ETC
# XRP_ETH
# XRP_EUR
# XRP_LTC
# XRP_NXT
# XRP_POSW
# XRP_REP
# XRP_RUR
# XRP_USD
# XRP_USDT
# XRP_XMR
# XRP_ZEC
# XSPEC_BTC
# XSPEC_DASH
# XSPEC_DOGE
# XSPEC_ETC
# XSPEC_ETH
# XSPEC_EUR
# XSPEC_LTC
# XSPEC_NXT
# XSPEC_POSW
# XSPEC_REP
# XSPEC_RUR
# XSPEC_USD
# XSPEC_USDT
# XSPEC_XMR
# XSPEC_ZEC
# XTO_BTC
# XTO_DASH
# XTO_DOGE
# XTO_ETC
# XTO_ETH
# XTO_EUR
# XTO_LTC
# XTO_NXT
# XTO_POSW
# XTO_REP
# XTO_RUR
# XTO_USD
# XTO_USDT
# XTO_XMR
# XTO_ZEC
# XVC_BTC
# XVC_DASH
# XVC_DOGE
# XVC_ETC
# XVC_ETH
# XVC_EUR
# XVC_LTC
# XVC_NXT
# XVC_POSW
# XVC_REP
# XVC_RUR
# XVC_USD
# XVC_USDT
# XVC_XMR
# XVC_ZEC
# XVG_BTC
# XVG_DASH
# XVG_DOGE
# XVG_ETC
# XVG_ETH
# XVG_EUR
# XVG_LTC
# XVG_NXT
# XVG_POSW
# XVG_REP
# XVG_RUR
# XVG_USD
# XVG_USDT
# XVG_XMR
# XVG_ZEC
# YOC_BTC
# YOC_DASH
# YOC_DOGE
# YOC_ETC
# YOC_ETH
# YOC_EUR
# YOC_LTC
# YOC_NXT
# YOC_POSW
# YOC_REP
# YOC_RUR
# YOC_USD
# YOC_USDT
# YOC_XMR
# YOC_ZEC
# ZCL_BTC
# ZCL_DASH
# ZCL_DOGE
# ZCL_ETC
# ZCL_ETH
# ZCL_EUR
# ZCL_LTC
# ZCL_NXT
# ZCL_POSW
# ZCL_REP
# ZCL_RUR
# ZCL_USD
# ZCL_USDT
# ZCL_XMR
# ZCL_ZEC
# ZEC_1ST
# ZEC_2GIVE
# ZEC_8BIT
# ZEC_ABY
# ZEC_ACP
# ZEC_ADCN
# ZEC_ADZ
# ZEC_AEON
# ZEC_AIB
# ZEC_AMP
# ZEC_ARC
# ZEC_ARDR
# ZEC_AUR
# ZEC_BASH
# ZEC_BAY
# ZEC_BCC
# ZEC_BCN
# ZEC_BCY
# ZEC_BHC
# ZEC_BIOS
# ZEC_BIT
# ZEC_BITB
# ZEC_BLK
# ZEC_BLU
# ZEC_BPC
# ZEC_BSD
# ZEC_BTA
# ZEC_BTC
# ZEC_BTC
# ZEC_BTCD
# ZEC_BTS
# ZEC_BURST
# ZEC_CANN
# ZEC_CCRB
# ZEC_CJ
# ZEC_CLAM
# ZEC_CLOAK
# ZEC_CLUB
# ZEC_CNT
# ZEC_CPC
# ZEC_CREVA
# ZEC_CRW
# ZEC_CURE
# ZEC_DASH
# ZEC_DASH
# ZEC_DCR
# ZEC_DCT
# ZEC_DGB
# ZEC_DGD
# ZEC_DIME
# ZEC_DOGE
# ZEC_DOGE
# ZEC_DRACO
# ZEC_DRZ
# ZEC_DSH
# ZEC_ECN
# ZEC_EGC
# ZEC_EL
# ZEC_ELE
# ZEC_EMC
# ZEC_EMC2
# ZEC_ENT
# ZEC_ETC
# ZEC_ETC
# ZEC_ETH
# ZEC_ETH
# ZEC_EUR
# ZEC_EUR
# ZEC_EXP
# ZEC_FCT
# ZEC_FJC
# ZEC_FRST
# ZEC_GAME
# ZEC_GB
# ZEC_GCR
# ZEC_GEO
# ZEC_GHS
# ZEC_GLD
# ZEC_GNO
# ZEC_GNT
# ZEC_GOLOS
# ZEC_GRC
# ZEC_GUP
# ZEC_HCC
# ZEC_HXX
# ZEC_ICN
# ZEC_INCNT
# ZEC_INFX
# ZEC_IOC
# ZEC_ION
# ZEC_IOP
# ZEC_ISL
# ZEC_ITI
# ZEC_JWL
# ZEC_KC
# ZEC_LBC
# ZEC_LEO
# ZEC_LEPEN
# ZEC_LSK
# ZEC_LTC
# ZEC_LTC
# ZEC_LTCR
# ZEC_LTS
# ZEC_LUN
# ZEC_LUNA
# ZEC_MAID
# ZEC_MLN
# ZEC_MOIN
# ZEC_MOJO
# ZEC_MONA
# ZEC_MSCN
# ZEC_MUE
# ZEC_NAUT
# ZEC_NAV
# ZEC_NLG
# ZEC_NMC
# ZEC_NOTE
# ZEC_NVC
# ZEC_NXC
# ZEC_NXT
# ZEC_NXT
# ZEC_OD
# ZEC_OK
# ZEC_OMNI
# ZEC_OTX
# ZEC_PINK
# ZEC_PIVX
# ZEC_PKB
# ZEC_POST
# ZEC_POSW
# ZEC_POSW
# ZEC_PPC
# ZEC_PRES
# ZEC_PROC
# ZEC_PSB
# ZEC_RADS
# ZEC_RBIES
# ZEC_RDD
# ZEC_REE
# ZEC_REP
# ZEC_REP
# ZEC_RIDE
# ZEC_RISE
# ZEC_RLC
# ZEC_ROYAL
# ZEC_RUB
# ZEC_RUR
# ZEC_RUR
# ZEC_SBD
# ZEC_SC
# ZEC_SHIFT
# ZEC_SIB
# ZEC_SLR
# ZEC_SLS
# ZEC_SNGLS
# ZEC_SNRG
# ZEC_SOAR
# ZEC_SONG
# ZEC_SPR
# ZEC_START
# ZEC_STEEM
# ZEC_STRAT
# ZEC_SWT
# ZEC_SXC
# ZEC_SYNX
# ZEC_SYS
# ZEC_TAAS
# ZEC_TIME
# ZEC_TKN
# ZEC_TLE
# ZEC_TRST
# ZEC_TRUMP
# ZEC_TSE
# ZEC_TX
# ZEC_U
# ZEC_UNC
# ZEC_UNO
# ZEC_UNY
# ZEC_USD
# ZEC_USD
# ZEC_USDT
# ZEC_USDT
# ZEC_VEC2
# ZEC_VIA
# ZEC_VOX
# ZEC_VRC
# ZEC_VRM
# ZEC_VRS
# ZEC_VTC
# ZEC_WAVES
# ZEC_WINGS
# ZEC_XAUR
# ZEC_XBY
# ZEC_XDN
# ZEC_XEM
# ZEC_XHI
# ZEC_XLM
# ZEC_XMR
# ZEC_XMR
# ZEC_XMS
# ZEC_XRP
# ZEC_XSPEC
# ZEC_XTO
# ZEC_XVC
# ZEC_XVG
# ZEC_YOC
# ZEC_ZCL
# ZEC_ZEC
# ZEC_ZEC
# ZEC_ZENI
# ZENI_BTC
# ZENI_DASH
# ZENI_DOGE
# ZENI_ETC
# ZENI_ETH
# ZENI_EUR
# ZENI_LTC
# ZENI_NXT
# ZENI_POSW
# ZENI_REP
# ZENI_RUR
# ZENI_USD
# ZENI_USDT
# ZENI_XMR
# ZENI_ZEC

# %%
#pos=0.25
#base_url="https://btc-e.nz/api/3/"

#for i in pairs:
#    ticker_url=base_url+"ticker/"+i.lower()
#    html_ticker=requests.get(ticker_url).text
#    ticker_data=json.loads(html_ticker)
   
#    print i, ticker_data
# Out:
# 1ST_BTC {u'success': 0, u'error': u'Invalid pair name: 1st_btc'}
# 1ST_DASH {u'success': 0, u'error': u'Invalid pair name: 1st_dash'}
# 1ST_DOGE {u'success': 0, u'error': u'Invalid pair name: 1st_doge'}
# 1ST_ETC {u'success': 0, u'error': u'Invalid pair name: 1st_etc'}
# 1ST_ETH {u'success': 0, u'error': u'Invalid pair name: 1st_eth'}
# 1ST_EUR {u'success': 0, u'error': u'Invalid pair name: 1st_eur'}
# 1ST_LTC {u'success': 0, u'error': u'Invalid pair name: 1st_ltc'}
# 1ST_NXT {u'success': 0, u'error': u'Invalid pair name: 1st_nxt'}
# 1ST_POSW {u'success': 0, u'error': u'Invalid pair name: 1st_posw'}
# 1ST_REP {u'success': 0, u'error': u'Invalid pair name: 1st_rep'}
# 1ST_RUR {u'success': 0, u'error': u'Invalid pair name: 1st_rur'}
# 1ST_USD {u'success': 0, u'error': u'Invalid pair name: 1st_usd'}
# 1ST_USDT {u'success': 0, u'error': u'Invalid pair name: 1st_usdt'}
# 1ST_XMR {u'success': 0, u'error': u'Invalid pair name: 1st_xmr'}
# 1ST_ZEC {u'success': 0, u'error': u'Invalid pair name: 1st_zec'}
# 2GIVE_BTC {u'success': 0, u'error': u'Invalid pair name: 2give_btc'}
# 2GIVE_DASH {u'success': 0, u'error': u'Invalid pair name: 2give_dash'}
# 2GIVE_DOGE {u'success': 0, u'error': u'Invalid pair name: 2give_doge'}
# 2GIVE_ETC {u'success': 0, u'error': u'Invalid pair name: 2give_etc'}
# 2GIVE_ETH {u'success': 0, u'error': u'Invalid pair name: 2give_eth'}
# 2GIVE_EUR {u'success': 0, u'error': u'Invalid pair name: 2give_eur'}
# 2GIVE_LTC {u'success': 0, u'error': u'Invalid pair name: 2give_ltc'}
# 2GIVE_NXT {u'success': 0, u'error': u'Invalid pair name: 2give_nxt'}
# 2GIVE_POSW {u'success': 0, u'error': u'Invalid pair name: 2give_posw'}
# 2GIVE_REP {u'success': 0, u'error': u'Invalid pair name: 2give_rep'}
# 2GIVE_RUR {u'success': 0, u'error': u'Invalid pair name: 2give_rur'}
# 2GIVE_USD {u'success': 0, u'error': u'Invalid pair name: 2give_usd'}
# 2GIVE_USDT {u'success': 0, u'error': u'Invalid pair name: 2give_usdt'}
# 2GIVE_XMR {u'success': 0, u'error': u'Invalid pair name: 2give_xmr'}
# 2GIVE_ZEC {u'success': 0, u'error': u'Invalid pair name: 2give_zec'}
# 8BIT_BTC {u'success': 0, u'error': u'Invalid pair name: 8bit_btc'}
# 8BIT_DASH {u'success': 0, u'error': u'Invalid pair name: 8bit_dash'}
# 8BIT_DOGE {u'success': 0, u'error': u'Invalid pair name: 8bit_doge'}
# 8BIT_ETC {u'success': 0, u'error': u'Invalid pair name: 8bit_etc'}
# 8BIT_ETH {u'success': 0, u'error': u'Invalid pair name: 8bit_eth'}
# 8BIT_EUR {u'success': 0, u'error': u'Invalid pair name: 8bit_eur'}
# 8BIT_LTC {u'success': 0, u'error': u'Invalid pair name: 8bit_ltc'}
# 8BIT_NXT {u'success': 0, u'error': u'Invalid pair name: 8bit_nxt'}
# 8BIT_POSW {u'success': 0, u'error': u'Invalid pair name: 8bit_posw'}
# 8BIT_REP {u'success': 0, u'error': u'Invalid pair name: 8bit_rep'}
# 8BIT_RUR {u'success': 0, u'error': u'Invalid pair name: 8bit_rur'}
# 8BIT_USD {u'success': 0, u'error': u'Invalid pair name: 8bit_usd'}
# 8BIT_USDT {u'success': 0, u'error': u'Invalid pair name: 8bit_usdt'}
# 8BIT_XMR {u'success': 0, u'error': u'Invalid pair name: 8bit_xmr'}
# 8BIT_ZEC {u'success': 0, u'error': u'Invalid pair name: 8bit_zec'}
# ABY_BTC {u'success': 0, u'error': u'Invalid pair name: aby_btc'}
# ABY_DASH {u'success': 0, u'error': u'Invalid pair name: aby_dash'}
# ABY_DOGE {u'success': 0, u'error': u'Invalid pair name: aby_doge'}
# ABY_ETC {u'success': 0, u'error': u'Invalid pair name: aby_etc'}
# ABY_ETH {u'success': 0, u'error': u'Invalid pair name: aby_eth'}
# ABY_EUR {u'success': 0, u'error': u'Invalid pair name: aby_eur'}
# ABY_LTC {u'success': 0, u'error': u'Invalid pair name: aby_ltc'}
# ABY_NXT {u'success': 0, u'error': u'Invalid pair name: aby_nxt'}
# ABY_POSW {u'success': 0, u'error': u'Invalid pair name: aby_posw'}
# ABY_REP {u'success': 0, u'error': u'Invalid pair name: aby_rep'}
# ABY_RUR {u'success': 0, u'error': u'Invalid pair name: aby_rur'}
# ABY_USD {u'success': 0, u'error': u'Invalid pair name: aby_usd'}
# ABY_USDT {u'success': 0, u'error': u'Invalid pair name: aby_usdt'}
# ABY_XMR {u'success': 0, u'error': u'Invalid pair name: aby_xmr'}
# ABY_ZEC {u'success': 0, u'error': u'Invalid pair name: aby_zec'}
# ACP_BTC {u'success': 0, u'error': u'Invalid pair name: acp_btc'}
# ACP_DASH {u'success': 0, u'error': u'Invalid pair name: acp_dash'}
# ACP_DOGE {u'success': 0, u'error': u'Invalid pair name: acp_doge'}
# ACP_ETC {u'success': 0, u'error': u'Invalid pair name: acp_etc'}
# ACP_ETH {u'success': 0, u'error': u'Invalid pair name: acp_eth'}
# ACP_EUR {u'success': 0, u'error': u'Invalid pair name: acp_eur'}
# ACP_LTC {u'success': 0, u'error': u'Invalid pair name: acp_ltc'}
# ACP_NXT {u'success': 0, u'error': u'Invalid pair name: acp_nxt'}
# ACP_POSW {u'success': 0, u'error': u'Invalid pair name: acp_posw'}
# ACP_REP {u'success': 0, u'error': u'Invalid pair name: acp_rep'}
# ACP_RUR {u'success': 0, u'error': u'Invalid pair name: acp_rur'}
# ACP_USD {u'success': 0, u'error': u'Invalid pair name: acp_usd'}
# ACP_USDT {u'success': 0, u'error': u'Invalid pair name: acp_usdt'}
# ACP_XMR {u'success': 0, u'error': u'Invalid pair name: acp_xmr'}
# ACP_ZEC {u'success': 0, u'error': u'Invalid pair name: acp_zec'}
# ADCN_BTC {u'success': 0, u'error': u'Invalid pair name: adcn_btc'}
# ADCN_DASH {u'success': 0, u'error': u'Invalid pair name: adcn_dash'}
# ADCN_DOGE {u'success': 0, u'error': u'Invalid pair name: adcn_doge'}
# ADCN_ETC {u'success': 0, u'error': u'Invalid pair name: adcn_etc'}
# ADCN_ETH {u'success': 0, u'error': u'Invalid pair name: adcn_eth'}
# ADCN_EUR {u'success': 0, u'error': u'Invalid pair name: adcn_eur'}
# ADCN_LTC {u'success': 0, u'error': u'Invalid pair name: adcn_ltc'}
# ADCN_NXT {u'success': 0, u'error': u'Invalid pair name: adcn_nxt'}
# ADCN_POSW {u'success': 0, u'error': u'Invalid pair name: adcn_posw'}
# ADCN_REP {u'success': 0, u'error': u'Invalid pair name: adcn_rep'}
# ADCN_RUR {u'success': 0, u'error': u'Invalid pair name: adcn_rur'}
# ADCN_USD {u'success': 0, u'error': u'Invalid pair name: adcn_usd'}
# ADCN_USDT {u'success': 0, u'error': u'Invalid pair name: adcn_usdt'}
# ADCN_XMR {u'success': 0, u'error': u'Invalid pair name: adcn_xmr'}
# ADCN_ZEC {u'success': 0, u'error': u'Invalid pair name: adcn_zec'}
# ADZ_BTC {u'success': 0, u'error': u'Invalid pair name: adz_btc'}
# ADZ_DASH {u'success': 0, u'error': u'Invalid pair name: adz_dash'}
# ADZ_DOGE {u'success': 0, u'error': u'Invalid pair name: adz_doge'}
# ADZ_ETC {u'success': 0, u'error': u'Invalid pair name: adz_etc'}
# ADZ_ETH {u'success': 0, u'error': u'Invalid pair name: adz_eth'}
# ADZ_EUR {u'success': 0, u'error': u'Invalid pair name: adz_eur'}
# ADZ_LTC {u'success': 0, u'error': u'Invalid pair name: adz_ltc'}
# ADZ_NXT {u'success': 0, u'error': u'Invalid pair name: adz_nxt'}
# ADZ_POSW {u'success': 0, u'error': u'Invalid pair name: adz_posw'}
# ADZ_REP {u'success': 0, u'error': u'Invalid pair name: adz_rep'}
# ADZ_RUR {u'success': 0, u'error': u'Invalid pair name: adz_rur'}
# ADZ_USD {u'success': 0, u'error': u'Invalid pair name: adz_usd'}
# ADZ_USDT {u'success': 0, u'error': u'Invalid pair name: adz_usdt'}
# ADZ_XMR {u'success': 0, u'error': u'Invalid pair name: adz_xmr'}
# ADZ_ZEC {u'success': 0, u'error': u'Invalid pair name: adz_zec'}
# AEON_BTC {u'success': 0, u'error': u'Invalid pair name: aeon_btc'}
# AEON_DASH {u'success': 0, u'error': u'Invalid pair name: aeon_dash'}
# AEON_DOGE {u'success': 0, u'error': u'Invalid pair name: aeon_doge'}
# AEON_ETC {u'success': 0, u'error': u'Invalid pair name: aeon_etc'}
# AEON_ETH {u'success': 0, u'error': u'Invalid pair name: aeon_eth'}
# AEON_EUR {u'success': 0, u'error': u'Invalid pair name: aeon_eur'}
# AEON_LTC {u'success': 0, u'error': u'Invalid pair name: aeon_ltc'}
# AEON_NXT {u'success': 0, u'error': u'Invalid pair name: aeon_nxt'}
# AEON_POSW {u'success': 0, u'error': u'Invalid pair name: aeon_posw'}
# AEON_REP {u'success': 0, u'error': u'Invalid pair name: aeon_rep'}
# AEON_RUR {u'success': 0, u'error': u'Invalid pair name: aeon_rur'}
# AEON_USD {u'success': 0, u'error': u'Invalid pair name: aeon_usd'}
# AEON_USDT {u'success': 0, u'error': u'Invalid pair name: aeon_usdt'}
# AEON_XMR {u'success': 0, u'error': u'Invalid pair name: aeon_xmr'}
# AEON_ZEC {u'success': 0, u'error': u'Invalid pair name: aeon_zec'}
# AIB_BTC {u'success': 0, u'error': u'Invalid pair name: aib_btc'}
# AIB_DASH {u'success': 0, u'error': u'Invalid pair name: aib_dash'}
# AIB_DOGE {u'success': 0, u'error': u'Invalid pair name: aib_doge'}
# AIB_ETC {u'success': 0, u'error': u'Invalid pair name: aib_etc'}
# AIB_ETH {u'success': 0, u'error': u'Invalid pair name: aib_eth'}
# AIB_EUR {u'success': 0, u'error': u'Invalid pair name: aib_eur'}
# AIB_LTC {u'success': 0, u'error': u'Invalid pair name: aib_ltc'}
# AIB_NXT {u'success': 0, u'error': u'Invalid pair name: aib_nxt'}
# AIB_POSW {u'success': 0, u'error': u'Invalid pair name: aib_posw'}
# AIB_REP {u'success': 0, u'error': u'Invalid pair name: aib_rep'}
# AIB_RUR {u'success': 0, u'error': u'Invalid pair name: aib_rur'}
# AIB_USD {u'success': 0, u'error': u'Invalid pair name: aib_usd'}
# AIB_USDT {u'success': 0, u'error': u'Invalid pair name: aib_usdt'}
# AIB_XMR {u'success': 0, u'error': u'Invalid pair name: aib_xmr'}
# AIB_ZEC {u'success': 0, u'error': u'Invalid pair name: aib_zec'}
# AMP_BTC {u'success': 0, u'error': u'Invalid pair name: amp_btc'}
# AMP_DASH {u'success': 0, u'error': u'Invalid pair name: amp_dash'}
# AMP_DOGE {u'success': 0, u'error': u'Invalid pair name: amp_doge'}
# AMP_ETC {u'success': 0, u'error': u'Invalid pair name: amp_etc'}
# AMP_ETH {u'success': 0, u'error': u'Invalid pair name: amp_eth'}
# AMP_EUR {u'success': 0, u'error': u'Invalid pair name: amp_eur'}
# AMP_LTC {u'success': 0, u'error': u'Invalid pair name: amp_ltc'}
# AMP_NXT {u'success': 0, u'error': u'Invalid pair name: amp_nxt'}
# AMP_POSW {u'success': 0, u'error': u'Invalid pair name: amp_posw'}
# AMP_REP {u'success': 0, u'error': u'Invalid pair name: amp_rep'}
# AMP_RUR {u'success': 0, u'error': u'Invalid pair name: amp_rur'}
# AMP_USD {u'success': 0, u'error': u'Invalid pair name: amp_usd'}
# AMP_USDT {u'success': 0, u'error': u'Invalid pair name: amp_usdt'}
# AMP_XMR {u'success': 0, u'error': u'Invalid pair name: amp_xmr'}
# AMP_ZEC {u'success': 0, u'error': u'Invalid pair name: amp_zec'}
# ARC_BTC {u'success': 0, u'error': u'Invalid pair name: arc_btc'}
# ARC_DASH {u'success': 0, u'error': u'Invalid pair name: arc_dash'}
# ARC_DOGE {u'success': 0, u'error': u'Invalid pair name: arc_doge'}
# ARC_ETC {u'success': 0, u'error': u'Invalid pair name: arc_etc'}
# ARC_ETH {u'success': 0, u'error': u'Invalid pair name: arc_eth'}
# ARC_EUR {u'success': 0, u'error': u'Invalid pair name: arc_eur'}
# ARC_LTC {u'success': 0, u'error': u'Invalid pair name: arc_ltc'}
# ARC_NXT {u'success': 0, u'error': u'Invalid pair name: arc_nxt'}
# ARC_POSW {u'success': 0, u'error': u'Invalid pair name: arc_posw'}
# ARC_REP {u'success': 0, u'error': u'Invalid pair name: arc_rep'}
# ARC_RUR {u'success': 0, u'error': u'Invalid pair name: arc_rur'}
# ARC_USD {u'success': 0, u'error': u'Invalid pair name: arc_usd'}
# ARC_USDT {u'success': 0, u'error': u'Invalid pair name: arc_usdt'}
# ARC_XMR {u'success': 0, u'error': u'Invalid pair name: arc_xmr'}
# ARC_ZEC {u'success': 0, u'error': u'Invalid pair name: arc_zec'}
# ARDR_BTC {u'success': 0, u'error': u'Invalid pair name: ardr_btc'}
# ARDR_DASH {u'success': 0, u'error': u'Invalid pair name: ardr_dash'}
# ARDR_DOGE {u'success': 0, u'error': u'Invalid pair name: ardr_doge'}
# ARDR_ETC {u'success': 0, u'error': u'Invalid pair name: ardr_etc'}
# ARDR_ETH {u'success': 0, u'error': u'Invalid pair name: ardr_eth'}
# ARDR_EUR {u'success': 0, u'error': u'Invalid pair name: ardr_eur'}
# ARDR_LTC {u'success': 0, u'error': u'Invalid pair name: ardr_ltc'}
# ARDR_NXT {u'success': 0, u'error': u'Invalid pair name: ardr_nxt'}
# ARDR_POSW {u'success': 0, u'error': u'Invalid pair name: ardr_posw'}
# ARDR_REP {u'success': 0, u'error': u'Invalid pair name: ardr_rep'}
# ARDR_RUR {u'success': 0, u'error': u'Invalid pair name: ardr_rur'}
# ARDR_USD {u'success': 0, u'error': u'Invalid pair name: ardr_usd'}
# ARDR_USDT {u'success': 0, u'error': u'Invalid pair name: ardr_usdt'}
# ARDR_XMR {u'success': 0, u'error': u'Invalid pair name: ardr_xmr'}
# ARDR_ZEC {u'success': 0, u'error': u'Invalid pair name: ardr_zec'}
# AUR_BTC {u'success': 0, u'error': u'Invalid pair name: aur_btc'}
# AUR_DASH {u'success': 0, u'error': u'Invalid pair name: aur_dash'}
# AUR_DOGE {u'success': 0, u'error': u'Invalid pair name: aur_doge'}
# AUR_ETC {u'success': 0, u'error': u'Invalid pair name: aur_etc'}
# AUR_ETH {u'success': 0, u'error': u'Invalid pair name: aur_eth'}
# AUR_EUR {u'success': 0, u'error': u'Invalid pair name: aur_eur'}
# AUR_LTC {u'success': 0, u'error': u'Invalid pair name: aur_ltc'}
# AUR_NXT {u'success': 0, u'error': u'Invalid pair name: aur_nxt'}
# AUR_POSW {u'success': 0, u'error': u'Invalid pair name: aur_posw'}
# AUR_REP {u'success': 0, u'error': u'Invalid pair name: aur_rep'}
# AUR_RUR {u'success': 0, u'error': u'Invalid pair name: aur_rur'}
# AUR_USD {u'success': 0, u'error': u'Invalid pair name: aur_usd'}
# AUR_USDT {u'success': 0, u'error': u'Invalid pair name: aur_usdt'}
# AUR_XMR {u'success': 0, u'error': u'Invalid pair name: aur_xmr'}
# AUR_ZEC {u'success': 0, u'error': u'Invalid pair name: aur_zec'}
# BASH_BTC {u'success': 0, u'error': u'Invalid pair name: bash_btc'}
# BASH_DASH {u'success': 0, u'error': u'Invalid pair name: bash_dash'}
# BASH_DOGE {u'success': 0, u'error': u'Invalid pair name: bash_doge'}
# BASH_ETC {u'success': 0, u'error': u'Invalid pair name: bash_etc'}
# BASH_ETH {u'success': 0, u'error': u'Invalid pair name: bash_eth'}
# BASH_EUR {u'success': 0, u'error': u'Invalid pair name: bash_eur'}
# BASH_LTC {u'success': 0, u'error': u'Invalid pair name: bash_ltc'}
# BASH_NXT {u'success': 0, u'error': u'Invalid pair name: bash_nxt'}
# BASH_POSW {u'success': 0, u'error': u'Invalid pair name: bash_posw'}
# BASH_REP {u'success': 0, u'error': u'Invalid pair name: bash_rep'}
# BASH_RUR {u'success': 0, u'error': u'Invalid pair name: bash_rur'}
# BASH_USD {u'success': 0, u'error': u'Invalid pair name: bash_usd'}
# BASH_USDT {u'success': 0, u'error': u'Invalid pair name: bash_usdt'}
# BASH_XMR {u'success': 0, u'error': u'Invalid pair name: bash_xmr'}
# BASH_ZEC {u'success': 0, u'error': u'Invalid pair name: bash_zec'}
# BAY_BTC {u'success': 0, u'error': u'Invalid pair name: bay_btc'}
# BAY_DASH {u'success': 0, u'error': u'Invalid pair name: bay_dash'}
# BAY_DOGE {u'success': 0, u'error': u'Invalid pair name: bay_doge'}
# BAY_ETC {u'success': 0, u'error': u'Invalid pair name: bay_etc'}
# BAY_ETH {u'success': 0, u'error': u'Invalid pair name: bay_eth'}
# BAY_EUR {u'success': 0, u'error': u'Invalid pair name: bay_eur'}
# BAY_LTC {u'success': 0, u'error': u'Invalid pair name: bay_ltc'}
# BAY_NXT {u'success': 0, u'error': u'Invalid pair name: bay_nxt'}
# BAY_POSW {u'success': 0, u'error': u'Invalid pair name: bay_posw'}
# BAY_REP {u'success': 0, u'error': u'Invalid pair name: bay_rep'}
# BAY_RUR {u'success': 0, u'error': u'Invalid pair name: bay_rur'}
# BAY_USD {u'success': 0, u'error': u'Invalid pair name: bay_usd'}
# BAY_USDT {u'success': 0, u'error': u'Invalid pair name: bay_usdt'}
# BAY_XMR {u'success': 0, u'error': u'Invalid pair name: bay_xmr'}
# BAY_ZEC {u'success': 0, u'error': u'Invalid pair name: bay_zec'}
# BCC_BTC {u'success': 0, u'error': u'Invalid pair name: bcc_btc'}
# BCC_DASH {u'success': 0, u'error': u'Invalid pair name: bcc_dash'}
# BCC_DOGE {u'success': 0, u'error': u'Invalid pair name: bcc_doge'}
# BCC_ETC {u'success': 0, u'error': u'Invalid pair name: bcc_etc'}
# BCC_ETH {u'success': 0, u'error': u'Invalid pair name: bcc_eth'}
# BCC_EUR {u'success': 0, u'error': u'Invalid pair name: bcc_eur'}
# BCC_LTC {u'success': 0, u'error': u'Invalid pair name: bcc_ltc'}
# BCC_NXT {u'success': 0, u'error': u'Invalid pair name: bcc_nxt'}
# BCC_POSW {u'success': 0, u'error': u'Invalid pair name: bcc_posw'}
# BCC_REP {u'success': 0, u'error': u'Invalid pair name: bcc_rep'}
# BCC_RUR {u'success': 0, u'error': u'Invalid pair name: bcc_rur'}
# BCC_USD {u'success': 0, u'error': u'Invalid pair name: bcc_usd'}
# BCC_USDT {u'success': 0, u'error': u'Invalid pair name: bcc_usdt'}
# BCC_XMR {u'success': 0, u'error': u'Invalid pair name: bcc_xmr'}
# BCC_ZEC {u'success': 0, u'error': u'Invalid pair name: bcc_zec'}
# BCN_BTC {u'success': 0, u'error': u'Invalid pair name: bcn_btc'}
# BCN_DASH {u'success': 0, u'error': u'Invalid pair name: bcn_dash'}
# BCN_DOGE {u'success': 0, u'error': u'Invalid pair name: bcn_doge'}
# BCN_ETC {u'success': 0, u'error': u'Invalid pair name: bcn_etc'}
# BCN_ETH {u'success': 0, u'error': u'Invalid pair name: bcn_eth'}
# BCN_EUR {u'success': 0, u'error': u'Invalid pair name: bcn_eur'}
# BCN_LTC {u'success': 0, u'error': u'Invalid pair name: bcn_ltc'}
# BCN_NXT {u'success': 0, u'error': u'Invalid pair name: bcn_nxt'}
# BCN_POSW {u'success': 0, u'error': u'Invalid pair name: bcn_posw'}
# BCN_REP {u'success': 0, u'error': u'Invalid pair name: bcn_rep'}
# BCN_RUR {u'success': 0, u'error': u'Invalid pair name: bcn_rur'}
# BCN_USD {u'success': 0, u'error': u'Invalid pair name: bcn_usd'}
# BCN_USDT {u'success': 0, u'error': u'Invalid pair name: bcn_usdt'}
# BCN_XMR {u'success': 0, u'error': u'Invalid pair name: bcn_xmr'}
# BCN_ZEC {u'success': 0, u'error': u'Invalid pair name: bcn_zec'}
# BCY_BTC {u'success': 0, u'error': u'Invalid pair name: bcy_btc'}
# BCY_DASH {u'success': 0, u'error': u'Invalid pair name: bcy_dash'}
# BCY_DOGE {u'success': 0, u'error': u'Invalid pair name: bcy_doge'}
# BCY_ETC {u'success': 0, u'error': u'Invalid pair name: bcy_etc'}
# BCY_ETH {u'success': 0, u'error': u'Invalid pair name: bcy_eth'}
# BCY_EUR {u'success': 0, u'error': u'Invalid pair name: bcy_eur'}
# BCY_LTC {u'success': 0, u'error': u'Invalid pair name: bcy_ltc'}
# BCY_NXT {u'success': 0, u'error': u'Invalid pair name: bcy_nxt'}
# BCY_POSW {u'success': 0, u'error': u'Invalid pair name: bcy_posw'}
# BCY_REP {u'success': 0, u'error': u'Invalid pair name: bcy_rep'}
# BCY_RUR {u'success': 0, u'error': u'Invalid pair name: bcy_rur'}
# BCY_USD {u'success': 0, u'error': u'Invalid pair name: bcy_usd'}
# BCY_USDT {u'success': 0, u'error': u'Invalid pair name: bcy_usdt'}
# BCY_XMR {u'success': 0, u'error': u'Invalid pair name: bcy_xmr'}
# BCY_ZEC {u'success': 0, u'error': u'Invalid pair name: bcy_zec'}
# BHC_BTC {u'success': 0, u'error': u'Invalid pair name: bhc_btc'}
# BHC_DASH {u'success': 0, u'error': u'Invalid pair name: bhc_dash'}
# BHC_DOGE {u'success': 0, u'error': u'Invalid pair name: bhc_doge'}
# BHC_ETC {u'success': 0, u'error': u'Invalid pair name: bhc_etc'}
# BHC_ETH {u'success': 0, u'error': u'Invalid pair name: bhc_eth'}
# BHC_EUR {u'success': 0, u'error': u'Invalid pair name: bhc_eur'}
# BHC_LTC {u'success': 0, u'error': u'Invalid pair name: bhc_ltc'}
# BHC_NXT {u'success': 0, u'error': u'Invalid pair name: bhc_nxt'}
# BHC_POSW {u'success': 0, u'error': u'Invalid pair name: bhc_posw'}
# BHC_REP {u'success': 0, u'error': u'Invalid pair name: bhc_rep'}
# BHC_RUR {u'success': 0, u'error': u'Invalid pair name: bhc_rur'}
# BHC_USD {u'success': 0, u'error': u'Invalid pair name: bhc_usd'}
# BHC_USDT {u'success': 0, u'error': u'Invalid pair name: bhc_usdt'}
# BHC_XMR {u'success': 0, u'error': u'Invalid pair name: bhc_xmr'}
# BHC_ZEC {u'success': 0, u'error': u'Invalid pair name: bhc_zec'}
# BIOS_BTC {u'success': 0, u'error': u'Invalid pair name: bios_btc'}
# BIOS_DASH {u'success': 0, u'error': u'Invalid pair name: bios_dash'}
# BIOS_DOGE {u'success': 0, u'error': u'Invalid pair name: bios_doge'}
# BIOS_ETC {u'success': 0, u'error': u'Invalid pair name: bios_etc'}
# BIOS_ETH {u'success': 0, u'error': u'Invalid pair name: bios_eth'}
# BIOS_EUR {u'success': 0, u'error': u'Invalid pair name: bios_eur'}
# BIOS_LTC {u'success': 0, u'error': u'Invalid pair name: bios_ltc'}
# BIOS_NXT {u'success': 0, u'error': u'Invalid pair name: bios_nxt'}
# BIOS_POSW {u'success': 0, u'error': u'Invalid pair name: bios_posw'}
# BIOS_REP {u'success': 0, u'error': u'Invalid pair name: bios_rep'}
# BIOS_RUR {u'success': 0, u'error': u'Invalid pair name: bios_rur'}
# BIOS_USD {u'success': 0, u'error': u'Invalid pair name: bios_usd'}
# BIOS_USDT {u'success': 0, u'error': u'Invalid pair name: bios_usdt'}
# BIOS_XMR {u'success': 0, u'error': u'Invalid pair name: bios_xmr'}
# BIOS_ZEC {u'success': 0, u'error': u'Invalid pair name: bios_zec'}
# BIT_BTC {u'success': 0, u'error': u'Invalid pair name: bit_btc'}
# BIT_DASH {u'success': 0, u'error': u'Invalid pair name: bit_dash'}
# BIT_DOGE {u'success': 0, u'error': u'Invalid pair name: bit_doge'}
# BIT_ETC {u'success': 0, u'error': u'Invalid pair name: bit_etc'}
# BIT_ETH {u'success': 0, u'error': u'Invalid pair name: bit_eth'}
# BIT_EUR {u'success': 0, u'error': u'Invalid pair name: bit_eur'}
# BIT_LTC {u'success': 0, u'error': u'Invalid pair name: bit_ltc'}
# BIT_NXT {u'success': 0, u'error': u'Invalid pair name: bit_nxt'}
# BIT_POSW {u'success': 0, u'error': u'Invalid pair name: bit_posw'}
# BIT_REP {u'success': 0, u'error': u'Invalid pair name: bit_rep'}
# BIT_RUR {u'success': 0, u'error': u'Invalid pair name: bit_rur'}
# BIT_USD {u'success': 0, u'error': u'Invalid pair name: bit_usd'}
# BIT_USDT {u'success': 0, u'error': u'Invalid pair name: bit_usdt'}
# BIT_XMR {u'success': 0, u'error': u'Invalid pair name: bit_xmr'}
# BIT_ZEC {u'success': 0, u'error': u'Invalid pair name: bit_zec'}
# BITB_BTC {u'success': 0, u'error': u'Invalid pair name: bitb_btc'}
# BITB_DASH {u'success': 0, u'error': u'Invalid pair name: bitb_dash'}
# BITB_DOGE {u'success': 0, u'error': u'Invalid pair name: bitb_doge'}
# BITB_ETC {u'success': 0, u'error': u'Invalid pair name: bitb_etc'}
# BITB_ETH {u'success': 0, u'error': u'Invalid pair name: bitb_eth'}
# BITB_EUR {u'success': 0, u'error': u'Invalid pair name: bitb_eur'}
# BITB_LTC {u'success': 0, u'error': u'Invalid pair name: bitb_ltc'}
# BITB_NXT {u'success': 0, u'error': u'Invalid pair name: bitb_nxt'}
# BITB_POSW {u'success': 0, u'error': u'Invalid pair name: bitb_posw'}
# BITB_REP {u'success': 0, u'error': u'Invalid pair name: bitb_rep'}
# BITB_RUR {u'success': 0, u'error': u'Invalid pair name: bitb_rur'}
# BITB_USD {u'success': 0, u'error': u'Invalid pair name: bitb_usd'}
# BITB_USDT {u'success': 0, u'error': u'Invalid pair name: bitb_usdt'}
# BITB_XMR {u'success': 0, u'error': u'Invalid pair name: bitb_xmr'}
# BITB_ZEC {u'success': 0, u'error': u'Invalid pair name: bitb_zec'}
# BLK_BTC {u'success': 0, u'error': u'Invalid pair name: blk_btc'}
# BLK_DASH {u'success': 0, u'error': u'Invalid pair name: blk_dash'}
# BLK_DOGE {u'success': 0, u'error': u'Invalid pair name: blk_doge'}
# BLK_ETC {u'success': 0, u'error': u'Invalid pair name: blk_etc'}
# BLK_ETH {u'success': 0, u'error': u'Invalid pair name: blk_eth'}
# BLK_EUR {u'success': 0, u'error': u'Invalid pair name: blk_eur'}
# BLK_LTC {u'success': 0, u'error': u'Invalid pair name: blk_ltc'}
# BLK_NXT {u'success': 0, u'error': u'Invalid pair name: blk_nxt'}
# BLK_POSW {u'success': 0, u'error': u'Invalid pair name: blk_posw'}
# BLK_REP {u'success': 0, u'error': u'Invalid pair name: blk_rep'}
# BLK_RUR {u'success': 0, u'error': u'Invalid pair name: blk_rur'}
# BLK_USD {u'success': 0, u'error': u'Invalid pair name: blk_usd'}
# BLK_USDT {u'success': 0, u'error': u'Invalid pair name: blk_usdt'}
# BLK_XMR {u'success': 0, u'error': u'Invalid pair name: blk_xmr'}
# BLK_ZEC {u'success': 0, u'error': u'Invalid pair name: blk_zec'}
# BLU_BTC {u'success': 0, u'error': u'Invalid pair name: blu_btc'}
# BLU_DASH {u'success': 0, u'error': u'Invalid pair name: blu_dash'}
# BLU_DOGE {u'success': 0, u'error': u'Invalid pair name: blu_doge'}
# BLU_ETC {u'success': 0, u'error': u'Invalid pair name: blu_etc'}
# BLU_ETH {u'success': 0, u'error': u'Invalid pair name: blu_eth'}
# BLU_EUR {u'success': 0, u'error': u'Invalid pair name: blu_eur'}
# BLU_LTC {u'success': 0, u'error': u'Invalid pair name: blu_ltc'}
# BLU_NXT {u'success': 0, u'error': u'Invalid pair name: blu_nxt'}
# BLU_POSW {u'success': 0, u'error': u'Invalid pair name: blu_posw'}
# BLU_REP {u'success': 0, u'error': u'Invalid pair name: blu_rep'}
# BLU_RUR {u'success': 0, u'error': u'Invalid pair name: blu_rur'}
# BLU_USD {u'success': 0, u'error': u'Invalid pair name: blu_usd'}
# BLU_USDT {u'success': 0, u'error': u'Invalid pair name: blu_usdt'}
# BLU_XMR {u'success': 0, u'error': u'Invalid pair name: blu_xmr'}
# BLU_ZEC {u'success': 0, u'error': u'Invalid pair name: blu_zec'}
# BPC_BTC {u'success': 0, u'error': u'Invalid pair name: bpc_btc'}
# BPC_DASH {u'success': 0, u'error': u'Invalid pair name: bpc_dash'}
# BPC_DOGE {u'success': 0, u'error': u'Invalid pair name: bpc_doge'}
# BPC_ETC {u'success': 0, u'error': u'Invalid pair name: bpc_etc'}
# BPC_ETH {u'success': 0, u'error': u'Invalid pair name: bpc_eth'}
# BPC_EUR {u'success': 0, u'error': u'Invalid pair name: bpc_eur'}
# BPC_LTC {u'success': 0, u'error': u'Invalid pair name: bpc_ltc'}
# BPC_NXT {u'success': 0, u'error': u'Invalid pair name: bpc_nxt'}
# BPC_POSW {u'success': 0, u'error': u'Invalid pair name: bpc_posw'}
# BPC_REP {u'success': 0, u'error': u'Invalid pair name: bpc_rep'}
# BPC_RUR {u'success': 0, u'error': u'Invalid pair name: bpc_rur'}
# BPC_USD {u'success': 0, u'error': u'Invalid pair name: bpc_usd'}
# BPC_USDT {u'success': 0, u'error': u'Invalid pair name: bpc_usdt'}
# BPC_XMR {u'success': 0, u'error': u'Invalid pair name: bpc_xmr'}
# BPC_ZEC {u'success': 0, u'error': u'Invalid pair name: bpc_zec'}
# BSD_BTC {u'success': 0, u'error': u'Invalid pair name: bsd_btc'}
# BSD_DASH {u'success': 0, u'error': u'Invalid pair name: bsd_dash'}
# BSD_DOGE {u'success': 0, u'error': u'Invalid pair name: bsd_doge'}
# BSD_ETC {u'success': 0, u'error': u'Invalid pair name: bsd_etc'}
# BSD_ETH {u'success': 0, u'error': u'Invalid pair name: bsd_eth'}
# BSD_EUR {u'success': 0, u'error': u'Invalid pair name: bsd_eur'}
# BSD_LTC {u'success': 0, u'error': u'Invalid pair name: bsd_ltc'}
# BSD_NXT {u'success': 0, u'error': u'Invalid pair name: bsd_nxt'}
# BSD_POSW {u'success': 0, u'error': u'Invalid pair name: bsd_posw'}
# BSD_REP {u'success': 0, u'error': u'Invalid pair name: bsd_rep'}
# BSD_RUR {u'success': 0, u'error': u'Invalid pair name: bsd_rur'}
# BSD_USD {u'success': 0, u'error': u'Invalid pair name: bsd_usd'}
# BSD_USDT {u'success': 0, u'error': u'Invalid pair name: bsd_usdt'}
# BSD_XMR {u'success': 0, u'error': u'Invalid pair name: bsd_xmr'}
# BSD_ZEC {u'success': 0, u'error': u'Invalid pair name: bsd_zec'}
# BTA_BTC {u'success': 0, u'error': u'Invalid pair name: bta_btc'}
# BTA_DASH {u'success': 0, u'error': u'Invalid pair name: bta_dash'}
# BTA_DOGE {u'success': 0, u'error': u'Invalid pair name: bta_doge'}
# BTA_ETC {u'success': 0, u'error': u'Invalid pair name: bta_etc'}
# BTA_ETH {u'success': 0, u'error': u'Invalid pair name: bta_eth'}
# BTA_EUR {u'success': 0, u'error': u'Invalid pair name: bta_eur'}
# BTA_LTC {u'success': 0, u'error': u'Invalid pair name: bta_ltc'}
# BTA_NXT {u'success': 0, u'error': u'Invalid pair name: bta_nxt'}
# BTA_POSW {u'success': 0, u'error': u'Invalid pair name: bta_posw'}
# BTA_REP {u'success': 0, u'error': u'Invalid pair name: bta_rep'}
# BTA_RUR {u'success': 0, u'error': u'Invalid pair name: bta_rur'}
# BTA_USD {u'success': 0, u'error': u'Invalid pair name: bta_usd'}
# BTA_USDT {u'success': 0, u'error': u'Invalid pair name: bta_usdt'}
# BTA_XMR {u'success': 0, u'error': u'Invalid pair name: bta_xmr'}
# BTA_ZEC {u'success': 0, u'error': u'Invalid pair name: bta_zec'}
# BTC_1ST {u'success': 0, u'error': u'Invalid pair name: btc_1st'}
# BTC_2GIVE {u'success': 0, u'error': u'Invalid pair name: btc_2give'}
# BTC_8BIT {u'success': 0, u'error': u'Invalid pair name: btc_8bit'}
# BTC_ABY {u'success': 0, u'error': u'Invalid pair name: btc_aby'}
# BTC_ACP {u'success': 0, u'error': u'Invalid pair name: btc_acp'}
# BTC_ADCN {u'success': 0, u'error': u'Invalid pair name: btc_adcn'}
# BTC_ADZ {u'success': 0, u'error': u'Invalid pair name: btc_adz'}
# BTC_AEON {u'success': 0, u'error': u'Invalid pair name: btc_aeon'}
# BTC_AIB {u'success': 0, u'error': u'Invalid pair name: btc_aib'}
# BTC_AMP {u'success': 0, u'error': u'Invalid pair name: btc_amp'}
# BTC_ARC {u'success': 0, u'error': u'Invalid pair name: btc_arc'}
# BTC_ARDR {u'success': 0, u'error': u'Invalid pair name: btc_ardr'}
# BTC_AUR {u'success': 0, u'error': u'Invalid pair name: btc_aur'}
# BTC_BASH {u'success': 0, u'error': u'Invalid pair name: btc_bash'}
# BTC_BAY {u'success': 0, u'error': u'Invalid pair name: btc_bay'}
# BTC_BCC {u'success': 0, u'error': u'Invalid pair name: btc_bcc'}
# BTC_BCN {u'success': 0, u'error': u'Invalid pair name: btc_bcn'}
# BTC_BCY {u'success': 0, u'error': u'Invalid pair name: btc_bcy'}
# BTC_BHC {u'success': 0, u'error': u'Invalid pair name: btc_bhc'}
# BTC_BIOS {u'success': 0, u'error': u'Invalid pair name: btc_bios'}
# BTC_BIT {u'success': 0, u'error': u'Invalid pair name: btc_bit'}
# BTC_BITB {u'success': 0, u'error': u'Invalid pair name: btc_bitb'}
# BTC_BLK {u'success': 0, u'error': u'Invalid pair name: btc_blk'}
# BTC_BLU {u'success': 0, u'error': u'Invalid pair name: btc_blu'}
# BTC_BPC {u'success': 0, u'error': u'Invalid pair name: btc_bpc'}
# BTC_BSD {u'success': 0, u'error': u'Invalid pair name: btc_bsd'}
# BTC_BTA {u'success': 0, u'error': u'Invalid pair name: btc_bta'}
# BTC_BTC {u'success': 0, u'error': u'Invalid pair name: btc_btc'}
# BTC_BTC {u'success': 0, u'error': u'Invalid pair name: btc_btc'}
# BTC_BTCD {u'success': 0, u'error': u'Invalid pair name: btc_btcd'}
# BTC_BTS {u'success': 0, u'error': u'Invalid pair name: btc_bts'}
# BTC_BURST {u'success': 0, u'error': u'Invalid pair name: btc_burst'}
# BTC_CANN {u'success': 0, u'error': u'Invalid pair name: btc_cann'}
# BTC_CCRB {u'success': 0, u'error': u'Invalid pair name: btc_ccrb'}
# BTC_CJ {u'success': 0, u'error': u'Invalid pair name: btc_cj'}
# BTC_CLAM {u'success': 0, u'error': u'Invalid pair name: btc_clam'}
# BTC_CLOAK {u'success': 0, u'error': u'Invalid pair name: btc_cloak'}
# BTC_CLUB {u'success': 0, u'error': u'Invalid pair name: btc_club'}
# BTC_CNT {u'success': 0, u'error': u'Invalid pair name: btc_cnt'}
# BTC_CPC {u'success': 0, u'error': u'Invalid pair name: btc_cpc'}
# BTC_CREVA {u'success': 0, u'error': u'Invalid pair name: btc_creva'}
# BTC_CRW {u'success': 0, u'error': u'Invalid pair name: btc_crw'}
# BTC_CURE {u'success': 0, u'error': u'Invalid pair name: btc_cure'}
# BTC_DASH {u'success': 0, u'error': u'Invalid pair name: btc_dash'}
# BTC_DASH {u'success': 0, u'error': u'Invalid pair name: btc_dash'}
# BTC_DCR {u'success': 0, u'error': u'Invalid pair name: btc_dcr'}
# BTC_DCT {u'success': 0, u'error': u'Invalid pair name: btc_dct'}
# BTC_DGB {u'success': 0, u'error': u'Invalid pair name: btc_dgb'}
# BTC_DGD {u'success': 0, u'error': u'Invalid pair name: btc_dgd'}
# BTC_DIME {u'success': 0, u'error': u'Invalid pair name: btc_dime'}
# BTC_DOGE {u'success': 0, u'error': u'Invalid pair name: btc_doge'}
# BTC_DOGE {u'success': 0, u'error': u'Invalid pair name: btc_doge'}
# BTC_DRACO {u'success': 0, u'error': u'Invalid pair name: btc_draco'}
# BTC_DRZ {u'success': 0, u'error': u'Invalid pair name: btc_drz'}
# BTC_DSH {u'success': 0, u'error': u'Invalid pair name: btc_dsh'}
# BTC_ECN {u'success': 0, u'error': u'Invalid pair name: btc_ecn'}
# BTC_EGC {u'success': 0, u'error': u'Invalid pair name: btc_egc'}
# BTC_EL {u'success': 0, u'error': u'Invalid pair name: btc_el'}
# BTC_ELE {u'success': 0, u'error': u'Invalid pair name: btc_ele'}
# BTC_EMC {u'success': 0, u'error': u'Invalid pair name: btc_emc'}
# BTC_EMC2 {u'success': 0, u'error': u'Invalid pair name: btc_emc2'}
# BTC_ENT {u'success': 0, u'error': u'Invalid pair name: btc_ent'}
# BTC_ETC {u'success': 0, u'error': u'Invalid pair name: btc_etc'}
# BTC_ETC {u'success': 0, u'error': u'Invalid pair name: btc_etc'}
# BTC_ETH {u'success': 0, u'error': u'Invalid pair name: btc_eth'}
# BTC_ETH {u'success': 0, u'error': u'Invalid pair name: btc_eth'}
# BTC_EUR {u'btc_eur': {u'sell': 2183.101, u'updated': 1497594836, u'buy': 2198.40998, u'last': 2183.101, u'vol': 816566.90486, u'vol_cur': 392.91584, u'high': 2198, u'low': 1885.15844, u'avg': 2041.57922}}
# BTC_EUR {u'btc_eur': {u'sell': 2183.101, u'updated': 1497594838, u'buy': 2198.40998, u'last': 2183.101, u'vol': 816566.90486, u'vol_cur': 392.91584, u'high': 2198, u'low': 1885.15844, u'avg': 2041.57922}}
# BTC_EXP {u'success': 0, u'error': u'Invalid pair name: btc_exp'}
# BTC_FCT {u'success': 0, u'error': u'Invalid pair name: btc_fct'}
# BTC_FJC {u'success': 0, u'error': u'Invalid pair name: btc_fjc'}
# BTC_FRST {u'success': 0, u'error': u'Invalid pair name: btc_frst'}
# BTC_GAME {u'success': 0, u'error': u'Invalid pair name: btc_game'}
# BTC_GB {u'success': 0, u'error': u'Invalid pair name: btc_gb'}
# BTC_GCR {u'success': 0, u'error': u'Invalid pair name: btc_gcr'}
# BTC_GEO {u'success': 0, u'error': u'Invalid pair name: btc_geo'}
# BTC_GHS {u'success': 0, u'error': u'Invalid pair name: btc_ghs'}
# BTC_GLD {u'success': 0, u'error': u'Invalid pair name: btc_gld'}
# BTC_GNO {u'success': 0, u'error': u'Invalid pair name: btc_gno'}
# BTC_GNT {u'success': 0, u'error': u'Invalid pair name: btc_gnt'}
# BTC_GOLOS {u'success': 0, u'error': u'Invalid pair name: btc_golos'}
# BTC_GRC {u'success': 0, u'error': u'Invalid pair name: btc_grc'}
# BTC_GUP {u'success': 0, u'error': u'Invalid pair name: btc_gup'}
# BTC_HCC {u'success': 0, u'error': u'Invalid pair name: btc_hcc'}
# BTC_HXX {u'success': 0, u'error': u'Invalid pair name: btc_hxx'}
# BTC_ICN {u'success': 0, u'error': u'Invalid pair name: btc_icn'}
# BTC_INCNT {u'success': 0, u'error': u'Invalid pair name: btc_incnt'}
# BTC_INFX {u'success': 0, u'error': u'Invalid pair name: btc_infx'}
# BTC_IOC {u'success': 0, u'error': u'Invalid pair name: btc_ioc'}
# BTC_ION {u'success': 0, u'error': u'Invalid pair name: btc_ion'}
# BTC_IOP {u'success': 0, u'error': u'Invalid pair name: btc_iop'}
# BTC_ISL {u'success': 0, u'error': u'Invalid pair name: btc_isl'}
# BTC_ITI {u'success': 0, u'error': u'Invalid pair name: btc_iti'}
# BTC_JWL {u'success': 0, u'error': u'Invalid pair name: btc_jwl'}
# BTC_KC {u'success': 0, u'error': u'Invalid pair name: btc_kc'}
# BTC_LBC {u'success': 0, u'error': u'Invalid pair name: btc_lbc'}
# BTC_LEO {u'success': 0, u'error': u'Invalid pair name: btc_leo'}
# BTC_LEPEN {u'success': 0, u'error': u'Invalid pair name: btc_lepen'}
# BTC_LSK {u'success': 0, u'error': u'Invalid pair name: btc_lsk'}
# BTC_LTC {u'success': 0, u'error': u'Invalid pair name: btc_ltc'}
# BTC_LTC {u'success': 0, u'error': u'Invalid pair name: btc_ltc'}
# BTC_LTCR {u'success': 0, u'error': u'Invalid pair name: btc_ltcr'}
# BTC_LTS {u'success': 0, u'error': u'Invalid pair name: btc_lts'}
# BTC_LUN {u'success': 0, u'error': u'Invalid pair name: btc_lun'}
# BTC_LUNA {u'success': 0, u'error': u'Invalid pair name: btc_luna'}
# BTC_MAID {u'success': 0, u'error': u'Invalid pair name: btc_maid'}
# BTC_MLN {u'success': 0, u'error': u'Invalid pair name: btc_mln'}
# BTC_MOIN {u'success': 0, u'error': u'Invalid pair name: btc_moin'}
# BTC_MOJO {u'success': 0, u'error': u'Invalid pair name: btc_mojo'}
# BTC_MONA {u'success': 0, u'error': u'Invalid pair name: btc_mona'}
# BTC_MSCN {u'success': 0, u'error': u'Invalid pair name: btc_mscn'}
# BTC_MUE {u'success': 0, u'error': u'Invalid pair name: btc_mue'}
# BTC_NAUT {u'success': 0, u'error': u'Invalid pair name: btc_naut'}
# BTC_NAV {u'success': 0, u'error': u'Invalid pair name: btc_nav'}
# BTC_NLG {u'success': 0, u'error': u'Invalid pair name: btc_nlg'}
# BTC_NMC {u'success': 0, u'error': u'Invalid pair name: btc_nmc'}
# BTC_NOTE {u'success': 0, u'error': u'Invalid pair name: btc_note'}
# BTC_NVC {u'success': 0, u'error': u'Invalid pair name: btc_nvc'}
# BTC_NXC {u'success': 0, u'error': u'Invalid pair name: btc_nxc'}
# BTC_NXT {u'success': 0, u'error': u'Invalid pair name: btc_nxt'}
# BTC_NXT {u'success': 0, u'error': u'Invalid pair name: btc_nxt'}
# BTC_OD {u'success': 0, u'error': u'Invalid pair name: btc_od'}
# BTC_OK {u'success': 0, u'error': u'Invalid pair name: btc_ok'}
# BTC_OMNI {u'success': 0, u'error': u'Invalid pair name: btc_omni'}
# BTC_OTX {u'success': 0, u'error': u'Invalid pair name: btc_otx'}
# BTC_PINK {u'success': 0, u'error': u'Invalid pair name: btc_pink'}
# BTC_PIVX {u'success': 0, u'error': u'Invalid pair name: btc_pivx'}
# BTC_PKB {u'success': 0, u'error': u'Invalid pair name: btc_pkb'}
# BTC_POST {u'success': 0, u'error': u'Invalid pair name: btc_post'}
# BTC_POSW {u'success': 0, u'error': u'Invalid pair name: btc_posw'}
# BTC_POSW {u'success': 0, u'error': u'Invalid pair name: btc_posw'}
# BTC_PPC {u'success': 0, u'error': u'Invalid pair name: btc_ppc'}
# BTC_PRES {u'success': 0, u'error': u'Invalid pair name: btc_pres'}
# BTC_PROC {u'success': 0, u'error': u'Invalid pair name: btc_proc'}
# BTC_PSB {u'success': 0, u'error': u'Invalid pair name: btc_psb'}
# BTC_RADS {u'success': 0, u'error': u'Invalid pair name: btc_rads'}
# BTC_RBIES {u'success': 0, u'error': u'Invalid pair name: btc_rbies'}
# BTC_RDD {u'success': 0, u'error': u'Invalid pair name: btc_rdd'}
# BTC_REE {u'success': 0, u'error': u'Invalid pair name: btc_ree'}
# BTC_REP {u'success': 0, u'error': u'Invalid pair name: btc_rep'}
# BTC_REP {u'success': 0, u'error': u'Invalid pair name: btc_rep'}
# BTC_RIDE {u'success': 0, u'error': u'Invalid pair name: btc_ride'}
# BTC_RISE {u'success': 0, u'error': u'Invalid pair name: btc_rise'}
# BTC_RLC {u'success': 0, u'error': u'Invalid pair name: btc_rlc'}
# BTC_ROYAL {u'success': 0, u'error': u'Invalid pair name: btc_royal'}
# BTC_RUB {u'success': 0, u'error': u'Invalid pair name: btc_rub'}
# BTC_RUR {u'btc_rur': {u'sell': 145501, u'updated': 1497594858, u'buy': 146475.70289, u'last': 145501.00001, u'vol': 62871215.19287, u'vol_cur': 440.78537, u'high': 147922.51399, u'low': 133333, u'avg': 140627.756995}}
# BTC_RUR {u'btc_rur': {u'sell': 145501, u'updated': 1497594858, u'buy': 146475.70289, u'last': 145501.00001, u'vol': 62871215.19287, u'vol_cur': 440.78537, u'high': 147922.51399, u'low': 133333, u'avg': 140627.756995}}
# BTC_SBD {u'success': 0, u'error': u'Invalid pair name: btc_sbd'}
# BTC_SC {u'success': 0, u'error': u'Invalid pair name: btc_sc'}
# BTC_SHIFT {u'success': 0, u'error': u'Invalid pair name: btc_shift'}
# BTC_SIB {u'success': 0, u'error': u'Invalid pair name: btc_sib'}
# BTC_SLR {u'success': 0, u'error': u'Invalid pair name: btc_slr'}
# BTC_SLS {u'success': 0, u'error': u'Invalid pair name: btc_sls'}
# BTC_SNGLS {u'success': 0, u'error': u'Invalid pair name: btc_sngls'}
# BTC_SNRG {u'success': 0, u'error': u'Invalid pair name: btc_snrg'}
# BTC_SOAR {u'success': 0, u'error': u'Invalid pair name: btc_soar'}
# BTC_SONG {u'success': 0, u'error': u'Invalid pair name: btc_song'}
# BTC_SPR {u'success': 0, u'error': u'Invalid pair name: btc_spr'}
# BTC_START {u'success': 0, u'error': u'Invalid pair name: btc_start'}
# BTC_STEEM {u'success': 0, u'error': u'Invalid pair name: btc_steem'}
# BTC_STRAT {u'success': 0, u'error': u'Invalid pair name: btc_strat'}
# BTC_SWT {u'success': 0, u'error': u'Invalid pair name: btc_swt'}
# BTC_SXC {u'success': 0, u'error': u'Invalid pair name: btc_sxc'}
# BTC_SYNX {u'success': 0, u'error': u'Invalid pair name: btc_synx'}
# BTC_SYS {u'success': 0, u'error': u'Invalid pair name: btc_sys'}
# BTC_TAAS {u'success': 0, u'error': u'Invalid pair name: btc_taas'}
# BTC_TIME {u'success': 0, u'error': u'Invalid pair name: btc_time'}
# BTC_TKN {u'success': 0, u'error': u'Invalid pair name: btc_tkn'}
# BTC_TLE {u'success': 0, u'error': u'Invalid pair name: btc_tle'}
# BTC_TRST {u'success': 0, u'error': u'Invalid pair name: btc_trst'}
# BTC_TRUMP {u'success': 0, u'error': u'Invalid pair name: btc_trump'}
# BTC_TSE {u'success': 0, u'error': u'Invalid pair name: btc_tse'}
# BTC_TX {u'success': 0, u'error': u'Invalid pair name: btc_tx'}
# BTC_U {u'success': 0, u'error': u'Invalid pair name: btc_u'}
# BTC_UNC {u'success': 0, u'error': u'Invalid pair name: btc_unc'}
# BTC_UNO {u'success': 0, u'error': u'Invalid pair name: btc_uno'}
# BTC_UNY {u'success': 0, u'error': u'Invalid pair name: btc_uny'}
# BTC_USD {u'btc_usd': {u'sell': 2448.001, u'updated': 1497594868, u'buy': 2449.999, u'last': 2450, u'vol': 31434690.8885, u'vol_cur': 13191.85611, u'high': 2489.878, u'low': 2250.585, u'avg': 2370.2315}}
# BTC_USD {u'btc_usd': {u'sell': 2448.001, u'updated': 1497594868, u'buy': 2449.999, u'last': 2450, u'vol': 31434690.8885, u'vol_cur': 13191.85611, u'high': 2489.878, u'low': 2250.585, u'avg': 2370.2315}}
# BTC_USDT {u'success': 0, u'error': u'Invalid pair name: btc_usdt'}
# BTC_USDT {u'success': 0, u'error': u'Invalid pair name: btc_usdt'}
# BTC_VEC2 {u'success': 0, u'error': u'Invalid pair name: btc_vec2'}
# BTC_VIA {u'success': 0, u'error': u'Invalid pair name: btc_via'}
# BTC_VOX {u'success': 0, u'error': u'Invalid pair name: btc_vox'}
# BTC_VRC {u'success': 0, u'error': u'Invalid pair name: btc_vrc'}
# BTC_VRM {u'success': 0, u'error': u'Invalid pair name: btc_vrm'}
# BTC_VRS {u'success': 0, u'error': u'Invalid pair name: btc_vrs'}
# BTC_VTC {u'success': 0, u'error': u'Invalid pair name: btc_vtc'}
# BTC_WAVES {u'success': 0, u'error': u'Invalid pair name: btc_waves'}
# BTC_WINGS {u'success': 0, u'error': u'Invalid pair name: btc_wings'}
# BTC_XAUR {u'success': 0, u'error': u'Invalid pair name: btc_xaur'}
# BTC_XBY {u'success': 0, u'error': u'Invalid pair name: btc_xby'}
# BTC_XDN {u'success': 0, u'error': u'Invalid pair name: btc_xdn'}
# BTC_XEM {u'success': 0, u'error': u'Invalid pair name: btc_xem'}
# BTC_XHI {u'success': 0, u'error': u'Invalid pair name: btc_xhi'}
# BTC_XLM {u'success': 0, u'error': u'Invalid pair name: btc_xlm'}
# BTC_XMR {u'success': 0, u'error': u'Invalid pair name: btc_xmr'}
# BTC_XMR {u'success': 0, u'error': u'Invalid pair name: btc_xmr'}
# BTC_XMS {u'success': 0, u'error': u'Invalid pair name: btc_xms'}
# BTC_XRP {u'success': 0, u'error': u'Invalid pair name: btc_xrp'}
# BTC_XSPEC {u'success': 0, u'error': u'Invalid pair name: btc_xspec'}
# BTC_XTO {u'success': 0, u'error': u'Invalid pair name: btc_xto'}
# BTC_XVC {u'success': 0, u'error': u'Invalid pair name: btc_xvc'}
# BTC_XVG {u'success': 0, u'error': u'Invalid pair name: btc_xvg'}
# BTC_YOC {u'success': 0, u'error': u'Invalid pair name: btc_yoc'}
# BTC_ZCL {u'success': 0, u'error': u'Invalid pair name: btc_zcl'}
# BTC_ZEC {u'success': 0, u'error': u'Invalid pair name: btc_zec'}
# BTC_ZEC {u'success': 0, u'error': u'Invalid pair name: btc_zec'}
# BTC_ZENI {u'success': 0, u'error': u'Invalid pair name: btc_zeni'}
# BTCD_BTC {u'success': 0, u'error': u'Invalid pair name: btcd_btc'}
# BTCD_DASH {u'success': 0, u'error': u'Invalid pair name: btcd_dash'}
# BTCD_DOGE {u'success': 0, u'error': u'Invalid pair name: btcd_doge'}
# BTCD_ETC {u'success': 0, u'error': u'Invalid pair name: btcd_etc'}
# BTCD_ETH {u'success': 0, u'error': u'Invalid pair name: btcd_eth'}
# BTCD_EUR {u'success': 0, u'error': u'Invalid pair name: btcd_eur'}
# BTCD_LTC {u'success': 0, u'error': u'Invalid pair name: btcd_ltc'}
# BTCD_NXT {u'success': 0, u'error': u'Invalid pair name: btcd_nxt'}
# BTCD_POSW {u'success': 0, u'error': u'Invalid pair name: btcd_posw'}
# BTCD_REP {u'success': 0, u'error': u'Invalid pair name: btcd_rep'}
# BTCD_RUR {u'success': 0, u'error': u'Invalid pair name: btcd_rur'}
# BTCD_USD {u'success': 0, u'error': u'Invalid pair name: btcd_usd'}
# BTCD_USDT {u'success': 0, u'error': u'Invalid pair name: btcd_usdt'}
# BTCD_XMR {u'success': 0, u'error': u'Invalid pair name: btcd_xmr'}
# BTCD_ZEC {u'success': 0, u'error': u'Invalid pair name: btcd_zec'}
# BTS_BTC {u'success': 0, u'error': u'Invalid pair name: bts_btc'}
# BTS_DASH {u'success': 0, u'error': u'Invalid pair name: bts_dash'}
# BTS_DOGE {u'success': 0, u'error': u'Invalid pair name: bts_doge'}
# BTS_ETC {u'success': 0, u'error': u'Invalid pair name: bts_etc'}
# BTS_ETH {u'success': 0, u'error': u'Invalid pair name: bts_eth'}
# BTS_EUR {u'success': 0, u'error': u'Invalid pair name: bts_eur'}
# BTS_LTC {u'success': 0, u'error': u'Invalid pair name: bts_ltc'}
# BTS_NXT {u'success': 0, u'error': u'Invalid pair name: bts_nxt'}
# BTS_POSW {u'success': 0, u'error': u'Invalid pair name: bts_posw'}
# BTS_REP {u'success': 0, u'error': u'Invalid pair name: bts_rep'}
# BTS_RUR {u'success': 0, u'error': u'Invalid pair name: bts_rur'}
# BTS_USD {u'success': 0, u'error': u'Invalid pair name: bts_usd'}
# BTS_USDT {u'success': 0, u'error': u'Invalid pair name: bts_usdt'}
# BTS_XMR {u'success': 0, u'error': u'Invalid pair name: bts_xmr'}
# BTS_ZEC {u'success': 0, u'error': u'Invalid pair name: bts_zec'}
# BURST_BTC {u'success': 0, u'error': u'Invalid pair name: burst_btc'}
# BURST_DASH {u'success': 0, u'error': u'Invalid pair name: burst_dash'}
# BURST_DOGE {u'success': 0, u'error': u'Invalid pair name: burst_doge'}
# BURST_ETC {u'success': 0, u'error': u'Invalid pair name: burst_etc'}
# BURST_ETH {u'success': 0, u'error': u'Invalid pair name: burst_eth'}
# BURST_EUR {u'success': 0, u'error': u'Invalid pair name: burst_eur'}
# BURST_LTC {u'success': 0, u'error': u'Invalid pair name: burst_ltc'}
# BURST_NXT {u'success': 0, u'error': u'Invalid pair name: burst_nxt'}
# BURST_POSW {u'success': 0, u'error': u'Invalid pair name: burst_posw'}
# BURST_REP {u'success': 0, u'error': u'Invalid pair name: burst_rep'}
# BURST_RUR {u'success': 0, u'error': u'Invalid pair name: burst_rur'}
# BURST_USD {u'success': 0, u'error': u'Invalid pair name: burst_usd'}
# BURST_USDT {u'success': 0, u'error': u'Invalid pair name: burst_usdt'}
# BURST_XMR {u'success': 0, u'error': u'Invalid pair name: burst_xmr'}
# BURST_ZEC {u'success': 0, u'error': u'Invalid pair name: burst_zec'}
# CANN_BTC {u'success': 0, u'error': u'Invalid pair name: cann_btc'}
# CANN_DASH {u'success': 0, u'error': u'Invalid pair name: cann_dash'}
# CANN_DOGE {u'success': 0, u'error': u'Invalid pair name: cann_doge'}
# CANN_ETC {u'success': 0, u'error': u'Invalid pair name: cann_etc'}
# CANN_ETH {u'success': 0, u'error': u'Invalid pair name: cann_eth'}
# CANN_EUR {u'success': 0, u'error': u'Invalid pair name: cann_eur'}
# CANN_LTC {u'success': 0, u'error': u'Invalid pair name: cann_ltc'}
# CANN_NXT {u'success': 0, u'error': u'Invalid pair name: cann_nxt'}
# CANN_POSW {u'success': 0, u'error': u'Invalid pair name: cann_posw'}
# CANN_REP {u'success': 0, u'error': u'Invalid pair name: cann_rep'}
# CANN_RUR {u'success': 0, u'error': u'Invalid pair name: cann_rur'}
# CANN_USD {u'success': 0, u'error': u'Invalid pair name: cann_usd'}
# CANN_USDT {u'success': 0, u'error': u'Invalid pair name: cann_usdt'}
# CANN_XMR {u'success': 0, u'error': u'Invalid pair name: cann_xmr'}
# CANN_ZEC {u'success': 0, u'error': u'Invalid pair name: cann_zec'}
# CCRB_BTC {u'success': 0, u'error': u'Invalid pair name: ccrb_btc'}
# CCRB_DASH {u'success': 0, u'error': u'Invalid pair name: ccrb_dash'}
# CCRB_DOGE {u'success': 0, u'error': u'Invalid pair name: ccrb_doge'}
# CCRB_ETC {u'success': 0, u'error': u'Invalid pair name: ccrb_etc'}
# CCRB_ETH {u'success': 0, u'error': u'Invalid pair name: ccrb_eth'}
# CCRB_EUR {u'success': 0, u'error': u'Invalid pair name: ccrb_eur'}
# CCRB_LTC {u'success': 0, u'error': u'Invalid pair name: ccrb_ltc'}
# CCRB_NXT {u'success': 0, u'error': u'Invalid pair name: ccrb_nxt'}
# CCRB_POSW {u'success': 0, u'error': u'Invalid pair name: ccrb_posw'}
# CCRB_REP {u'success': 0, u'error': u'Invalid pair name: ccrb_rep'}
# CCRB_RUR {u'success': 0, u'error': u'Invalid pair name: ccrb_rur'}
# CCRB_USD {u'success': 0, u'error': u'Invalid pair name: ccrb_usd'}
# CCRB_USDT {u'success': 0, u'error': u'Invalid pair name: ccrb_usdt'}
# CCRB_XMR {u'success': 0, u'error': u'Invalid pair name: ccrb_xmr'}
# CCRB_ZEC {u'success': 0, u'error': u'Invalid pair name: ccrb_zec'}
# CJ_BTC {u'success': 0, u'error': u'Invalid pair name: cj_btc'}
# CJ_DASH {u'success': 0, u'error': u'Invalid pair name: cj_dash'}
# CJ_DOGE {u'success': 0, u'error': u'Invalid pair name: cj_doge'}
# CJ_ETC {u'success': 0, u'error': u'Invalid pair name: cj_etc'}
# CJ_ETH {u'success': 0, u'error': u'Invalid pair name: cj_eth'}
# CJ_EUR {u'success': 0, u'error': u'Invalid pair name: cj_eur'}
# CJ_LTC {u'success': 0, u'error': u'Invalid pair name: cj_ltc'}
# CJ_NXT {u'success': 0, u'error': u'Invalid pair name: cj_nxt'}
# CJ_POSW {u'success': 0, u'error': u'Invalid pair name: cj_posw'}
# CJ_REP {u'success': 0, u'error': u'Invalid pair name: cj_rep'}
# CJ_RUR {u'success': 0, u'error': u'Invalid pair name: cj_rur'}
# CJ_USD {u'success': 0, u'error': u'Invalid pair name: cj_usd'}
# CJ_USDT {u'success': 0, u'error': u'Invalid pair name: cj_usdt'}
# CJ_XMR {u'success': 0, u'error': u'Invalid pair name: cj_xmr'}
# CJ_ZEC {u'success': 0, u'error': u'Invalid pair name: cj_zec'}
# CLAM_BTC {u'success': 0, u'error': u'Invalid pair name: clam_btc'}
# CLAM_DASH {u'success': 0, u'error': u'Invalid pair name: clam_dash'}
# CLAM_DOGE {u'success': 0, u'error': u'Invalid pair name: clam_doge'}
# CLAM_ETC {u'success': 0, u'error': u'Invalid pair name: clam_etc'}
# CLAM_ETH {u'success': 0, u'error': u'Invalid pair name: clam_eth'}
# CLAM_EUR {u'success': 0, u'error': u'Invalid pair name: clam_eur'}
# CLAM_LTC {u'success': 0, u'error': u'Invalid pair name: clam_ltc'}
# ...
# OMNI_LTC {u'success': 0, u'error': u'Invalid pair name: omni_ltc'}
# OMNI_NXT {u'success': 0, u'error': u'Invalid pair name: omni_nxt'}
# OMNI_POSW {u'success': 0, u'error': u'Invalid pair name: omni_posw'}
# OMNI_REP {u'success': 0, u'error': u'Invalid pair name: omni_rep'}
# OMNI_RUR {u'success': 0, u'error': u'Invalid pair name: omni_rur'}
# OMNI_USD {u'success': 0, u'error': u'Invalid pair name: omni_usd'}
# OMNI_USDT {u'success': 0, u'error': u'Invalid pair name: omni_usdt'}
# OMNI_XMR {u'success': 0, u'error': u'Invalid pair name: omni_xmr'}
# OMNI_ZEC {u'success': 0, u'error': u'Invalid pair name: omni_zec'}
# OTX_BTC {u'success': 0, u'error': u'Invalid pair name: otx_btc'}
# OTX_DASH {u'success': 0, u'error': u'Invalid pair name: otx_dash'}
# OTX_DOGE {u'success': 0, u'error': u'Invalid pair name: otx_doge'}
# OTX_ETC {u'success': 0, u'error': u'Invalid pair name: otx_etc'}
# OTX_ETH {u'success': 0, u'error': u'Invalid pair name: otx_eth'}
# OTX_EUR {u'success': 0, u'error': u'Invalid pair name: otx_eur'}
# OTX_LTC {u'success': 0, u'error': u'Invalid pair name: otx_ltc'}
# OTX_NXT {u'success': 0, u'error': u'Invalid pair name: otx_nxt'}
# OTX_POSW {u'success': 0, u'error': u'Invalid pair name: otx_posw'}
# OTX_REP {u'success': 0, u'error': u'Invalid pair name: otx_rep'}
# OTX_RUR {u'success': 0, u'error': u'Invalid pair name: otx_rur'}
# OTX_USD {u'success': 0, u'error': u'Invalid pair name: otx_usd'}
# OTX_USDT {u'success': 0, u'error': u'Invalid pair name: otx_usdt'}
# OTX_XMR {u'success': 0, u'error': u'Invalid pair name: otx_xmr'}
# OTX_ZEC {u'success': 0, u'error': u'Invalid pair name: otx_zec'}
# PINK_BTC {u'success': 0, u'error': u'Invalid pair name: pink_btc'}
# PINK_DASH {u'success': 0, u'error': u'Invalid pair name: pink_dash'}
# PINK_DOGE {u'success': 0, u'error': u'Invalid pair name: pink_doge'}
# PINK_ETC {u'success': 0, u'error': u'Invalid pair name: pink_etc'}
# PINK_ETH {u'success': 0, u'error': u'Invalid pair name: pink_eth'}
# PINK_EUR {u'success': 0, u'error': u'Invalid pair name: pink_eur'}
# PINK_LTC {u'success': 0, u'error': u'Invalid pair name: pink_ltc'}
# PINK_NXT {u'success': 0, u'error': u'Invalid pair name: pink_nxt'}
# PINK_POSW {u'success': 0, u'error': u'Invalid pair name: pink_posw'}
# PINK_REP {u'success': 0, u'error': u'Invalid pair name: pink_rep'}
# PINK_RUR {u'success': 0, u'error': u'Invalid pair name: pink_rur'}
# PINK_USD {u'success': 0, u'error': u'Invalid pair name: pink_usd'}
# PINK_USDT {u'success': 0, u'error': u'Invalid pair name: pink_usdt'}
# PINK_XMR {u'success': 0, u'error': u'Invalid pair name: pink_xmr'}
# PINK_ZEC {u'success': 0, u'error': u'Invalid pair name: pink_zec'}
# PIVX_BTC {u'success': 0, u'error': u'Invalid pair name: pivx_btc'}
# PIVX_DASH {u'success': 0, u'error': u'Invalid pair name: pivx_dash'}
# PIVX_DOGE {u'success': 0, u'error': u'Invalid pair name: pivx_doge'}
# PIVX_ETC {u'success': 0, u'error': u'Invalid pair name: pivx_etc'}
# PIVX_ETH {u'success': 0, u'error': u'Invalid pair name: pivx_eth'}
# PIVX_EUR {u'success': 0, u'error': u'Invalid pair name: pivx_eur'}
# PIVX_LTC {u'success': 0, u'error': u'Invalid pair name: pivx_ltc'}
# PIVX_NXT {u'success': 0, u'error': u'Invalid pair name: pivx_nxt'}
# PIVX_POSW {u'success': 0, u'error': u'Invalid pair name: pivx_posw'}
# PIVX_REP {u'success': 0, u'error': u'Invalid pair name: pivx_rep'}
# PIVX_RUR {u'success': 0, u'error': u'Invalid pair name: pivx_rur'}
# PIVX_USD {u'success': 0, u'error': u'Invalid pair name: pivx_usd'}
# PIVX_USDT {u'success': 0, u'error': u'Invalid pair name: pivx_usdt'}
# PIVX_XMR {u'success': 0, u'error': u'Invalid pair name: pivx_xmr'}
# PIVX_ZEC {u'success': 0, u'error': u'Invalid pair name: pivx_zec'}
# PKB_BTC {u'success': 0, u'error': u'Invalid pair name: pkb_btc'}
# PKB_DASH {u'success': 0, u'error': u'Invalid pair name: pkb_dash'}
# PKB_DOGE {u'success': 0, u'error': u'Invalid pair name: pkb_doge'}
# PKB_ETC {u'success': 0, u'error': u'Invalid pair name: pkb_etc'}
# PKB_ETH {u'success': 0, u'error': u'Invalid pair name: pkb_eth'}
# PKB_EUR {u'success': 0, u'error': u'Invalid pair name: pkb_eur'}
# PKB_LTC {u'success': 0, u'error': u'Invalid pair name: pkb_ltc'}
# PKB_NXT {u'success': 0, u'error': u'Invalid pair name: pkb_nxt'}
# PKB_POSW {u'success': 0, u'error': u'Invalid pair name: pkb_posw'}
# PKB_REP {u'success': 0, u'error': u'Invalid pair name: pkb_rep'}
# PKB_RUR {u'success': 0, u'error': u'Invalid pair name: pkb_rur'}
# PKB_USD {u'success': 0, u'error': u'Invalid pair name: pkb_usd'}
# PKB_USDT {u'success': 0, u'error': u'Invalid pair name: pkb_usdt'}
# PKB_XMR {u'success': 0, u'error': u'Invalid pair name: pkb_xmr'}
# PKB_ZEC {u'success': 0, u'error': u'Invalid pair name: pkb_zec'}
# POST_BTC {u'success': 0, u'error': u'Invalid pair name: post_btc'}
# POST_DASH {u'success': 0, u'error': u'Invalid pair name: post_dash'}
# POST_DOGE {u'success': 0, u'error': u'Invalid pair name: post_doge'}
# POST_ETC {u'success': 0, u'error': u'Invalid pair name: post_etc'}
# POST_ETH {u'success': 0, u'error': u'Invalid pair name: post_eth'}
# POST_EUR {u'success': 0, u'error': u'Invalid pair name: post_eur'}
# POST_LTC {u'success': 0, u'error': u'Invalid pair name: post_ltc'}
# POST_NXT {u'success': 0, u'error': u'Invalid pair name: post_nxt'}
# POST_POSW {u'success': 0, u'error': u'Invalid pair name: post_posw'}
# POST_REP {u'success': 0, u'error': u'Invalid pair name: post_rep'}
# POST_RUR {u'success': 0, u'error': u'Invalid pair name: post_rur'}
# POST_USD {u'success': 0, u'error': u'Invalid pair name: post_usd'}
# POST_USDT {u'success': 0, u'error': u'Invalid pair name: post_usdt'}
# POST_XMR {u'success': 0, u'error': u'Invalid pair name: post_xmr'}
# POST_ZEC {u'success': 0, u'error': u'Invalid pair name: post_zec'}
# POSW_1ST {u'success': 0, u'error': u'Invalid pair name: posw_1st'}
# POSW_2GIVE {u'success': 0, u'error': u'Invalid pair name: posw_2give'}
# POSW_8BIT {u'success': 0, u'error': u'Invalid pair name: posw_8bit'}
# POSW_ABY {u'success': 0, u'error': u'Invalid pair name: posw_aby'}
# POSW_ACP {u'success': 0, u'error': u'Invalid pair name: posw_acp'}
# POSW_ADCN {u'success': 0, u'error': u'Invalid pair name: posw_adcn'}
# POSW_ADZ {u'success': 0, u'error': u'Invalid pair name: posw_adz'}
# POSW_AEON {u'success': 0, u'error': u'Invalid pair name: posw_aeon'}
# POSW_AIB {u'success': 0, u'error': u'Invalid pair name: posw_aib'}
# POSW_AMP {u'success': 0, u'error': u'Invalid pair name: posw_amp'}
# POSW_ARC {u'success': 0, u'error': u'Invalid pair name: posw_arc'}
# POSW_ARDR {u'success': 0, u'error': u'Invalid pair name: posw_ardr'}
# POSW_AUR {u'success': 0, u'error': u'Invalid pair name: posw_aur'}
# POSW_BASH {u'success': 0, u'error': u'Invalid pair name: posw_bash'}
# POSW_BAY {u'success': 0, u'error': u'Invalid pair name: posw_bay'}
# POSW_BCC {u'success': 0, u'error': u'Invalid pair name: posw_bcc'}
# POSW_BCN {u'success': 0, u'error': u'Invalid pair name: posw_bcn'}
# POSW_BCY {u'success': 0, u'error': u'Invalid pair name: posw_bcy'}
# POSW_BHC {u'success': 0, u'error': u'Invalid pair name: posw_bhc'}
# POSW_BIOS {u'success': 0, u'error': u'Invalid pair name: posw_bios'}
# POSW_BIT {u'success': 0, u'error': u'Invalid pair name: posw_bit'}
# POSW_BITB {u'success': 0, u'error': u'Invalid pair name: posw_bitb'}
# POSW_BLK {u'success': 0, u'error': u'Invalid pair name: posw_blk'}
# POSW_BLU {u'success': 0, u'error': u'Invalid pair name: posw_blu'}
# POSW_BPC {u'success': 0, u'error': u'Invalid pair name: posw_bpc'}
# POSW_BSD {u'success': 0, u'error': u'Invalid pair name: posw_bsd'}
# POSW_BTA {u'success': 0, u'error': u'Invalid pair name: posw_bta'}
# POSW_BTC {u'success': 0, u'error': u'Invalid pair name: posw_btc'}
# POSW_BTC {u'success': 0, u'error': u'Invalid pair name: posw_btc'}
# POSW_BTCD {u'success': 0, u'error': u'Invalid pair name: posw_btcd'}
# POSW_BTS {u'success': 0, u'error': u'Invalid pair name: posw_bts'}
# POSW_BURST {u'success': 0, u'error': u'Invalid pair name: posw_burst'}
# POSW_CANN {u'success': 0, u'error': u'Invalid pair name: posw_cann'}
# POSW_CCRB {u'success': 0, u'error': u'Invalid pair name: posw_ccrb'}
# POSW_CJ {u'success': 0, u'error': u'Invalid pair name: posw_cj'}
# POSW_CLAM {u'success': 0, u'error': u'Invalid pair name: posw_clam'}
# POSW_CLOAK {u'success': 0, u'error': u'Invalid pair name: posw_cloak'}
# POSW_CLUB {u'success': 0, u'error': u'Invalid pair name: posw_club'}
# POSW_CNT {u'success': 0, u'error': u'Invalid pair name: posw_cnt'}
# POSW_CPC {u'success': 0, u'error': u'Invalid pair name: posw_cpc'}
# POSW_CREVA {u'success': 0, u'error': u'Invalid pair name: posw_creva'}
# POSW_CRW {u'success': 0, u'error': u'Invalid pair name: posw_crw'}
# POSW_CURE {u'success': 0, u'error': u'Invalid pair name: posw_cure'}
# POSW_DASH {u'success': 0, u'error': u'Invalid pair name: posw_dash'}
# POSW_DASH {u'success': 0, u'error': u'Invalid pair name: posw_dash'}
# POSW_DCR {u'success': 0, u'error': u'Invalid pair name: posw_dcr'}
# POSW_DCT {u'success': 0, u'error': u'Invalid pair name: posw_dct'}
# POSW_DGB {u'success': 0, u'error': u'Invalid pair name: posw_dgb'}
# POSW_DGD {u'success': 0, u'error': u'Invalid pair name: posw_dgd'}
# POSW_DIME {u'success': 0, u'error': u'Invalid pair name: posw_dime'}
# POSW_DOGE {u'success': 0, u'error': u'Invalid pair name: posw_doge'}
# POSW_DOGE {u'success': 0, u'error': u'Invalid pair name: posw_doge'}
# POSW_DRACO {u'success': 0, u'error': u'Invalid pair name: posw_draco'}
# POSW_DRZ {u'success': 0, u'error': u'Invalid pair name: posw_drz'}
# POSW_DSH {u'success': 0, u'error': u'Invalid pair name: posw_dsh'}
# POSW_ECN {u'success': 0, u'error': u'Invalid pair name: posw_ecn'}
# POSW_EGC {u'success': 0, u'error': u'Invalid pair name: posw_egc'}
# POSW_EL {u'success': 0, u'error': u'Invalid pair name: posw_el'}
# POSW_ELE {u'success': 0, u'error': u'Invalid pair name: posw_ele'}
# POSW_EMC {u'success': 0, u'error': u'Invalid pair name: posw_emc'}
# POSW_EMC2 {u'success': 0, u'error': u'Invalid pair name: posw_emc2'}
# POSW_ENT {u'success': 0, u'error': u'Invalid pair name: posw_ent'}
# POSW_ETC {u'success': 0, u'error': u'Invalid pair name: posw_etc'}
# POSW_ETC {u'success': 0, u'error': u'Invalid pair name: posw_etc'}
# POSW_ETH {u'success': 0, u'error': u'Invalid pair name: posw_eth'}
# POSW_ETH {u'success': 0, u'error': u'Invalid pair name: posw_eth'}
# POSW_EUR {u'success': 0, u'error': u'Invalid pair name: posw_eur'}
# POSW_EUR {u'success': 0, u'error': u'Invalid pair name: posw_eur'}
# POSW_EXP {u'success': 0, u'error': u'Invalid pair name: posw_exp'}
# POSW_FCT {u'success': 0, u'error': u'Invalid pair name: posw_fct'}
# POSW_FJC {u'success': 0, u'error': u'Invalid pair name: posw_fjc'}
# POSW_FRST {u'success': 0, u'error': u'Invalid pair name: posw_frst'}
# POSW_GAME {u'success': 0, u'error': u'Invalid pair name: posw_game'}
# POSW_GB {u'success': 0, u'error': u'Invalid pair name: posw_gb'}
# POSW_GCR {u'success': 0, u'error': u'Invalid pair name: posw_gcr'}
# POSW_GEO {u'success': 0, u'error': u'Invalid pair name: posw_geo'}
# POSW_GHS {u'success': 0, u'error': u'Invalid pair name: posw_ghs'}
# POSW_GLD {u'success': 0, u'error': u'Invalid pair name: posw_gld'}
# POSW_GNO {u'success': 0, u'error': u'Invalid pair name: posw_gno'}
# POSW_GNT {u'success': 0, u'error': u'Invalid pair name: posw_gnt'}
# POSW_GOLOS {u'success': 0, u'error': u'Invalid pair name: posw_golos'}
# POSW_GRC {u'success': 0, u'error': u'Invalid pair name: posw_grc'}
# POSW_GUP {u'success': 0, u'error': u'Invalid pair name: posw_gup'}
# POSW_HCC {u'success': 0, u'error': u'Invalid pair name: posw_hcc'}
# POSW_HXX {u'success': 0, u'error': u'Invalid pair name: posw_hxx'}
# POSW_ICN {u'success': 0, u'error': u'Invalid pair name: posw_icn'}
# POSW_INCNT {u'success': 0, u'error': u'Invalid pair name: posw_incnt'}
# POSW_INFX {u'success': 0, u'error': u'Invalid pair name: posw_infx'}
# POSW_IOC {u'success': 0, u'error': u'Invalid pair name: posw_ioc'}
# POSW_ION {u'success': 0, u'error': u'Invalid pair name: posw_ion'}
# POSW_IOP {u'success': 0, u'error': u'Invalid pair name: posw_iop'}
# POSW_ISL {u'success': 0, u'error': u'Invalid pair name: posw_isl'}
# POSW_ITI {u'success': 0, u'error': u'Invalid pair name: posw_iti'}
# POSW_JWL {u'success': 0, u'error': u'Invalid pair name: posw_jwl'}
# POSW_KC {u'success': 0, u'error': u'Invalid pair name: posw_kc'}
# POSW_LBC {u'success': 0, u'error': u'Invalid pair name: posw_lbc'}
# POSW_LEO {u'success': 0, u'error': u'Invalid pair name: posw_leo'}
# POSW_LEPEN {u'success': 0, u'error': u'Invalid pair name: posw_lepen'}
# POSW_LSK {u'success': 0, u'error': u'Invalid pair name: posw_lsk'}
# POSW_LTC {u'success': 0, u'error': u'Invalid pair name: posw_ltc'}
# POSW_LTC {u'success': 0, u'error': u'Invalid pair name: posw_ltc'}
# POSW_LTCR {u'success': 0, u'error': u'Invalid pair name: posw_ltcr'}
# POSW_LTS {u'success': 0, u'error': u'Invalid pair name: posw_lts'}
# POSW_LUN {u'success': 0, u'error': u'Invalid pair name: posw_lun'}
# POSW_LUNA {u'success': 0, u'error': u'Invalid pair name: posw_luna'}
# POSW_MAID {u'success': 0, u'error': u'Invalid pair name: posw_maid'}
# POSW_MLN {u'success': 0, u'error': u'Invalid pair name: posw_mln'}
# POSW_MOIN {u'success': 0, u'error': u'Invalid pair name: posw_moin'}
# POSW_MOJO {u'success': 0, u'error': u'Invalid pair name: posw_mojo'}
# POSW_MONA {u'success': 0, u'error': u'Invalid pair name: posw_mona'}
# POSW_MSCN {u'success': 0, u'error': u'Invalid pair name: posw_mscn'}
# POSW_MUE {u'success': 0, u'error': u'Invalid pair name: posw_mue'}
# POSW_NAUT {u'success': 0, u'error': u'Invalid pair name: posw_naut'}
# POSW_NAV {u'success': 0, u'error': u'Invalid pair name: posw_nav'}
# POSW_NLG {u'success': 0, u'error': u'Invalid pair name: posw_nlg'}
# POSW_NMC {u'success': 0, u'error': u'Invalid pair name: posw_nmc'}
# POSW_NOTE {u'success': 0, u'error': u'Invalid pair name: posw_note'}
# POSW_NVC {u'success': 0, u'error': u'Invalid pair name: posw_nvc'}
# POSW_NXC {u'success': 0, u'error': u'Invalid pair name: posw_nxc'}
# POSW_NXT {u'success': 0, u'error': u'Invalid pair name: posw_nxt'}
# POSW_NXT {u'success': 0, u'error': u'Invalid pair name: posw_nxt'}
# POSW_OD {u'success': 0, u'error': u'Invalid pair name: posw_od'}
# POSW_OK {u'success': 0, u'error': u'Invalid pair name: posw_ok'}
# POSW_OMNI {u'success': 0, u'error': u'Invalid pair name: posw_omni'}
# POSW_OTX {u'success': 0, u'error': u'Invalid pair name: posw_otx'}
# POSW_PINK {u'success': 0, u'error': u'Invalid pair name: posw_pink'}
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-13-0fa0c5c5258e> in <module>()
#       6     #depth_url=base_url+"depth/"+pairs
#       7
# ----> 8     html_ticker=requests.get(ticker_url).text
#       9     #html_depth=requests.get(depth_url).text
#      10
#
# C:\Anaconda2\lib\site-packages\requests\api.pyc in get(url, params, **kwargs)
#      69
#      70     kwargs.setdefault('allow_redirects', True)
# ---> 71     return request('get', url, params=params, **kwargs)
#      72
#      73
#
# C:\Anaconda2\lib\site-packages\requests\api.pyc in request(method, url, **kwargs)
#      55     # cases, and look like a memory leak in others.
#      56     with sessions.Session() as session:
# ---> 57         return session.request(method=method, url=url, **kwargs)
#      58
#      59
#
# C:\Anaconda2\lib\site-packages\requests\sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     473         }
#     474         send_kwargs.update(settings)
# --> 475         resp = self.send(prep, **send_kwargs)
#     476
#     477         return resp
#
# C:\Anaconda2\lib\site-packages\requests\sessions.pyc in send(self, request, **kwargs)
#     583
#     584         # Send the request
# --> 585         r = adapter.send(request, **kwargs)
#     586
#     587         # Total elapsed time of the request (approximately)
#
# C:\Anaconda2\lib\site-packages\requests\adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     451
#     452         except (ProtocolError, socket.error) as err:
# --> 453             raise ConnectionError(err, request=request)
#     454
#     455         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', error(10054, ''))
