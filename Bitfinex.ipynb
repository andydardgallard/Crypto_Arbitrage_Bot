# %%
import requests
import json
import csv

def write_csv(new_line):
    with open("bitfinex.csv", "a" ) as fout:
        writer=csv.writer(fout)
        writer.writerow((new_line))

# %%
pos=0.25
base_url="https://api.bitfinex.com/v1/"
pairs=open('pairs.txt').read()
pairs=pairs.lower().replace("_","").split("\n")

symbol_url=base_url+"symbols"
html_symbol=requests.get(symbol_url).text
symbol_data=json.loads(html_symbol)
#print symbol_data

for i in symbol_data:
    if i in pairs:
        ticker_url=base_url+"pubticker/"+i
        html_ticker=requests.get(ticker_url).text
        ticker_data=json.loads(html_ticker)        

        depth_url=base_url+"book/"+i
        html_depth=requests.get(depth_url).text
        depth_data=json.loads(html_depth)

        q=0
        w=[]
        e=[]
        for j in depth_data["bids"]:
            q=q+float(j["amount"])
            if q>pos:
                w.append(j)
            if q<pos:
                e.append(j)      
        r=0
        t=0
        for j in e:
            r=float(j["price"])*float(j["amount"])+r
            t=float(j["amount"])+t    
        r=float(w[0]["price"])*(pos-t)+r
        bids=r/pos
    
        q=0
        w=[]
        e=[]
        for j in depth_data["asks"]:
            q=q+float(j["amount"])
            if q>pos:
                w.append(j)
            if q<pos:
                e.append(j)    
        r=0
        t=0
        for j in e:
            r=float(j["price"])*float(j["amount"])+r
            t=float(j["amount"])+t    
        r=float(w[0]["price"])*(pos-t)+r
        asks=r/pos     
    
        new_line=["bitfinex", i.upper(), ticker_data["ask"], ticker_data["bid"], asks, bids]
        print new_line
        write_csv(new_line)
# Out:
# ['bitfinex', u'LTCBTC', u'0.018285', u'0.018265', 0.018295168, 0.018265]
# ['bitfinex', u'ETHBTC', u'0.13893', u'0.13888', 0.13889, 0.13866]
# ['bitfinex', u'ETCBTC', u'0.0083987', u'0.0083663', 0.0083993, 0.008367]
# ['bitfinex', u'ZECBTC', u'0.15183', u'0.15136', 0.15183, 0.15136]
# ['bitfinex', u'XMRBTC', u'0.019702', u'0.019647', 0.019702, 0.019643479999999998]

# %%
#pairs=open('pairs.txt').read()#.split("\n")

# %%
#h=0
#for i in symbol_data:
#    if i in pairs:
#        h=h+1
#        ticker_url=base_url+"pubticker/"+i
#        print h, i, ticker_url

# %%
#pairs=pairs.lower().replace("_","").split("\n")
#print pairs
# Out:
# ['btcltc', 'btcdoge', 'btceth', 'btcdash', 'btcxmr', 'btcetc', 'btcusdt', 'btcposw', 'btczec', 'btcnxt', 'btcrep', 'ltcbtc', 'dogebtc', 'ethbtc', 'dashbtc', 'xmrbtc', 'etcbtc', 'usdtbtc', 'poswbtc', 'zecbtc', 'nxtbtc', 'repbtc', 'nvcbtc']

# %%
from time import sleep

# %%
g=0
while g<5:
    g=g+1
    print g, "start"
    # %run exmo
    # %run poloniex
    print g, "stop"
    sleep(60)
# Out:
# 1 start
# ['exmo', 'ETHUSD', '358,8', '358,1', '359,720565162', '358,1']
# ['exmo', 'DASHRUB', '11750,4785702', '11659,1838489', '11763,5784475', '11645,6218782']
# ['poloniex', u'BTCZEC', '0,15177461', '0,15175000', '0,151774600567', '0,15175']
# ['poloniex', u'BTCETC', '0,00842900', '0,00841132', '0,008429', '0,00841132']
# ['poloniex', u'BTCETH', '0,13883227', '0,13870000', '0,13883227', '0,13855002']
# ['poloniex', u'BTCDOGE', '0,00000119', '0,00000118', '1,19e-06', '1,18e-06']
# ['poloniex', u'BTCXMR', '0,01970494', '0,01970450', '0,0197049460936', '0,0197045']
# 4 stop
# 5 start
# ['exmo', 'ETHUSD', '359,5', '359,00000001', '359,811543938', '359,000000001']
# ['exmo', 'DASHRUB', '11750,4785702', '11659,1838489', '11763,7373867', '11647,5346789']
# ['exmo', 'BTCUSD', '2587,49799999', '2570,33032', '2591,23270564', '2568,20448073']
# ['exmo', 'LTCBTC', '0,01855', '0,01844', '0,0185586632358', '0,01843516']
# ['exmo', 'BTCRUB', '153696,88373739', '153000,00000001', '153697,12109', '152944,630849']
# ['exmo', 'USDRUB', '59,45999999', '59,17000001', '59,45999999', '59,17000001']
# ['exmo', 'ETHBTC', '0,1389', '0,1382', '0,139017588', '0,1382']
# ['exmo', 'ETHEUR', '321,40468154', '321,35414427', '321,40468154', '319,825439533']
# ['exmo', 'ETHLTC', '7,549', '7,50000001', '7,54901753792', '7,50000000067']
# ['exmo', 'DOGEBTC', '0,0000012', '0,00000119', '1,2e-06', '1,19e-06']
# ['exmo', 'DASHBTC', '0,07607492', '0,07588', '0,07607492', '0,07588']
# ['exmo', 'BTCUAH', '70890', '68874', '70995,6', '68549,5747461']
# ['exmo', 'ETHRUB', '21416,999999', '21223,43000001', '21416,999999', '21218,9181055']
# ['exmo', 'DASHUSD', '197,4475697', '196,01001', '197,72815013', '196,01000054']
# ['exmo', 'LTCRUB', '2856,86051837', '2838', '2856,86051837', '2834,34645179']
# ['exmo', 'BTCEUR', '2315,4013917', '2300,00054', '2339,99536612', '2298,09510102']
# ['poloniex', u'BTCREP', '0,01265262', '0,01265002', '0,01265262', '0,01265002']
# ['poloniex', u'USDTBTC', '2558,89294500', '2558,77777781', '2565,37953862', '2558,77777781']
# ['poloniex', u'BTCNXT', '0,00007180', '0,00007165', '7,18e-05', '7,165e-05']
# ['poloniex', u'BTCLTC', '0,01852000', '0,01851366', '0,01852', '0,0185032765871']
# ['poloniex', u'BTCDASH', '0,07628000', '0,07620000', '0,0762898416091', '0,0762']
# ['poloniex', u'BTCZEC', '0,15177458', '0,15175000', '0,151774581134', '0,15175']
# ['poloniex', u'BTCETC', '0,00841216', '0,00841101', '0,00841216', '0,00841101']
# ['poloniex', u'BTCETH', '0,13858415', '0,13858414', '0,138709379237', '0,138570710175']
# ['poloniex', u'BTCDOGE', '0,00000119', '0,00000118', '1,19e-06', '1,18e-06']
# ['poloniex', u'BTCXMR', '0,01974198', '0,01972349', '0,01974198', '0,01972349']
# 5 stop

# %%
# Out:
# ERROR: File `u'exmo,.py'` not found.
