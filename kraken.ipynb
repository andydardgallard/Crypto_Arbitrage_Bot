# %%
import requests
import json
import csv

def write_csv(new_line):
    with open("kraken.csv", "a" ) as fout:
        writer=csv.writer(fout)
        writer.writerow((new_line))

# %%
pos=0.25
base_url="https://api.kraken.com/0/public/"

pairs=open('pairs.txt').read()
pairs=pairs.replace("_","").replace("BTC","XBT").split("\n")

symbol_url=base_url+"AssetPairs"
html_symbol=requests.get(symbol_url).text
symbol_data=json.loads(html_symbol)

symbols=[]
z=0
for i in symbol_data['result']:   
    symbols.append(symbol_data['result'][i]["altname"])    

symbols=str(symbols).replace("[","").replace("]",'').replace("u",'').replace(" ","").replace("'","")

ticker_url=base_url+"Ticker?pair="+symbols
html_ticker=requests.get(ticker_url).text
ticker_data=json.loads(html_ticker)

for i in ticker_data['result']:
    if symbol_data['result'][i]["altname"] in pairs:
        depth_url=base_url+"Depth?pair="+symbol_data['result'][i]["altname"]+'&count=10'
        html_depth=requests.get(depth_url).text
        depth_data=json.loads(html_depth)
    
        try:
            q=0
            w=[]
            e=[]
            for j in depth_data['result'][i]['bids']:    
                q=q+float(j[1])
                if q>pos:
                    w.append(j)
                if q<pos:
                    e.append(j)  
            r=0
            t=0
            for j in e:
                r=float(j[0])*j[1]+r
                t=j[1]+t    
            r=float(w[0][0])*(pos-t)+r
            bids=r/pos        
        except:
            bids=ticker_data['result'][i]['b'][0]        
        
        try:
            q=0
            w=[]
            e=[]
            for j in depth_data['result'][i]['asks']:    
                q=q+float(j[1])
                if q>pos:
                    w.append(j)
                if q<pos:
                    e.append(j)  
            r=0
            t=0
            for j in e:
                r=float(j[0])*j[1]+r
                t=j[1]+t    
            r=float(w[0][0])*(pos-t)+r
            asks=r/pos        
        except:
            asks=ticker_data['result'][i]['a'][0]
        
        new_line=["kraken", symbol_data['result'][i]["altname"].replace("XBT","BTC"), ticker_data['result'][i]['a'][0], 
                  ticker_data['result'][i]['b'][0], asks, bids]
        
        print new_line
        write_csv(new_line)
# Out:
# 1 ['kraken', u'XMRUSD', u'47.75545000', u'47.30021000', 47.75545, 47.30021]
# 2 ['kraken', u'ETHUSD', u'349.99984', u'349.00030', 349.99984, 349.0003]
# 3 ['kraken', u'XMREUR', u'43.00440000', u'42.26514000', 43.0044, 42.26514]
# 4 ['kraken', u'GNOEUR', u'218.949830', u'214.089330', 218.94982, 214.08934]
# 5 ['kraken', u'XLMUSD', u'0.03706300', u'0.03671400', 0.037062, 0.036714]
# 6 ['kraken', u'XMRBTC', u'0.01932500', u'0.01920400', 0.019325, 0.019205]
# 7 ['kraken', u'MLNETH', u'0.25993000', u'0.25901000', 0.25993, 0.25901]
# 8 ['kraken', u'DASHBTC', u'0.06585800', u'0.06504600', 0.065857, 0.065048]
# 9 ['kraken', u'ZECEUR', u'339.99980', u'336.10037', u'339.99980', 336.10038]
# 10 ['kraken', u'GNOBTC', u'0.09849900', u'0.09755100', 0.098499, 0.097551]
# 11 ['kraken', u'XLMEUR', u'0.03304700', u'0.03300900', 0.033229, 0.033108]
# 12 ['kraken', u'XRPUSD', u'0.24969700', u'0.24770300', 0.249695, 0.247704]
# 13 ['kraken', u'REPBTC', u'0.011499', u'0.011434', 0.011548, 0.011445]
# 14 ['kraken', u'REPETH', u'0.080790', u'0.080270', 0.08099, 0.0803]
# 15 ['kraken', u'ETHBTC', u'0.142351', u'0.142081', 0.142351, 0.142081]
# 16 ['kraken', u'LTCUSD', u'32.89500', u'32.60206', u'32.89500', 32.60201]
# 17 ['kraken', u'ZECUSD', u'378.11462', u'372.84907', u'378.11462', 372.84927]
# 18 ['kraken', u'ETCBTC', u'0.00697869', u'0.00692700', 0.00697866, 0.00692801]
# 19 ['kraken', u'LTCEUR', u'29.39799', u'29.28700', 29.395, 29.27002]
# 20 ['kraken', u'ETCETH', u'0.04919259', u'0.04863506', u'0.04919259', 0.04863511]
# 21 ['kraken', u'LTCBTC', u'0.01330900', u'0.01327300', 0.013306, 0.013268]
# 22 ['kraken', u'ZECBTC', u'0.153724', u'0.152584', 0.153725, 0.15259]
# 23 ['kraken', u'GNOETH', u'0.68500000', u'0.68050600', u'0.68500000', 0.680527]
# 24 ['kraken', u'ETHEUR', u'315.09998', u'315.09964', 314.98999, u'315.09964']
# 25 ['kraken', u'ICNBTC', u'0.000785', u'0.000782', 0.000785, 0.000783]
# 26 ['kraken', u'XLMBTC', u'0.000015010', u'0.000014880', 1.508e-05, 1.49e-05]
# 27 ['kraken', u'ETCEUR', u'15.47562000', u'15.27117000', 15.47554, 15.2717]
# 28 ['kraken', u'MLNBTC', u'0.03703100', u'0.03659200', 0.037033, u'0.03659200']
# 29 ['kraken', u'ICNETH', u'0.005530', u'0.005510', 0.00553, 0.00551]
# 30 ['kraken', u'XRPBTC', u'0.000101000', u'0.000100530', 0.00010099, 0.00010012]
# 31 ['kraken', u'REPUSD', u'28.57459', u'26.45279', 28.57452, 27.69395]
# 32 ['kraken', u'XRPEUR', u'0.22359300', u'0.22121100', 0.22359, 0.221205]
# 33 ['kraken', u'DASHEUR', u'147.496830', u'144.100000', 147.49661, u'144.100000']
# 34 ['kraken', u'BTCEUR', u'2211.89400', u'2205.64500', 2210.998, u'2205.64500']
# 35 ['kraken', u'ETCUSD', u'17.14893000', u'17.04001000', 17.12213, 17.04013]
# 36 ['kraken', u'REPEUR', u'25.39997', u'25.30000', 25.39998, 25.3]
# 37 ['kraken', u'GNOUSD', u'244.994470', u'238.570880', 244.99441, 238.57092]
# 38 ['kraken', u'DASHUSD', u'165.882910', u'160.882940', 165.8826, u'160.882940']
# 39 ['kraken', u'BTCUSD', u'2466.03300', u'2455.65900', u'2466.03300', 2453.091]
# 40 ['kraken', u'USDTUSD', u'1.02670000', u'1.01020000', 1.0267, 1.0101]

# %%
pairs=open('pairs.txt').read()
pairs=pairs.replace("_","").replace("BTC","XBT").split("\n")
print pairs
# Out:
# ['1STXBT', '1STDASH', '1STDOGE', '1STETC', '1STETH', '1STEUR', '1STLTC', '1STNXT', '1STPOSW', '1STREP', '1STRUR', '1STUSD', '1STUSDT', '1STXMR', '1STZEC', '2GIVEXBT', '2GIVEDASH', '2GIVEDOGE', '2GIVEETC', '2GIVEETH', '2GIVEEUR', '2GIVELTC', '2GIVENXT', '2GIVEPOSW', '2GIVEREP', '2GIVERUR', '2GIVEUSD', '2GIVEUSDT', '2GIVEXMR', '2GIVEZEC', '8BITXBT', '8BITDASH', '8BITDOGE', '8BITETC', '8BITETH', '8BITEUR', '8BITLTC', '8BITNXT', '8BITPOSW', '8BITREP', '8BITRUR', '8BITUSD', '8BITUSDT', '8BITXMR', '8BITZEC', 'ABYXBT', 'ABYDASH', 'ABYDOGE', 'ABYETC', 'ABYETH', 'ABYEUR', 'ABYLTC', 'ABYNXT', 'ABYPOSW', 'ABYREP', 'ABYRUR', 'ABYUSD', 'ABYUSDT', 'ABYXMR', 'ABYZEC', 'ACPXBT', 'ACPDASH', 'ACPDOGE', 'ACPETC', 'ACPETH', 'ACPEUR', 'ACPLTC', 'ACPNXT', 'ACPPOSW', 'ACPREP', 'ACPRUR', 'ACPUSD', 'ACPUSDT', 'ACPXMR', 'ACPZEC', 'ADCNXBT', 'ADCNDASH', 'ADCNDOGE', 'ADCNETC', 'ADCNETH', 'ADCNEUR', 'ADCNLTC', 'ADCNNXT', 'ADCNPOSW', 'ADCNREP', 'ADCNRUR', 'ADCNUSD', 'ADCNUSDT', 'ADCNXMR', 'ADCNZEC', 'ADZXBT', 'ADZDASH', 'ADZDOGE', 'ADZETC', 'ADZETH', 'ADZEUR', 'ADZLTC', 'ADZNXT', 'ADZPOSW', 'ADZREP', 'ADZRUR', 'ADZUSD', 'ADZUSDT', 'ADZXMR', 'ADZZEC', 'AEONXBT', 'AEONDASH', 'AEONDOGE', 'AEONETC', 'AEONETH', 'AEONEUR', 'AEONLTC', 'AEONNXT', 'AEONPOSW', 'AEONREP', 'AEONRUR', 'AEONUSD', 'AEONUSDT', 'AEONXMR', 'AEONZEC', 'AIBXBT', 'AIBDASH', 'AIBDOGE', 'AIBETC', 'AIBETH', 'AIBEUR', 'AIBLTC', 'AIBNXT', 'AIBPOSW', 'AIBREP', 'AIBRUR', 'AIBUSD', 'AIBUSDT', 'AIBXMR', 'AIBZEC', 'AMPXBT', 'AMPDASH', 'AMPDOGE', 'AMPETC', 'AMPETH', 'AMPEUR', 'AMPLTC', 'AMPNXT', 'AMPPOSW', 'AMPREP', 'AMPRUR', 'AMPUSD', 'AMPUSDT', 'AMPXMR', 'AMPZEC', 'ARCXBT', 'ARCDASH', 'ARCDOGE', 'ARCETC', 'ARCETH', 'ARCEUR', 'ARCLTC', 'ARCNXT', 'ARCPOSW', 'ARCREP', 'ARCRUR', 'ARCUSD', 'ARCUSDT', 'ARCXMR', 'ARCZEC', 'ARDRXBT', 'ARDRDASH', 'ARDRDOGE', 'ARDRETC', 'ARDRETH', 'ARDREUR', 'ARDRLTC', 'ARDRNXT', 'ARDRPOSW', 'ARDRREP', 'ARDRRUR', 'ARDRUSD', 'ARDRUSDT', 'ARDRXMR', 'ARDRZEC', 'AURXBT', 'AURDASH', 'AURDOGE', 'AURETC', 'AURETH', 'AUREUR', 'AURLTC', 'AURNXT', 'AURPOSW', 'AURREP', 'AURRUR', 'AURUSD', 'AURUSDT', 'AURXMR', 'AURZEC', 'BASHXBT', 'BASHDASH', 'BASHDOGE', 'BASHETC', 'BASHETH', 'BASHEUR', 'BASHLTC', 'BASHNXT', 'BASHPOSW', 'BASHREP', 'BASHRUR', 'BASHUSD', 'BASHUSDT', 'BASHXMR', 'BASHZEC', 'BAYXBT', 'BAYDASH', 'BAYDOGE', 'BAYETC', 'BAYETH', 'BAYEUR', 'BAYLTC', 'BAYNXT', 'BAYPOSW', 'BAYREP', 'BAYRUR', 'BAYUSD', 'BAYUSDT', 'BAYXMR', 'BAYZEC', 'BCCXBT', 'BCCDASH', 'BCCDOGE', 'BCCETC', 'BCCETH', 'BCCEUR', 'BCCLTC', 'BCCNXT', 'BCCPOSW', 'BCCREP', 'BCCRUR', 'BCCUSD', 'BCCUSDT', 'BCCXMR', 'BCCZEC', 'BCNXBT', 'BCNDASH', 'BCNDOGE', 'BCNETC', 'BCNETH', 'BCNEUR', 'BCNLTC', 'BCNNXT', 'BCNPOSW', 'BCNREP', 'BCNRUR', 'BCNUSD', 'BCNUSDT', 'BCNXMR', 'BCNZEC', 'BCYXBT', 'BCYDASH', 'BCYDOGE', 'BCYETC', 'BCYETH', 'BCYEUR', 'BCYLTC', 'BCYNXT', 'BCYPOSW', 'BCYREP', 'BCYRUR', 'BCYUSD', 'BCYUSDT', 'BCYXMR', 'BCYZEC', 'BHCXBT', 'BHCDASH', 'BHCDOGE', 'BHCETC', 'BHCETH', 'BHCEUR', 'BHCLTC', 'BHCNXT', 'BHCPOSW', 'BHCREP', 'BHCRUR', 'BHCUSD', 'BHCUSDT', 'BHCXMR', 'BHCZEC', 'BIOSXBT', 'BIOSDASH', 'BIOSDOGE', 'BIOSETC', 'BIOSETH', 'BIOSEUR', 'BIOSLTC', 'BIOSNXT', 'BIOSPOSW', 'BIOSREP', 'BIOSRUR', 'BIOSUSD', 'BIOSUSDT', 'BIOSXMR', 'BIOSZEC', 'BITXBT', 'BITDASH', 'BITDOGE', 'BITETC', 'BITETH', 'BITEUR', 'BITLTC', 'BITNXT', 'BITPOSW', 'BITREP', 'BITRUR', 'BITUSD', 'BITUSDT', 'BITXMR', 'BITZEC', 'BITBXBT', 'BITBDASH', 'BITBDOGE', 'BITBETC', 'BITBETH', 'BITBEUR', 'BITBLTC', 'BITBNXT', 'BITBPOSW', 'BITBREP', 'BITBRUR', 'BITBUSD', 'BITBUSDT', 'BITBXMR', 'BITBZEC', 'BLKXBT', 'BLKDASH', 'BLKDOGE', 'BLKETC', 'BLKETH', 'BLKEUR', 'BLKLTC', 'BLKNXT', 'BLKPOSW', 'BLKREP', 'BLKRUR', 'BLKUSD', 'BLKUSDT', 'BLKXMR', 'BLKZEC', 'BLUXBT', 'BLUDASH', 'BLUDOGE', 'BLUETC', 'BLUETH', 'BLUEUR', 'BLULTC', 'BLUNXT', 'BLUPOSW', 'BLUREP', 'BLURUR', 'BLUUSD', 'BLUUSDT', 'BLUXMR', 'BLUZEC', 'BPCXBT', 'BPCDASH', 'BPCDOGE', 'BPCETC', 'BPCETH', 'BPCEUR', 'BPCLTC', 'BPCNXT', 'BPCPOSW', 'BPCREP', 'BPCRUR', 'BPCUSD', 'BPCUSDT', 'BPCXMR', 'BPCZEC', 'BSDXBT', 'BSD ...

# %%
print depth_url
# Out:
# https://api.kraken.com/0/public/Depth?pair=USDTUSD&count=10
