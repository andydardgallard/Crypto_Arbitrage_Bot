# %%
from time import sleep

k=1
while k<288:    
    try:
        print k, "start"
        # %run USD-BTC.ipynb
        #%run RUB-BTC.ipynb
    
        print k, "stop" 
        sleep(255)
        k=k+1
    except:
        pass
# Out:
# 1 start
# ['2017-07-18 12:38:42', 'btc-e', 'USD_BTC', '2190', '2186,19', '2192,391606', '2186,17310477']
# ['2017-07-18 12:38:45', 'bitfinex', 'USD_BTC', '2221,3', '2219,8', '2221,4323', '2219,7']
# ['2017-07-18 12:38:48', 'kraken', 'USD_BTC', '2224,00800', '2220,01000', '2224,00800', '2223,998']
# ['2017-07-18 12:38:48', 'hitbtc', 'USD_BTC', '2217,07', '2215,44', '2220,4651', '2212,6466']
# ['2017-07-18 12:38:49', 'yobit', 'USD_BTC', '2229,5', '2213,89349999', '2230,42436224', '2213,09543867']
# ['2017-07-18 12:38:49', 'exmo', 'USD_BTC', '2246,24', '2234', '2247,96274411', '2233,24793674']
# ['2017-07-18 12:38:51', 'livecoin', 'USD_BTC', '2234,95999', '2234,95986', '2239,85531698', '2185,31627091']
# ['2017-07-18 12:38:52', 'cexio', 'USD_BTC', '2299,9064', '2295,0829', '2299,91022655', '2292,36551991']
# ...
