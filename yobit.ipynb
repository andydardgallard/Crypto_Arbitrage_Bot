# %%
import requests
import json
import csv

def write_csv(new_line):
    with open("yobit.csv", "a" ) as fout:
        writer=csv.writer(fout)
        writer.writerow((new_line))

# %%
pos=0.25
base_url="https://yobit.net/api/3/"

symbol_url=base_url+"info"
html_symbol=requests.get(symbol_url).text
symbol_data=json.loads(html_symbol)

for i in symbol_data['pairs']:
    if i.upper() in pairs:
        ticker_url=base_url+"ticker/"+i
        html_ticker=requests.get(ticker_url).text
        ticker_data=json.loads(html_ticker)
    
        depth_url=base_url+"depth/"+i+"?limit=10"
        html_depth=requests.get(depth_url).text
        depth_data=json.loads(html_depth)
    
        try:
            q=0
            w=[]
            e=[]
            for j in depth_data[i]["bids"]:
                q=q+j[1]
                if q>pos:
                    w.append(j)
                if q<pos:
                    e.append(j)      
            r=0
            t=0
            for j in e:
                r=j[0]*j[1]+r
                t=j[1]+t    
            r=w[0][0]*(pos-t)+r
            bids=r/pos
        except:
            bids=ticker_data[i]['buy']

        try:
            q=0
            w=[]
            e=[]
            for j in depth_data[i]["asks"]:
                q=q+j[1]
                if q>pos:
                    w.append(j)
                if q<pos:
                    e.append(j)    
            r=0
            t=0
            for j in e:
                r=j[0]*j[1]+r
                t=j[1]+t    
            r=w[0][0]*(pos-t)+r
            asks=r/pos
        except:
            asks=ticker_data[i]['sell']
    
        new_line=['yobit', i.upper().replace("_",""), ticker_data[i]['sell'], ticker_data[i]['buy'], asks, bids]
        
        print new_line
        write_csv(new_line)
# Out:
# 1 ['yobit', u'DASHBTC', 0.0660923, 0.0650006, 0.0660923, 0.0650006]
# 2 ['yobit', u'SXCBTC', 2.11e-06, 1.73e-06, 2.11e-06, 1.73e-06]
# 3 ['yobit', u'SIBRUR', 28.78999997, 25.00000002, 28.78999997, 25.00000002]
# 4 ['yobit', u'LSKBTC', 0.00123, 0.00121596, 0.00123, 0.0012140120006364002]
# 5 ['yobit', u'DOGEBTC', 1.21e-06, 1.2e-06, 1.21e-06, 1.2e-06]
# 6 ['yobit', u'DGDBTC', 4.167e-05, 3.906e-05, 4.167e-05, 3.906e-05]
# 7 ['yobit', u'AURBTC', 0.00033801, 0.00023026, 0.00033801, 0.00023026]
# 8 ['yobit', u'CNTBTC', 9.95e-06, 9.22e-06, 9.95e-06, 9.22e-06]
# 9 ['yobit', u'INFXBTC', 0.00028586, 0.00021, 0.00028586, 0.00021]
# 10 ['yobit', u'ITIBTC', 0, 0.00456752, 0, 0.0045641091762956]
# 11 ['yobit', u'PSBBTC', 3.85e-06, 2.96e-06, 3.85e-06, 2.96e-06]
# 12 ['yobit', u'LUNABTC', 8.15e-06, 7e-06, 8.15e-06, 7e-06]
# 13 ['yobit', u'BLUBTC', 5e-07, 3.8e-07, 5e-07, 3.8e-07]
# 14 ['yobit', u'XMSBTC', 0.000106, 7.71e-05, 0.000106, 7.71e-05]
# 15 ['yobit', u'BTABTC', 0.00029972, 0.00025501, 0.00029972, 0.00025501]
# 16 ['yobit', u'CPCBTC', 0.00023554, 0.00018136, 0.00023554, 0.00018136]
# 107 ['yobit', u'PKBBTC', 0.000179, 0.00013274, 0.000179, 0.00013274]
# 108 ['yobit', u'EXPBTC', 0.00199, 0.00125382, 0.00199, 0.0012537215429868002]
# 109 ['yobit', u'2GIVEBTC', 2.3e-06, 1.65e-06, 2.3e-06, 1.65e-06]
# 110 ['yobit', u'FRSTBTC', 0.00119597, 0.00119527, 0.00119597, 0.00119527]
# 111 ['yobit', u'SYNXBTC', 9.785e-05, 5.207e-05, 9.785e-05, 5.207e-05]
# 112 ['yobit', u'MUEBTC', 1.827e-05, 1.681e-05, 1.827e-05, 1.681e-05]
# 113 ['yobit', u'ETHBTC', 0.14353699, 0.14210201, 0.1437320285668348, 0.14210201]
# 114 ['yobit', u'DIMEBTC', 1e-08, 0, 1e-08, 0]
# 115 ['yobit', u'DGBBTC', 1.17e-05, 1.155e-05, 1.17e-05, 1.155e-05]
# 116 ['yobit', u'ENTBTC', 7.89e-06, 6.29e-06, 7.89e-06, 6.29e-06]
# 117 ['yobit', u'DASHRUR', 10297.99999993, 9707.99999994, 10297.99999993, 9707.999999930738]
# 118 ['yobit', u'CJBTC', 1.3e-07, 1.2e-07, 1.3e-07, 1.2e-07]
# 119 ['yobit', u'KCBTC', 2.67e-06, 2.12e-06, 2.67e-06, 2.12e-06]
# 120 ['yobit', u'REEBTC', 3.42e-06, 1.53e-06, 3.42e-06, 1.53e-06]
# 121 ['yobit', u'CRWBTC', 0.0005797, 0.00028013, 0.0005797, 0.00028013]
# 122 ['yobit', u'JWLBTC', 2.14e-06, 1.57e-06, 2.14e-06, 1.57e-06]
# 123 ['yobit', u'DOGEUSD', 0.00329894, 0.00310001, 0.00329894, 0.0031000033078119995]
# 124 ['yobit', u'PPCBTC', 0.00079, 0.00074002, 0.00079427204, 0.00074002]
# 125 ['yobit', u'CANNBTC', 1.98e-05, 1.166e-05, 1.98e-05, 1.166e-05]
# 126 ['yobit', u'UBTC', 1.591e-05, 1.537e-05, 1.591e-05, 1.537e-05]

# %%
pairs=open('pairs.txt').read().split("\n")
print pairs, "876"
# Out:
# ['1ST_BTC', '1ST_DASH', '1ST_DOGE', '1ST_ETC', '1ST_ETH', '1ST_EUR', '1ST_LTC', '1ST_NXT', '1ST_POSW', '1ST_REP', '1ST_RUR', '1ST_USD', '1ST_USDT', '1ST_XMR', '1ST_ZEC', '2GIVE_BTC', '2GIVE_DASH', '2GIVE_DOGE', '2GIVE_ETC', '2GIVE_ETH', '2GIVE_EUR', '2GIVE_LTC', '2GIVE_NXT', '2GIVE_POSW', '2GIVE_REP', '2GIVE_RUR', '2GIVE_USD', '2GIVE_USDT', '2GIVE_XMR', '2GIVE_ZEC', '8BIT_BTC', '8BIT_DASH', '8BIT_DOGE', '8BIT_ETC', '8BIT_ETH', '8BIT_EUR', '8BIT_LTC', '8BIT_NXT', '8BIT_POSW', '8BIT_REP', '8BIT_RUR', '8BIT_USD', '8BIT_USDT', '8BIT_XMR', '8BIT_ZEC', 'ABY_BTC', 'ABY_DASH', 'ABY_DOGE', 'ABY_ETC', 'ABY_ETH', 'ABY_EUR', 'ABY_LTC', 'ABY_NXT', 'ABY_POSW', 'ABY_REP', 'ABY_RUR', 'ABY_USD', 'ABY_USDT', 'ABY_XMR', 'ABY_ZEC', 'ACP_BTC', 'ACP_DASH', 'ACP_DOGE', 'ACP_ETC', 'ACP_ETH', 'ACP_EUR', 'ACP_LTC', 'ACP_NXT', 'ACP_POSW', 'ACP_REP', 'ACP_RUR', 'ACP_USD', 'ACP_USDT', 'ACP_XMR', 'ACP_ZEC', 'ADCN_BTC', 'ADCN_DASH', 'ADCN_DOGE', 'ADCN_ETC', 'ADCN_ETH', 'ADCN_EUR', 'ADCN_LTC', 'ADCN_NXT', 'ADCN_POSW', 'ADCN_REP', 'ADCN_RUR', 'ADCN_USD', 'ADCN_USDT', 'ADCN_XMR', 'ADCN_ZEC', 'ADZ_BTC', 'ADZ_DASH', 'ADZ_DOGE', 'ADZ_ETC', 'ADZ_ETH', 'ADZ_EUR', 'ADZ_LTC', 'ADZ_NXT', 'ADZ_POSW', 'ADZ_REP', 'ADZ_RUR', 'ADZ_USD', 'ADZ_USDT', 'ADZ_XMR', 'ADZ_ZEC', 'AEON_BTC', 'AEON_DASH', 'AEON_DOGE', 'AEON_ETC', 'AEON_ETH', 'AEON_EUR', 'AEON_LTC', 'AEON_NXT', 'AEON_POSW', 'AEON_REP', 'AEON_RUR', 'AEON_USD', 'AEON_USDT', 'AEON_XMR', 'AEON_ZEC', 'AIB_BTC', 'AIB_DASH', 'AIB_DOGE', 'AIB_ETC', 'AIB_ETH', 'AIB_EUR', 'AIB_LTC', 'AIB_NXT', 'AIB_POSW', 'AIB_REP', 'AIB_RUR', 'AIB_USD', 'AIB_USDT', 'AIB_XMR', 'AIB_ZEC', 'AMP_BTC', 'AMP_DASH', 'AMP_DOGE', 'AMP_ETC', 'AMP_ETH', 'AMP_EUR', 'AMP_LTC', 'AMP_NXT', 'AMP_POSW', 'AMP_REP', 'AMP_RUR', 'AMP_USD', 'AMP_USDT', 'AMP_XMR', 'AMP_ZEC', 'ARC_BTC', 'ARC_DASH', 'ARC_DOGE', 'ARC_ETC', 'ARC_ETH', 'ARC_EUR', 'ARC_LTC', 'ARC_NXT', 'ARC_POSW', 'ARC_REP', 'ARC_RUR', 'ARC_USD', 'ARC_USDT', 'ARC_XMR', 'ARC_ZEC', 'ARDR_BTC', 'ARDR_DASH', 'ARDR_DOGE', 'ARDR_ETC', 'ARDR_ETH', 'ARDR_EUR', 'ARDR_LTC', 'ARDR_NXT', 'ARDR_POSW', 'ARDR_REP', 'ARDR_RUR', 'ARDR_USD', 'ARDR_USDT', 'ARDR_XMR', 'ARDR_ZEC', 'AUR_BTC', 'AUR_DASH', 'AUR_DOGE', 'AUR_ETC', 'AUR_ETH', 'AUR_EUR', 'AUR_LTC', 'AUR_NXT', 'AUR_POSW', 'AUR_REP', 'AUR_RUR', 'AUR_USD', 'AUR_USDT', 'AUR_XMR', 'AUR_ZEC', 'BASH_BTC', 'BASH_DASH', 'BASH_DOGE', 'BASH_ETC', 'BASH_ETH', 'BASH_EUR', 'BASH_LTC', 'BASH_NXT', 'BASH_POSW', 'BASH_REP', 'BASH_RUR', 'BASH_USD', 'BASH_USDT', 'BASH_XMR', 'BASH_ZEC', 'BAY_BTC', 'BAY_DASH', 'BAY_DOGE', 'BAY_ETC', 'BAY_ETH', 'BAY_EUR', 'BAY_LTC', 'BAY_NXT', 'BAY_POSW', 'BAY_REP', 'BAY_RUR', 'BAY_USD', 'BAY_USDT', 'BAY_XMR', 'BAY_ZEC', 'BCC_BTC', 'BCC_DASH', 'BCC_DOGE', 'BCC_ETC', 'BCC_ETH', 'BCC_EUR', 'BCC_LTC', 'BCC_NXT', 'BCC_POSW', 'BCC_REP', 'BCC_RUR', 'BCC_USD', 'BCC_USDT', 'BCC_XMR', 'BCC_ZEC', 'BCN_BTC', 'BCN_DASH', 'BCN_DOGE', 'BCN_ETC', 'BCN_ETH', 'BCN_EUR', 'BCN_LTC', 'BCN_NXT', 'BCN_POSW', 'BCN_REP', 'BCN_RUR', 'BCN_USD', 'BCN_USDT', 'BCN_XMR', 'BCN_ZEC', 'BCY_BTC', 'BCY_DASH', 'BCY_DOGE', 'BCY_ETC', 'BCY_ETH', 'BCY_EUR', 'BCY_LTC', 'BCY_NXT', 'BCY_POSW', 'BCY_REP', 'BCY_RUR', 'BCY_USD', 'BCY_USDT', 'BCY_XMR', 'BCY_ZEC', 'BHC_BTC', 'BHC_DASH', 'BHC_DOGE', 'BHC_ETC', 'BHC_ETH', 'BHC_EUR', 'BHC_LTC', 'BHC_NXT', 'BHC_POSW', 'BHC_REP', 'BHC_RUR', 'BHC_USD', 'BHC_USDT', 'BHC_XMR', 'BHC_ZEC', 'BIOS_BTC', 'BIOS_DASH', 'BIOS_DOGE', 'BIOS_ETC', 'BIOS_ETH', 'BIOS_EUR', 'BIOS_LTC', 'BIOS_NXT', 'BIOS_POSW', 'BIOS_REP', 'BIOS_RUR', 'BIOS_USD', 'BIOS_USDT', 'BIOS_XMR', 'BIOS_ZEC', 'BIT_BTC', 'BIT_DASH', 'BIT_DOGE', 'BIT_ETC', 'BIT_ETH', 'BIT_EUR', 'BIT_LTC', 'BIT_NXT', 'BIT_POSW', 'BIT_REP', 'BIT_RUR', 'BIT_USD', 'BIT_USDT', 'BIT_XMR', 'BIT_ZEC', 'BITB_BTC', 'BITB_DASH', 'BITB_DOGE', 'BITB_ETC', 'BITB_ETH', 'BITB_EUR', 'BITB_LTC', 'BITB_NXT', 'BITB_POSW', 'BITB_REP', 'BITB_RUR', 'BITB_USD', 'BITB_USDT', 'BITB_XMR', 'BITB_ZEC', 'BLK_BTC', 'BLK_DASH', 'BLK_DOGE', 'BLK_ETC', 'BLK_ETH', 'BLK_EUR', 'BLK_LTC', 'BLK_NXT', 'BLK_POSW', 'BLK_REP', 'BLK_RUR', 'BLK_USD', 'BLK_USDT', ...

# %%
print i
# Out:
# noo_btc
