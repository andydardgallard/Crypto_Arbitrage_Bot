# %%
import requests
import json
import csv

def write_csv(new_line):
    with open("hitbtc.csv", "a" ) as fout:
        writer=csv.writer(fout)
        writer.writerow((new_line))

# %%
pos=0.25
base_url="https://api.hitbtc.com/api/1/public/"
pairs=open('pairs.txt').read()
pairs=pairs.replace("_","").split("\n")

ticker_url=base_url+"ticker"
html_ticker=requests.get(ticker_url).text
ticker_data=json.loads(html_ticker)

for i in ticker_data:
    if i in pairs:
        depth_url=base_url+i+"/orderbook?format_price=number&format_amount=number"
        html_depth=requests.get(depth_url).text
        depth_data=json.loads(html_depth)
    
        q=0
        w=[]
        e=[]
        for j in depth_data["bids"]:
            q=q+j[1]
            if q>pos:
                w.append(j)
            if q<pos:
                e.append(j)      
        r=0
        t=0
        for j in e:
            r=j[0]*j[1]+r
            t=j[1]+t    
        r=w[0][0]*(pos-t)+r
        bids=r/pos
    
        q=0
        w=[]
        e=[]
        for j in depth_data["asks"]:
            q=q+j[1]
            if q>pos:
                w.append(j)
            if q<pos:
                e.append(j)      
        r=0
        t=0
        for j in e:
            r=j[0]*j[1]+r
            t=j[1]+t    
        r=w[0][0]*(pos-t)+r
        asks=r/pos
    
        new_line=["hitbtc", i, ticker_data[i]["ask"], ticker_data[i]["bid"], asks, bids]
        print new_line
        
        write_csv(new_line)
# Out:
# ['hitbtc', u'XMRBTC', u'0.019294', u'0.019244', 0.019294, 0.019244]
# ['hitbtc', u'BTCEUR', u'2223.00', u'1800.00', 2486.8656, 1800.0]
# ['hitbtc', u'NXCBTC', u'0.00012000', u'0.00008051', 0.00012, 8.051e-05]
# ['hitbtc', u'TIMEBTC', u'0.008488', u'0.007200', 0.008488, 0.0068064]
# ['hitbtc', u'SBDBTC', u'0.00069', u'0.00062', 0.00069, 0.00062]
# ['hitbtc', u'MAIDBTC', u'0.00019137', u'0.00019100', 0.00019139, 0.000191]
# ['hitbtc', u'DASHBTC', u'0.065805', u'0.065600', 0.065805, 0.0656]
# ['hitbtc', u'1STBTC', u'0.000390', u'0.000320', 0.00039, 0.00032]
# ['hitbtc', u'DOGEUSD', u'0.003123', u'0.002927', 0.003123, 0.002927]
# ['hitbtc', u'GUPBTC', u'0.00017499', u'0.00012110', 0.00017499, 0.0001211]
# ['hitbtc', u'RLCBTC', u'0.00032000', u'0.00024500', 0.00032, 0.000245]
# ['hitbtc', u'AEONBTC', u'0.00027000', u'0.00026000', 0.00027, 0.00026]
# ['hitbtc', u'REPBTC', u'0.013490', u'0.011092', 0.01349, 0.011092]
# ['hitbtc', u'SNGLSBTC', u'0.00008890', u'0.00008001', 8.89e-05, 8.001e-05]
# ['hitbtc', u'EMCBTC', u'0.00055000', u'0.00054100', 0.00055, 0.000541]
# ['hitbtc', u'TRSTBTC', u'0.000140', u'0.000112', 0.00014, 0.000112]
# ['hitbtc', u'BTCUSD', u'2439.92', u'2430.00', 2442.836, 2425.6863999999996]
# ['hitbtc', u'BCNUSD', u'0.001955', u'0.001921', 0.001955, 0.001921]
# ['hitbtc', u'ETHEUR', u'324.9999', u'155.0001', 324.99999959999997, 155.0000144]
# ['hitbtc', u'LTCBTC', u'0.01308', u'0.01307', 0.01308, 0.01307]
# ['hitbtc', u'DSHBTC', u'0.000015716', u'0.000015306', 1.5716e-05, 1.5306e-05]
# ['hitbtc', u'ZECBTC', u'0.151692', u'0.151691', 0.151692, 0.151691]
# ['hitbtc', u'MAIDUSD', u'0.473532', u'0.457469', 0.473532, 0.457469]
# ['hitbtc', u'STEEMEUR', u'2.0000', u'1.0000', 2.357216, 0.68128]
# ['hitbtc', u'TAASBTC', u'0.00127000', u'0.00100021', 0.00127, 0.00100021]
# ['hitbtc', u'SWTBTC', u'0.00229998', u'0.00160002', 0.00229998, 0.00160002]
# ['hitbtc', u'ZECUSD', u'374.79', u'364.61', 375.61400000000003, 364.61]
# ['hitbtc', u'WINGSBTC', u'0.00030000', u'0.00029500', 0.0003, 0.000295]
# ['hitbtc', u'SCBTC', u'0.000006100', u'0.000005642', 6.1e-06, 5.642e-06]
# ['hitbtc', u'XEMUSD', u'0.190012', u'0.183919', 0.190031, 0.183921]
# ['hitbtc', u'LSKEUR', u'4.0000', u'2.0002', 4.499499999999999, 2.0002]
# ['hitbtc', u'BCNBTC', u'0.0000008000', u'0.0000007999', 8e-07, 7.999e-07]
# ['hitbtc', u'LUNBTC', u'0.00269998', u'0.00105019', 0.00269998, 0.00105019]
# ['hitbtc', u'LTCUSD', u'32.046', u'31.634', 32.0802, 31.634]
# ['hitbtc', u'DCTBTC', u'0.003900', u'0.001329', 0.0039, 0.001329]
# ['hitbtc', u'ICNBTC', u'0.000798', u'0.000780', 0.000798, 0.00074254]
# ['hitbtc', u'NXTBTC', u'0.00006560', u'0.00006538', 6.56e-05, 6.538e-05]
# ['hitbtc', u'TKNBTC', u'0.00041899', u'0.00030002', 0.00041899, 0.00030002]
# ['hitbtc', u'ETHUSD', u'353.28', u'346.28', 353.8582, 346.27047999999996]
# ['hitbtc', u'ETCBTC', u'0.006955', u'0.006923', 0.006955, 0.006923]
# ['hitbtc', u'XEMBTC', u'0.00007714', u'0.00007648', 7.713e-05, 7.648e-05]
# ['hitbtc', u'LSKBTC', u'0.0012455', u'0.0012371', 0.0012468, 0.001234988]
# ['hitbtc', u'ETCUSD', u'18.74', u'16.85', 19.192040000000002, 16.85]
# ['hitbtc', u'XDNBTC', u'0.0000019031', u'0.0000018950', 1.9033e-06, 1.9e-06]
# ['hitbtc', u'ARDRBTC', u'0.000086130', u'0.000081500', 8.613e-05, 8.15e-05]
# ['hitbtc', u'ETHBTC', u'0.142440', u'0.142438', 0.14264728000000002, 0.142468]
# ['hitbtc', u'NXTUSD', u'0.16570', u'0.15121', 0.1657, 0.15121]
# ['hitbtc', u'GNOBTC', u'0.104500', u'0.090001', 0.10504335999999999, 0.09000002]
# ['hitbtc', u'DOGEBTC', u'0.000001210', u'0.000001205', 1.21e-06, 1.205e-06]
# ['hitbtc', u'STEEMBTC', u'0.00085', u'0.00083', 0.00085, 0.00083]
# ['hitbtc', u'WAVESBTC', u'0.0021999', u'0.0020006', 0.002199996, 0.0020006]
# ['hitbtc', u'XDNUSD', u'0.004681', u'0.004542', 0.004681, 0.004542]
# ['hitbtc', u'AMPBTC', u'0.00020000', u'0.00017400', 0.0002, 0.000174]
# ['hitbtc', u'LTCEUR', u'25.823', u'11.603', 25.8234, 11.6024]
# ['hitbtc', u'XAURBTC', u'0.00012771', u'0.00009501', 0.00012771, 9.501e-05]
# ['hitbtc', u'DASHUSD', u'161.95', u'158.11', 161.82, 158.11]
# ['hitbtc', u'DGDBTC', u'0.042999', u'0.037700', 0.08727942, 0.037518408]
# ['hitbtc', u'XMRUSD', u'47.29', u'46.62', 47.37964, 46.63]

# %%
pairs=open('pairs.txt').read()
pairs=pairs.replace("_","").split("\n")
print pairs
# Out:
# ['1STBTC', '1STDASH', '1STDOGE', '1STETC', '1STETH', '1STEUR', '1STLTC', '1STNXT', '1STPOSW', '1STREP', '1STRUR', '1STUSD', '1STUSDT', '1STXMR', '1STZEC', '2GIVEBTC', '2GIVEDASH', '2GIVEDOGE', '2GIVEETC', '2GIVEETH', '2GIVEEUR', '2GIVELTC', '2GIVENXT', '2GIVEPOSW', '2GIVEREP', '2GIVERUR', '2GIVEUSD', '2GIVEUSDT', '2GIVEXMR', '2GIVEZEC', '8BITBTC', '8BITDASH', '8BITDOGE', '8BITETC', '8BITETH', '8BITEUR', '8BITLTC', '8BITNXT', '8BITPOSW', '8BITREP', '8BITRUR', '8BITUSD', '8BITUSDT', '8BITXMR', '8BITZEC', 'ABYBTC', 'ABYDASH', 'ABYDOGE', 'ABYETC', 'ABYETH', 'ABYEUR', 'ABYLTC', 'ABYNXT', 'ABYPOSW', 'ABYREP', 'ABYRUR', 'ABYUSD', 'ABYUSDT', 'ABYXMR', 'ABYZEC', 'ACPBTC', 'ACPDASH', 'ACPDOGE', 'ACPETC', 'ACPETH', 'ACPEUR', 'ACPLTC', 'ACPNXT', 'ACPPOSW', 'ACPREP', 'ACPRUR', 'ACPUSD', 'ACPUSDT', 'ACPXMR', 'ACPZEC', 'ADCNBTC', 'ADCNDASH', 'ADCNDOGE', 'ADCNETC', 'ADCNETH', 'ADCNEUR', 'ADCNLTC', 'ADCNNXT', 'ADCNPOSW', 'ADCNREP', 'ADCNRUR', 'ADCNUSD', 'ADCNUSDT', 'ADCNXMR', 'ADCNZEC', 'ADZBTC', 'ADZDASH', 'ADZDOGE', 'ADZETC', 'ADZETH', 'ADZEUR', 'ADZLTC', 'ADZNXT', 'ADZPOSW', 'ADZREP', 'ADZRUR', 'ADZUSD', 'ADZUSDT', 'ADZXMR', 'ADZZEC', 'AEONBTC', 'AEONDASH', 'AEONDOGE', 'AEONETC', 'AEONETH', 'AEONEUR', 'AEONLTC', 'AEONNXT', 'AEONPOSW', 'AEONREP', 'AEONRUR', 'AEONUSD', 'AEONUSDT', 'AEONXMR', 'AEONZEC', 'AIBBTC', 'AIBDASH', 'AIBDOGE', 'AIBETC', 'AIBETH', 'AIBEUR', 'AIBLTC', 'AIBNXT', 'AIBPOSW', 'AIBREP', 'AIBRUR', 'AIBUSD', 'AIBUSDT', 'AIBXMR', 'AIBZEC', 'AMPBTC', 'AMPDASH', 'AMPDOGE', 'AMPETC', 'AMPETH', 'AMPEUR', 'AMPLTC', 'AMPNXT', 'AMPPOSW', 'AMPREP', 'AMPRUR', 'AMPUSD', 'AMPUSDT', 'AMPXMR', 'AMPZEC', 'ARCBTC', 'ARCDASH', 'ARCDOGE', 'ARCETC', 'ARCETH', 'ARCEUR', 'ARCLTC', 'ARCNXT', 'ARCPOSW', 'ARCREP', 'ARCRUR', 'ARCUSD', 'ARCUSDT', 'ARCXMR', 'ARCZEC', 'ARDRBTC', 'ARDRDASH', 'ARDRDOGE', 'ARDRETC', 'ARDRETH', 'ARDREUR', 'ARDRLTC', 'ARDRNXT', 'ARDRPOSW', 'ARDRREP', 'ARDRRUR', 'ARDRUSD', 'ARDRUSDT', 'ARDRXMR', 'ARDRZEC', 'AURBTC', 'AURDASH', 'AURDOGE', 'AURETC', 'AURETH', 'AUREUR', 'AURLTC', 'AURNXT', 'AURPOSW', 'AURREP', 'AURRUR', 'AURUSD', 'AURUSDT', 'AURXMR', 'AURZEC', 'BASHBTC', 'BASHDASH', 'BASHDOGE', 'BASHETC', 'BASHETH', 'BASHEUR', 'BASHLTC', 'BASHNXT', 'BASHPOSW', 'BASHREP', 'BASHRUR', 'BASHUSD', 'BASHUSDT', 'BASHXMR', 'BASHZEC', 'BAYBTC', 'BAYDASH', 'BAYDOGE', 'BAYETC', 'BAYETH', 'BAYEUR', 'BAYLTC', 'BAYNXT', 'BAYPOSW', 'BAYREP', 'BAYRUR', 'BAYUSD', 'BAYUSDT', 'BAYXMR', 'BAYZEC', 'BCCBTC', 'BCCDASH', 'BCCDOGE', 'BCCETC', 'BCCETH', 'BCCEUR', 'BCCLTC', 'BCCNXT', 'BCCPOSW', 'BCCREP', 'BCCRUR', 'BCCUSD', 'BCCUSDT', 'BCCXMR', 'BCCZEC', 'BCNBTC', 'BCNDASH', 'BCNDOGE', 'BCNETC', 'BCNETH', 'BCNEUR', 'BCNLTC', 'BCNNXT', 'BCNPOSW', 'BCNREP', 'BCNRUR', 'BCNUSD', 'BCNUSDT', 'BCNXMR', 'BCNZEC', 'BCYBTC', 'BCYDASH', 'BCYDOGE', 'BCYETC', 'BCYETH', 'BCYEUR', 'BCYLTC', 'BCYNXT', 'BCYPOSW', 'BCYREP', 'BCYRUR', 'BCYUSD', 'BCYUSDT', 'BCYXMR', 'BCYZEC', 'BHCBTC', 'BHCDASH', 'BHCDOGE', 'BHCETC', 'BHCETH', 'BHCEUR', 'BHCLTC', 'BHCNXT', 'BHCPOSW', 'BHCREP', 'BHCRUR', 'BHCUSD', 'BHCUSDT', 'BHCXMR', 'BHCZEC', 'BIOSBTC', 'BIOSDASH', 'BIOSDOGE', 'BIOSETC', 'BIOSETH', 'BIOSEUR', 'BIOSLTC', 'BIOSNXT', 'BIOSPOSW', 'BIOSREP', 'BIOSRUR', 'BIOSUSD', 'BIOSUSDT', 'BIOSXMR', 'BIOSZEC', 'BITBTC', 'BITDASH', 'BITDOGE', 'BITETC', 'BITETH', 'BITEUR', 'BITLTC', 'BITNXT', 'BITPOSW', 'BITREP', 'BITRUR', 'BITUSD', 'BITUSDT', 'BITXMR', 'BITZEC', 'BITBBTC', 'BITBDASH', 'BITBDOGE', 'BITBETC', 'BITBETH', 'BITBEUR', 'BITBLTC', 'BITBNXT', 'BITBPOSW', 'BITBREP', 'BITBRUR', 'BITBUSD', 'BITBUSDT', 'BITBXMR', 'BITBZEC', 'BLKBTC', 'BLKDASH', 'BLKDOGE', 'BLKETC', 'BLKETH', 'BLKEUR', 'BLKLTC', 'BLKNXT', 'BLKPOSW', 'BLKREP', 'BLKRUR', 'BLKUSD', 'BLKUSDT', 'BLKXMR', 'BLKZEC', 'BLUBTC', 'BLUDASH', 'BLUDOGE', 'BLUETC', 'BLUETH', 'BLUEUR', 'BLULTC', 'BLUNXT', 'BLUPOSW', 'BLUREP', 'BLURUR', 'BLUUSD', 'BLUUSDT', 'BLUXMR', 'BLUZEC', 'BPCBTC', 'BPCDASH', 'BPCDOGE', 'BPCETC', 'BPCETH', 'BPCEUR', 'BPCLTC', 'BPCNXT', 'BPCPOSW', 'BPCREP', 'BPCRUR', 'BPCUSD', 'BPCUSDT', 'BPCXMR', 'BPCZEC', 'BSDBTC', 'BSD ...

# %%
print ticker_url
# Out:
# https://api.hitbtc.com/api/1/public/ticker
